# %%
import glob
import regex as re
from collections import Counter

import pandas as pd

from scipy.stats import zscore
from scipy.spatial import distance

import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer

class Zscores():
    def __init__(self, data):
        self.data = data

    def remove_stopwords(self):
        stopword = open("de_stopwords.txt")
        stopwords = stopword.read()
        self.data['text'] = [str(i).lower() for i in self.data['text']]
        self.data['removedstopword'] = self.data['text'].apply(lambda x: ' '.join([item for item in str(x).split() if item not in stopwords]))
        return self.data


    def count_frequencies(self, df):
        freq_list = []
        for i, row in df.iterrows():
            title = str(row.ID)
            vocab = Counter(row.removedstopword.split())
            frequencies = list(vocab.values())
            words = list(vocab.keys())
            freq_list.append(pd.Series(frequencies, words, name=title))
        return freq_list

    def calculate_zscores(self):
        df = self.remove_stopwords()
        freq_list = self.count_frequencies(df)
        counts = pd.DataFrame(freq_list)
        counts = counts.fillna(0)
        counts = counts.div(counts.sum(axis=1), axis=0)
        counts.loc['Total_per_word'] = counts.sum()
        counts = counts.sort_values(by='Total_per_word', axis=1, ascending=False)
        counts.drop('Total_per_word', inplace=True, axis=0)
#         print(counts)
        zscores = counts.apply(zscore)
#         print(zscores)

        zscores.drop(zscores.columns[1000:], inplace=True, axis=1)

        return counts, zscores

# %%
poems = pd.read_csv('../corpus/0_csv_fuer_delta/fontane_corpus_gesamt.csv')
z = Zscores(poems)
counts, zscores = z.calculate_zscores()
# zscores.to_csv('../results/delta/zscores_fontane.csv')
counts
# Out:
# /home/teresa/.local/lib/python3.7/site-packages/ipykernel_launcher.py:34: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#                                                       in+die      herz  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000  0.000000
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.025641  0.128205
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000  0.000000
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.023923  0.009569
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000  0.000000
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.038462  0.000000
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.031746  0.000000
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.000000  0.000000
#
#                                                       zu+die    an+die  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000  0.000000
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000  0.000000
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.009569  0.000000
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000  0.000000
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.038462  0.000000
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.000000  0.015873
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.000000  0.000000
#
#                                                          alt    stehen  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000  0.000000
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000  0.029412
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.004785  0.009569
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000  0.000000
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.038462  0.000000
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.000000  0.000000
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.048780  0.000000
#
#                                                       liegen  still     glück  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000    0.0  0.000000
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000    0.0  0.000000
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000    0.0  0.000000
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.025641    0.0  0.025641
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000    0.0  0.000000
# ...                                                      ...    ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.004785    0.0  0.000000
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000    0.0  0.000000
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.000000    0.0  0.000000
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.015873    0.0  0.000000
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.000000    0.0  0.024390
#
#                                                         kind  ...  knöchel  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000  ...      0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000  ...      0.0
# ...                                                      ...  ...      ...
# autoren_lyrik_lemma_fontane_Religion                0.004785  ...      0.0
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000  ...      0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.000000  ...      0.0
#
#                                                     treulich  ausgehöhlt  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben               0.0         0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...       0.0         0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...       0.0         0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...       0.0         0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...       0.0         0.0
# ...                                                      ...         ...
# autoren_lyrik_lemma_fontane_Religion                     0.0         0.0
# autoren_lyrik_lemma_Fontane_Prolog                       0.0         0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz         0.0         0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                 0.0         0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...       0.0         0.0
#
#                                                     baumstamm  felsig  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben                0.0     0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...        0.0     0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...        0.0     0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...        0.0     0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...        0.0     0.0
# ...                                                       ...     ...
# autoren_lyrik_lemma_fontane_Religion                      0.0     0.0
# autoren_lyrik_lemma_Fontane_Prolog                        0.0     0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz          0.0     0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                  0.0     0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...        0.0     0.0
#
#                                                     phöniciens  great  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben                 0.0    0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...         0.0    0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...         0.0    0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...         0.0    0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...         0.0    0.0
# ...                                                        ...    ...
# autoren_lyrik_lemma_fontane_Religion                       0.0    0.0
# autoren_lyrik_lemma_Fontane_Prolog                         0.0    0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz           0.0    0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                   0.0    0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...         0.0    0.0
#
#                                                     eastern  eisengeschuppten  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben              0.0               0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...      0.0               0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...      0.0               0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...      0.0               0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...      0.0               0.0
# ...                                                     ...               ...
# autoren_lyrik_lemma_fontane_Religion                    0.0               0.0
# autoren_lyrik_lemma_Fontane_Prolog                      0.0               0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz        0.0               0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                0.0               0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...      0.0               0.0
#
#                                                     mephisto
# autoren_lyrik_lemma_Fontane_Die zwei Raben               0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...       0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...       0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...       0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...       0.0
# ...                                                      ...
# autoren_lyrik_lemma_fontane_Religion                     0.0
# autoren_lyrik_lemma_Fontane_Prolog                       0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz         0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                 0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...       0.0
#
# [720 rows x 13643 columns]
#                                                     in+die  herz  zu+die  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben             NaN   NaN     NaN
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...     NaN   NaN     NaN
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...     NaN   NaN     NaN
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...     NaN   NaN     NaN
# autoren_lyrik_lemma_fontane_König Karl der Zwei...     NaN   NaN     NaN
# ...                                                    ...   ...     ...
# autoren_lyrik_lemma_fontane_Religion                   NaN   NaN     NaN
# autoren_lyrik_lemma_Fontane_Prolog                     NaN   NaN     NaN
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz       NaN   NaN     NaN
# autoren_lyrik_lemma_fontane_Hastingsfeld               NaN   NaN     NaN
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...     NaN   NaN     NaN
#
#                                                     an+die  alt  stehen  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben             NaN  NaN     NaN
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...     NaN  NaN     NaN
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...     NaN  NaN     NaN
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...     NaN  NaN     NaN
# autoren_lyrik_lemma_fontane_König Karl der Zwei...     NaN  NaN     NaN
# ...                                                    ...  ...     ...
# autoren_lyrik_lemma_fontane_Religion                   NaN  NaN     NaN
# autoren_lyrik_lemma_Fontane_Prolog                     NaN  NaN     NaN
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz       NaN  NaN     NaN
# autoren_lyrik_lemma_fontane_Hastingsfeld               NaN  NaN     NaN
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...     NaN  NaN     NaN
#
#                                                     liegen  still  glück  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben             NaN    NaN    NaN
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...     NaN    NaN    NaN
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...     NaN    NaN    NaN
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...     NaN    NaN    NaN
# autoren_lyrik_lemma_fontane_König Karl der Zwei...     NaN    NaN    NaN
# ...                                                    ...    ...    ...
# autoren_lyrik_lemma_fontane_Religion                   NaN    NaN    NaN
# autoren_lyrik_lemma_Fontane_Prolog                     NaN    NaN    NaN
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz       NaN    NaN    NaN
# autoren_lyrik_lemma_fontane_Hastingsfeld               NaN    NaN    NaN
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...     NaN    NaN    NaN
#
#                                                     kind  ...  knöchel  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben           NaN  ...      NaN
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...   NaN  ...      NaN
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...   NaN  ...      NaN
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...   NaN  ...      NaN
# autoren_lyrik_lemma_fontane_König Karl der Zwei...   NaN  ...      NaN
# ...                                                  ...  ...      ...
# autoren_lyrik_lemma_fontane_Religion                 NaN  ...      NaN
# autoren_lyrik_lemma_Fontane_Prolog                   NaN  ...      NaN
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz     NaN  ...      NaN
# autoren_lyrik_lemma_fontane_Hastingsfeld             NaN  ...      NaN
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...   NaN  ...      NaN
#
#                                                     treulich  ausgehöhlt  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben               NaN         NaN
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...       NaN         NaN
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...       NaN         NaN
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...       NaN         NaN
# autoren_lyrik_lemma_fontane_König Karl der Zwei...       NaN         NaN
# ...                                                      ...         ...
# autoren_lyrik_lemma_fontane_Religion                     NaN         NaN
# autoren_lyrik_lemma_Fontane_Prolog                       NaN         NaN
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz         NaN         NaN
# autoren_lyrik_lemma_fontane_Hastingsfeld                 NaN         NaN
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...       NaN         NaN
#
#                                                     baumstamm  felsig  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben                NaN     NaN
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...        NaN     NaN
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...        NaN     NaN
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...        NaN     NaN
# autoren_lyrik_lemma_fontane_König Karl der Zwei...        NaN     NaN
# ...                                                       ...     ...
# autoren_lyrik_lemma_fontane_Religion                      NaN     NaN
# autoren_lyrik_lemma_Fontane_Prolog                        NaN     NaN
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz          NaN     NaN
# autoren_lyrik_lemma_fontane_Hastingsfeld                  NaN     NaN
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...        NaN     NaN
#
#                                                     phöniciens  great  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben                 NaN    NaN
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...         NaN    NaN
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...         NaN    NaN
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...         NaN    NaN
# autoren_lyrik_lemma_fontane_König Karl der Zwei...         NaN    NaN
# ...                                                        ...    ...
# autoren_lyrik_lemma_fontane_Religion                       NaN    NaN
# autoren_lyrik_lemma_Fontane_Prolog                         NaN    NaN
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz           NaN    NaN
# autoren_lyrik_lemma_fontane_Hastingsfeld                   NaN    NaN
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...         NaN    NaN
#
#                                                     eastern  eisengeschuppten  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben              NaN               NaN
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...      NaN               NaN
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...      NaN               NaN
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...      NaN               NaN
# autoren_lyrik_lemma_fontane_König Karl der Zwei...      NaN               NaN
# ...                                                     ...               ...
# autoren_lyrik_lemma_fontane_Religion                    NaN               NaN
# autoren_lyrik_lemma_Fontane_Prolog                      NaN               NaN
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz        NaN               NaN
# autoren_lyrik_lemma_fontane_Hastingsfeld                NaN               NaN
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...      NaN               NaN
#
#                                                     mephisto
# autoren_lyrik_lemma_Fontane_Die zwei Raben               NaN
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...       NaN
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...       NaN
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...       NaN
# autoren_lyrik_lemma_fontane_König Karl der Zwei...       NaN
# ...                                                      ...
# autoren_lyrik_lemma_fontane_Religion                     NaN
# autoren_lyrik_lemma_Fontane_Prolog                       NaN
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz         NaN
# autoren_lyrik_lemma_fontane_Hastingsfeld                 NaN
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...       NaN
#
# [720 rows x 13643 columns]
#                                                       in+die      herz  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000  0.000000
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.025641  0.128205
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000  0.000000
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.023923  0.009569
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000  0.000000
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.038462  0.000000
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.031746  0.000000
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.000000  0.000000
#
#                                                       zu+die    an+die  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000  0.000000
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000  0.000000
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.009569  0.000000
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000  0.000000
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.038462  0.000000
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.000000  0.015873
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.000000  0.000000
#
#                                                          alt    stehen  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000  0.000000
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.000000  0.000000
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000  0.029412
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.004785  0.009569
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000  0.000000
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.038462  0.000000
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.000000  0.000000
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.048780  0.000000
#
#                                                       liegen  still     glück  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000    0.0  0.000000
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000    0.0  0.000000
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000    0.0  0.000000
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.025641    0.0  0.025641
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000    0.0  0.000000
# ...                                                      ...    ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.004785    0.0  0.000000
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000    0.0  0.000000
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.000000    0.0  0.000000
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.015873    0.0  0.000000
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.000000    0.0  0.024390
#
#                                                         kind  ...  knöchel  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          0.000000  ...      0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  0.000000  ...      0.0
# ...                                                      ...  ...      ...
# autoren_lyrik_lemma_fontane_Religion                0.004785  ...      0.0
# autoren_lyrik_lemma_Fontane_Prolog                  0.000000  ...      0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.000000  ...      0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  0.000000  ...      0.0
#
#                                                     treulich  ausgehöhlt  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben               0.0         0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...       0.0         0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...       0.0         0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...       0.0         0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...       0.0         0.0
# ...                                                      ...         ...
# autoren_lyrik_lemma_fontane_Religion                     0.0         0.0
# autoren_lyrik_lemma_Fontane_Prolog                       0.0         0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz         0.0         0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                 0.0         0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...       0.0         0.0
#
#                                                     baumstamm  felsig  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben                0.0     0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...        0.0     0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...        0.0     0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...        0.0     0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...        0.0     0.0
# ...                                                       ...     ...
# autoren_lyrik_lemma_fontane_Religion                      0.0     0.0
# autoren_lyrik_lemma_Fontane_Prolog                        0.0     0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz          0.0     0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                  0.0     0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...        0.0     0.0
#
#                                                     phöniciens  great  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben                 0.0    0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...         0.0    0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...         0.0    0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...         0.0    0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...         0.0    0.0
# ...                                                        ...    ...
# autoren_lyrik_lemma_fontane_Religion                       0.0    0.0
# autoren_lyrik_lemma_Fontane_Prolog                         0.0    0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz           0.0    0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                   0.0    0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...         0.0    0.0
#
#                                                     eastern  eisengeschuppten  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben              0.0               0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...      0.0               0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...      0.0               0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...      0.0               0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...      0.0               0.0
# ...                                                     ...               ...
# autoren_lyrik_lemma_fontane_Religion                    0.0               0.0
# autoren_lyrik_lemma_Fontane_Prolog                      0.0               0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz        0.0               0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                0.0               0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...      0.0               0.0
#
#                                                     mephisto
# autoren_lyrik_lemma_Fontane_Die zwei Raben               0.0
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...       0.0
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...       0.0
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...       0.0
# autoren_lyrik_lemma_fontane_König Karl der Zwei...       0.0
# ...                                                      ...
# autoren_lyrik_lemma_fontane_Religion                     0.0
# autoren_lyrik_lemma_Fontane_Prolog                       0.0
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz         0.0
# autoren_lyrik_lemma_fontane_Hastingsfeld                 0.0
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...       0.0
#
# [720 rows x 13643 columns]

# %%
z = counts - counts.mean()/counts.std(ddof=0)
z
# Out:
#                                                       in+die      herz  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.573394 -0.375032
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.573394 -0.375032
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.573394 -0.375032
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.547753 -0.246826
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.573394 -0.375032
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion               -0.549471 -0.365462
# autoren_lyrik_lemma_Fontane_Prolog                 -0.573394 -0.375032
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.534933 -0.375032
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.541648 -0.375032
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.573394 -0.375032
#
#                                                       zu+die    an+die  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.357853 -0.297434
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.357853 -0.297434
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.357853 -0.297434
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.357853 -0.297434
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.357853 -0.297434
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion               -0.348284 -0.297434
# autoren_lyrik_lemma_Fontane_Prolog                 -0.357853 -0.297434
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.319391 -0.297434
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.357853 -0.281561
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.357853 -0.297434
#
#                                                          alt    stehen  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.334467 -0.207769
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.334467 -0.207769
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.334467 -0.207769
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.334467 -0.207769
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.334467 -0.178357
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion               -0.329682 -0.198200
# autoren_lyrik_lemma_Fontane_Prolog                 -0.334467 -0.207769
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.296005 -0.207769
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.334467 -0.207769
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.285686 -0.207769
#
#                                                       liegen    still  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.261299 -0.24733
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.261299 -0.24733
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.261299 -0.24733
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.235658 -0.24733
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.261299 -0.24733
# ...                                                      ...      ...
# autoren_lyrik_lemma_fontane_Religion               -0.256514 -0.24733
# autoren_lyrik_lemma_Fontane_Prolog                 -0.261299 -0.24733
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.261299 -0.24733
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.245426 -0.24733
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.261299 -0.24733
#
#                                                        glück      kind  ...  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.193622 -0.202280  ...
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.193622 -0.202280  ...
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.193622 -0.202280  ...
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.167981 -0.202280  ...
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.193622 -0.202280  ...
# ...                                                      ...       ...  ...
# autoren_lyrik_lemma_fontane_Religion               -0.193622 -0.197495  ...
# autoren_lyrik_lemma_Fontane_Prolog                 -0.193622 -0.202280  ...
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.193622 -0.202280  ...
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.193622 -0.202280  ...
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.169232 -0.202280  ...
#
#                                                     knöchel  treulich  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.03732  -0.03732
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.03732  -0.03732
# ...                                                     ...       ...
# autoren_lyrik_lemma_fontane_Religion               -0.03732  -0.03732
# autoren_lyrik_lemma_Fontane_Prolog                 -0.03732  -0.03732
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.03732  -0.03732
#
#                                                     ausgehöhlt  baumstamm  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben            -0.03732   -0.03732
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...    -0.03732   -0.03732
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...    -0.03732   -0.03732
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...    -0.03732   -0.03732
# autoren_lyrik_lemma_fontane_König Karl der Zwei...    -0.03732   -0.03732
# ...                                                        ...        ...
# autoren_lyrik_lemma_fontane_Religion                  -0.03732   -0.03732
# autoren_lyrik_lemma_Fontane_Prolog                    -0.03732   -0.03732
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz      -0.03732   -0.03732
# autoren_lyrik_lemma_fontane_Hastingsfeld              -0.03732   -0.03732
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...    -0.03732   -0.03732
#
#                                                      felsig  phöniciens  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.03732    -0.03732
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.03732    -0.03732
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.03732    -0.03732
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.03732    -0.03732
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.03732    -0.03732
# ...                                                     ...         ...
# autoren_lyrik_lemma_fontane_Religion               -0.03732    -0.03732
# autoren_lyrik_lemma_Fontane_Prolog                 -0.03732    -0.03732
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.03732    -0.03732
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.03732    -0.03732
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.03732    -0.03732
#
#                                                       great  eastern  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.03732 -0.03732
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.03732 -0.03732
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.03732 -0.03732
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.03732 -0.03732
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.03732 -0.03732
# ...                                                     ...      ...
# autoren_lyrik_lemma_fontane_Religion               -0.03732 -0.03732
# autoren_lyrik_lemma_Fontane_Prolog                 -0.03732 -0.03732
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.03732 -0.03732
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.03732 -0.03732
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.03732 -0.03732
#
#                                                     eisengeschuppten  mephisto
# autoren_lyrik_lemma_Fontane_Die zwei Raben                  -0.03732  -0.03732
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...          -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...          -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...          -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_König Karl der Zwei...          -0.03732  -0.03732
# ...                                                              ...       ...
# autoren_lyrik_lemma_fontane_Religion                        -0.03732  -0.03732
# autoren_lyrik_lemma_Fontane_Prolog                          -0.03732  -0.03732
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz            -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_Hastingsfeld                    -0.03732  -0.03732
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...          -0.03732  -0.03732
#
# [720 rows x 13643 columns]

# %%
poems = pd.read_csv('../corpus/0_csv_fuer_delta/hauptcorpus_gesamt.csv')
z = Zscores(poems)
counts, zscores = z.calculate_zscores()
# zscores.to_csv('../results/delta/zscores_fontane.csv')

# %%
counts
# Out:
#                                  in+die      herz    zu+die    an+die  \
# lyrik_lemma_l00100002          0.058824  0.000000  0.019608  0.000000
# lyrik_lemma_l00100003          0.000000  0.045455  0.000000  0.000000
# lyrik_lemma_l00100004          0.058824  0.000000  0.000000  0.000000
# lyrik_lemma_l00100005          0.000000  0.000000  0.000000  0.000000
# lyrik_lemma_l00100006          0.047619  0.023810  0.000000  0.000000
# ...                                 ...       ...       ...       ...
# epik_lemma_lewald_clementine   0.006754  0.009583  0.004928  0.002921
# epik_lemma_falke_durchschnitt  0.011482  0.001914  0.008190  0.005971
# epik_lemma_heiberg_frau        0.008912  0.001936  0.004681  0.002521
# epik_lemma_meyer_richterin     0.009249  0.002563  0.004012  0.004792
# epik_lemma_fontane_birnbaum    0.007032  0.001157  0.006409  0.005786
#
#                                   nacht     still      hand   von+die  \
# lyrik_lemma_l00100002          0.000000  0.000000  0.000000  0.019608
# lyrik_lemma_l00100003          0.000000  0.000000  0.000000  0.000000
# lyrik_lemma_l00100004          0.000000  0.000000  0.000000  0.019608
# lyrik_lemma_l00100005          0.000000  0.000000  0.000000  0.022727
# lyrik_lemma_l00100006          0.000000  0.023810  0.000000  0.000000
# ...                                 ...       ...       ...       ...
# epik_lemma_lewald_clementine   0.001643  0.001186  0.003012  0.000730
# epik_lemma_falke_durchschnitt  0.000153  0.000306  0.002603  0.002067
# epik_lemma_heiberg_frau        0.000900  0.000540  0.005041  0.000990
# epik_lemma_meyer_richterin     0.000891  0.001003  0.007689  0.001449
# epik_lemma_fontane_birnbaum    0.000801  0.000801  0.004540  0.003027
#
#                                    tief      auge  ...  seďfs  schiffbruches  \
# lyrik_lemma_l00100002          0.000000  0.000000  ...    0.0            0.0
# lyrik_lemma_l00100003          0.000000  0.000000  ...    0.0            0.0
# lyrik_lemma_l00100004          0.000000  0.000000  ...    0.0            0.0
# lyrik_lemma_l00100005          0.000000  0.022727  ...    0.0            0.0
# lyrik_lemma_l00100006          0.000000  0.000000  ...    0.0            0.0
# ...                                 ...       ...  ...    ...            ...
# epik_lemma_lewald_clementine   0.002464  0.003833  ...    0.0            0.0
# epik_lemma_falke_durchschnitt  0.001684  0.002679  ...    0.0            0.0
# epik_lemma_heiberg_frau        0.001575  0.004276  ...    0.0            0.0
# epik_lemma_meyer_richterin     0.001560  0.005683  ...    0.0            0.0
# epik_lemma_fontane_birnbaum    0.000979  0.001869  ...    0.0            0.0
#
#                                schrankartiger  deghri  patronenkapsel  \
# lyrik_lemma_l00100002                     0.0     0.0             0.0
# lyrik_lemma_l00100003                     0.0     0.0             0.0
# lyrik_lemma_l00100004                     0.0     0.0             0.0
# lyrik_lemma_l00100005                     0.0     0.0             0.0
# lyrik_lemma_l00100006                     0.0     0.0             0.0
# ...                                       ...     ...             ...
# epik_lemma_lewald_clementine              0.0     0.0             0.0
# epik_lemma_falke_durchschnitt             0.0     0.0             0.0
# epik_lemma_heiberg_frau                   0.0     0.0             0.0
# epik_lemma_meyer_richterin                0.0     0.0             0.0
# epik_lemma_fontane_birnbaum               0.0     0.0             0.0
#
#                                ketschikise  kettschuwal  ziegenfell  \
# lyrik_lemma_l00100002                  0.0          0.0         0.0
# lyrik_lemma_l00100003                  0.0          0.0         0.0
# lyrik_lemma_l00100004                  0.0          0.0         0.0
# lyrik_lemma_l00100005                  0.0          0.0         0.0
# lyrik_lemma_l00100006                  0.0          0.0         0.0
# ...                                    ...          ...         ...
# epik_lemma_lewald_clementine           0.0          0.0         0.0
# epik_lemma_falke_durchschnitt          0.0          0.0         0.0
# epik_lemma_heiberg_frau                0.0          0.0         0.0
# epik_lemma_meyer_richterin             0.0          0.0         0.0
# epik_lemma_fontane_birnbaum            0.0          0.0         0.0
#
#                                haarseite  herübergeklungen
# lyrik_lemma_l00100002                0.0               0.0
# lyrik_lemma_l00100003                0.0               0.0
# lyrik_lemma_l00100004                0.0               0.0
# lyrik_lemma_l00100005                0.0               0.0
# lyrik_lemma_l00100006                0.0               0.0
# ...                                  ...               ...
# epik_lemma_lewald_clementine         0.0               0.0
# epik_lemma_falke_durchschnitt        0.0               0.0
# epik_lemma_heiberg_frau              0.0               0.0
# epik_lemma_meyer_richterin           0.0               0.0
# epik_lemma_fontane_birnbaum          0.0               0.0
#
# [4750 rows x 66084 columns]

# %%
pd.read_csv('../results/delta/zscores_hauptcorpus.csv')
# Out:
#                          Unnamed: 0    in+die      herz    zu+die    an+die  \
# 0             lyrik_lemma_l00100002  1.563739 -0.513578  0.727674 -0.419972
# 1             lyrik_lemma_l00100003 -0.813560  1.859508 -0.511697 -0.419972
# 2             lyrik_lemma_l00100004  1.563739 -0.513578 -0.511697 -0.419972
# 3             lyrik_lemma_l00100005 -0.813560 -0.513578 -0.511697 -0.419972
# 4             lyrik_lemma_l00100006  1.110920  0.729467 -0.511697 -0.419972
# ...                             ...       ...       ...       ...       ...
# 4745   epik_lemma_lewald_clementine -0.540617 -0.013275 -0.200185 -0.217410
# 4746  epik_lemma_falke_durchschnitt -0.349528 -0.413670  0.006005 -0.005859
# 4747        epik_lemma_heiberg_frau -0.453370 -0.412528 -0.215801 -0.245139
# 4748     epik_lemma_meyer_richterin -0.439773 -0.379772 -0.258132 -0.087632
# 4749    epik_lemma_fontane_birnbaum -0.529359 -0.453163 -0.106590 -0.018663
#
#          nacht     still      hand   von+die      tief  ...     mühle  \
# 0    -0.389943 -0.382607 -0.341125  1.346938 -0.315030  ... -0.052825
# 1    -0.389943 -0.382607 -0.341125 -0.397408 -0.315030  ... -0.052825
# 2    -0.389943 -0.382607 -0.341125  1.346938 -0.315030  ... -0.052825
# 3    -0.389943 -0.382607 -0.341125  1.624448 -0.315030  ... -0.052825
# 4    -0.389943  1.162376 -0.341125 -0.397408 -0.315030  ... -0.052825
# ...        ...       ...       ...       ...       ...  ...       ...
# 4745 -0.283174 -0.305619 -0.121934 -0.332455 -0.139037  ... -0.052825
# 4746 -0.379993 -0.362739 -0.151715 -0.213547 -0.194757  ... -0.052825
# 4747 -0.331433 -0.347557  0.025780 -0.309312 -0.202512  ... -0.052825
# 4748 -0.332004 -0.317530  0.218458 -0.268536 -0.203610  ... -0.052825
# 4749 -0.337875 -0.330622 -0.010727 -0.128164 -0.245098  ...  0.083475
#
#          mädel     sorge  unsichtbar  friedlich  flut|fluten     ehren  \
# 0    -0.064558 -0.067829   -0.068593  -0.074197    -0.047408 -0.075286
# 1    -0.064558 -0.067829   -0.068593  -0.074197    -0.047408 -0.075286
# 2    -0.064558 -0.067829   -0.068593  -0.074197    -0.047408 -0.075286
# 3    -0.064558 -0.067829   -0.068593  -0.074197    -0.047408 -0.075286
# 4    -0.064558 -0.067829   -0.068593  -0.074197    -0.047408 -0.075286
# ...        ...       ...         ...        ...          ...       ...
# 4745 -0.064558 -0.031867   -0.032216  -0.074197    -0.047408  0.085004
# 4746 -0.064558 -0.037667   -0.068593  -0.074197    -0.047408  0.092762
# 4747 -0.064558  0.340105    0.003172  -0.054763    -0.047408 -0.015994
# 4748 -0.064558 -0.023921   -0.024178  -0.074197    -0.047408 -0.075286
# 4749 -0.064558  0.212768    0.037847  -0.074197    -0.047408  0.041968
#
#           ward      zahn    künden
# 0    -0.085897 -0.053619 -0.088829
# 1    -0.085897 -0.053619 -0.088829
# 2    -0.085897 -0.053619 -0.088829
# 3    -0.085897 -0.053619 -0.088829
# 4    -0.085897 -0.053619 -0.088829
# ...        ...       ...       ...
# 4745 -0.085897 -0.053619 -0.088829
# 4746 -0.085897 -0.029575 -0.088829
# 4747 -0.085897 -0.011202 -0.088829
# 4748 -0.085897  0.016386 -0.088829
# 4749 -0.085897 -0.053619 -0.088829
#
# [4750 rows x 1001 columns]

# %%
pd.read_csv('../results/delta/zscores_autorencorpus.csv')
# Out:
#                                              Unnamed: 0    in+die      herz  \
# 0            autoren_lyrik_lemma_Fontane_Die zwei Raben -0.616192 -0.385651
# 1                    autoren_lyrik_lemma_christen_Bitte -0.616192 -0.385651
# 2               autoren_lyrik_lemma_Conradi_8. Abschied -0.616192  3.082474
# 3     autoren_lyrik_lemma_dahn_Die Rosen auf dem Kir...  0.238895  0.662852
# 4     autoren_lyrik_lemma_christen_12. [Wenn ich ihn...  2.726421 -0.385651
# ...                                                 ...       ...       ...
# 2329              autoren_lyrik_lemma_conradi_l00170057 -0.616192  0.594471
# 2330                     autoren_lyrik_lemma_dahn_Armin -0.616192 -0.385651
# 2331  autoren_lyrik_lemma_keller_13. [O heiliger Aug...  2.325307 -0.385651
# 2332  autoren_lyrik_lemma_conradi_Ein Ende vor dem A... -0.063278 -0.385651
# 2333  autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rü... -0.616192 -0.385651
#
#         zu+die    an+die       alt     still    liegen     nacht    stehen  \
# 0    -0.418633 -0.305068 -0.295028 -0.290518 -0.287249 -0.273353 -0.229351
# 1    -0.418633 -0.305068 -0.295028  3.341151 -0.287249 -0.273353 -0.229351
# 2    -0.418633 -0.305068 -0.295028  5.296665 -0.287249 -0.273353 -0.229351
# 3    -0.418633 -0.305068 -0.295028 -0.290518 -0.287249 -0.273353 -0.229351
# 4    -0.418633 -0.305068 -0.295028 -0.290518 -0.287249 -0.273353 -0.229351
# ...        ...       ...       ...       ...       ...       ...       ...
# 2329  2.081825 -0.305068 -0.295028  1.288468 -0.287249  1.313332 -0.229351
# 2330 -0.418633 -0.305068 -0.295028 -0.290518 -0.287249 -0.273353 -0.229351
# 2331 -0.418633 -0.305068 -0.295028 -0.290518 -0.287249 -0.273353 -0.229351
# 2332  0.013777 -0.305068 -0.295028  1.347829  0.254326  0.275425  0.782223
# 2333 -0.418633 -0.305068  2.732216 -0.290518 -0.287249 -0.273353 -0.229351
#
#       ...   silbern     maria  nüchtern  betteljung   streben    jammer  \
# 0     ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
# 1     ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
# 2     ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
# 3     ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
# 4     ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
# ...   ...       ...       ...       ...         ...       ...       ...
# 2329  ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
# 2330  ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
# 2331  ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
# 2332  ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
# 2333  ... -0.085715 -0.071874 -0.063147   -0.041242 -0.058623 -0.089055
#
#        skandal  wind|winde|winden  abendrot    gellen
# 0    -0.025871          -0.059878   -0.0641 -0.079232
# 1    -0.025871          -0.059878   -0.0641 -0.079232
# 2    -0.025871          -0.059878   -0.0641 -0.079232
# 3    -0.025871          -0.059878   -0.0641 -0.079232
# 4    -0.025871          -0.059878   -0.0641 -0.079232
# ...        ...                ...       ...       ...
# 2329 -0.025871           7.080034   -0.0641 -0.079232
# 2330 -0.025871          -0.059878   -0.0641 -0.079232
# 2331 -0.025871          -0.059878   -0.0641 -0.079232
# 2332 -0.025871          -0.059878   -0.0641 -0.079232
# 2333 -0.025871          -0.059878   -0.0641 -0.079232
#
# [2334 rows x 1001 columns]

# %%
f = pd.read_hdf('../results/delta/fontane/delta_fontane.h5')
f
# Out:
#                                                     manhattan  cosine label  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben               0.00    1.00  same
# autoren_lyrik_lemma_fontane_Nette Bücher               187.75   -0.01  same
# autoren_lyrik_lemma_fontane_Weltzeitungs-Inserat       195.81   -0.02  same
# autoren_lyrik_lemma_fontane_An die Autoritätskl...     197.58   -0.01  same
# autoren_lyrik_lemma_fontane_Sanft ruhe seine Asche     198.98   -0.01  same
# ...                                                       ...     ...   ...
# autoren_lyrik_lemma_Fontane_Die zwei Raben             295.83    0.01  same
# autoren_lyrik_lemma_Fontane_10. Man wird nicht ...     301.26   -0.01  same
# autoren_lyrik_lemma_Fontane_Der erste Schnee           304.33   -0.01  same
# autoren_lyrik_lemma_Fontane_7. Tritt ein für de...     304.46   -0.01  same
# autoren_lyrik_lemma_fontane_Plädoyer gegen die ...        NaN     NaN  same
#
#                                                    genres   author
# autoren_lyrik_lemma_Fontane_Die zwei Raben          lemma  Fontane
# autoren_lyrik_lemma_fontane_Nette Bücher            lemma  fontane
# autoren_lyrik_lemma_fontane_Weltzeitungs-Inserat    lemma  fontane
# autoren_lyrik_lemma_fontane_An die Autoritätskl...  lemma  fontane
# autoren_lyrik_lemma_fontane_Sanft ruhe seine Asche  lemma  fontane
# ...                                                   ...      ...
# autoren_lyrik_lemma_Fontane_Die zwei Raben          lemma  Fontane
# autoren_lyrik_lemma_Fontane_10. Man wird nicht ...  lemma  Fontane
# autoren_lyrik_lemma_Fontane_Der erste Schnee        lemma  Fontane
# autoren_lyrik_lemma_Fontane_7. Tritt ein für de...  lemma  Fontane
# autoren_lyrik_lemma_fontane_Plädoyer gegen die ...  lemma  fontane
#
# [518400 rows x 5 columns]

# %%
for i, row in f.iterrows():
    f.loc[i,'genres'] = (str(i).split('_')[1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0afbd815301d> in <module>
#       1 for i, row in f.iterrows():
# ----> 2     f.loc[i,'genres'] = (str(i).split('_')[1])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668             key = com.apply_if_callable(key, self.obj)
#     669         indexer = self._get_setitem_indexer(key)
# --> 670         self._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1026                 # scalar
#    1027                 for item in labels:
# -> 1028                     setter(item, value)
#    1029
#    1030         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in setter(item, v)
#     958                     # set the item, possibly having a dtype change
#     959                     s._consolidate_inplace()
# --> 960                     s = s.copy()
#     961                     s._data = s._data.setitem(indexer=pi, value=v)
#     962                     s._maybe_update_cacher(clear=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in copy(self, deep)
#    5809         dtype: object
#    5810         """
# -> 5811         data = self._data.copy(deep=deep)
#    5812         return self._constructor(data).__finalize__(self)
#    5813
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in copy(self, deep)
#     792             new_axes = list(self.axes)
#     793
# --> 794         res = self.apply("copy", deep=deep)
#     795         res.axes = new_axes
#     796         return res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in copy(self, deep)
#     696         values = self.values
#     697         if deep:
# --> 698             values = values.copy()
#     699         return self.make_block_same_class(values, ndim=self.ndim)
#     700
#
# KeyboardInterrupt:

# %%
f
