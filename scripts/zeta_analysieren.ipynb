# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from collections import Counter

# %%
for file in os.listdir('../results/zeta/pro_wort/'):
    print(file)
    fig, ax = plt.subplots(figsize=(20,50))
    zeta = pd.read_csv('../results/zeta/pro_wort/'+file, header=None)
    zeta.columns = ['wort', 'zeta']
    zeta = zeta.sort_values(by='zeta', ascending=False)
    sns.barplot(x='zeta', y=zeta.wort[-100:], data=zeta, color='g')
    title = file.split('_')[0].capitalize()
    filename = file.split('.')[0]
    plt.title(title)
    plt.savefig('../results/zeta/visualisierung/pro_wort/'+ str(filename) + '2.png')
    plt.show()
    plt.close(fig)
# Out:
# adjektive_500pro_wort.csv
# pronomen_500pro_wort.csv
# verben_100pro_wort.csv
# emotion_100pro_wort.csv
# adjektive_1000pro_wort.csv
# anführungszeichen_500pro_wort.csv
# plutchik_100pro_wort.csv
# pronomen_1000pro_wort.csv
# anführungszeichen_100pro_wort.csv
# sentiws_500pro_wort.csv
# pronomen_100pro_wort.csv
# ohneDuplikate_500pro_wort.csv
# sprechmarkerKurz_100pro_wort.csv
# sprechmarkerKurz_1000pro_wort.csv
# erzählinstanz_500pro_wort.csv
# plutchik_1000pro_wort.csv
# nurDuplikate_1000pro_wort.csv
# ohneDuplikate_1000pro_wort.csv
# emotion_1000pro_wort.csv
# anführungszeichen_1000pro_wort.csv
# sentiws_100pro_wort.csv
# sentiws_1000pro_wort.csv
# substantive_100pro_wort.csv
# erzählinstanz_1000pro_wort.csv
# nurDuplikate_500pro_wort.csv
# emotion_500pro_wort.csv
# verben_1000pro_wort.csv
# verben_500pro_wort.csv
# sprechmarker_500pro_wort.csv
# adjektive_100pro_wort.csv
# substantive_1000pro_wort.csv
# sprechmarker_1000pro_wort.csv
# plutchik_500pro_wort.csv
# sprechmarker_100pro_wort.csv
# substantive_500pro_wort.csv
# ohneDuplikate_100pro_wort.csv
# sprechmarkerKurz_500pro_wort.csv
# nurDuplikate_100pro_wort.csv
# erzählinstanz_100pro_wort.csv

# %%
def visualise_zeta(eins, zwei, drei, slices, figsize=(20,10)):
    fig, axs = plt.subplots(1,3, figsize=figsize)
    sns.barplot(x='zeta', y=eins.wort[slices], data=eins, color='b', ax=axs[0])
    axs[0].set_title('100 Wörter pro Segment')
    sns.barplot(x='zeta', y=zwei.wort[slices], data=zwei, color='b', ax=axs[1])
    axs[1].set_title('500 Wörter pro Segment')
    sns.barplot(x='zeta', y=drei.wort[slices], data=drei, color='b', ax=axs[2])
    axs[2].set_title('1000 Wörter pro Segment')
    return
    
def prepare_df(df):
    df.columns = ['wort', 'zeta']
    df = df.sort_values(by='zeta', ascending=False)
    return df

# %%
emotion100 = pd.read_csv('../results/zeta/emotion_100pro_wort.csv', header=None)
emotion100 = prepare_df(emotion100)

emotion500 = pd.read_csv('../results/zeta/emotion_500pro_wort.csv', header=None)
emotion500 = prepare_df(emotion500)

emotion1000 = pd.read_csv('../results/zeta/emotion_1000pro_wort.csv', header=None)
emotion1000 = prepare_df(emotion1000)

visualise_zeta(emotion100, emotion500, emotion1000, slices=slice(0, 10, None))

# %%
nomen100 = pd.read_csv('../results/zeta/nomen_100pro_wort.csv', header=None)
nomen100 = prepare_df(nomen100)

nomen500 = pd.read_csv('../results/zeta/nomen_500pro_wort.csv', header=None)
nomen500 = prepare_df(nomen500)

nomen1000 = pd.read_csv('../results/zeta/nomen_1000pro_wort.csv', header=None)
nomen1000 = prepare_df(nomen1000)

visualise_zeta(nomen100, nomen500, nomen1000, slices=slice(0, -1, None))

# %%
anf100 = pd.read_csv('../results/zeta/anf_100pro_wort.csv', header=None)
anf100 = prepare_df(anf100)

anf500 = pd.read_csv('../results/zeta/anf_500pro_wort.csv', header=None)
anf500 = prepare_df(anf500)

anf1000 = pd.read_csv('../results/zeta/anf_1000pro_wort.csv', header=None)
anf1000 = prepare_df(anf1000)

visualise_zeta(anf100, anf500, anf1000, slices=slice(0, 20, None))

# %%
instanz100 = pd.read_csv('../results/zeta/instanz_100pro_wort.csv', header=None)
instanz100 = prepare_df(instanz100)

instanz500 = pd.read_csv('../results/zeta/instanz_500pro_wort.csv', header=None)
instanz500 = prepare_df(instanz500)

instanz1000 = pd.read_csv('../results/zeta/instanz_1000pro_wort.csv', header=None)
instanz1000 = prepare_df(instanz1000)

visualise_zeta(instanz100, instanz500, instanz1000, slices=slice(0, 20, None))

# %%
sprech100 = pd.read_csv('../results/zeta/sprechmarker_100pro_wort.csv', header=None)
sprech100 = prepare_df(sprech100)

sprech500 = pd.read_csv('../results/zeta/sprechmarker_500pro_wort.csv', header=None)
sprech500 = prepare_df(sprech500)

sprech1000 = pd.read_csv('../results/zeta/sprechmarker_1000pro_wort.csv', header=None)
sprech1000 = prepare_df(sprech1000)

visualise_zeta(sprech100, sprech500, sprech1000, slices=slice(0, 20, None))

# %%
lsprech100 = pd.read_csv('../results/zeta/sprechmarker_lang_100pro_wort.csv', header=None)
lsprech100 = prepare_df(lsprech100)

lsprech500 = pd.read_csv('../results/zeta/sprechmarker_lang_500pro_wort.csv', header=None)
lsprech500 = prepare_df(lsprech500)

lsprech1000 = pd.read_csv('../results/zeta/sprechmarker_lang_1000pro_wort.csv', header=None)
lsprech1000 = prepare_df(lsprech1000)

visualise_zeta(lsprech100, lsprech500, lsprech1000, slices=slice(0, 20, None))

# %%
visualise_zeta(lsprech100, lsprech500, lsprech1000, slices=slice(-20, -1, None))

# %%
ohne_dupl100 = pd.read_csv('../results/zeta/ohne_dupl_100pro_wort.csv', header=None)
ohne_dupl100 = prepare_df(ohne_dupl100)

ohne_dupl500 = pd.read_csv('../results/zeta/ohne_dupl_500pro_wort.csv', header=None)
ohne_dupl500 = prepare_df(ohne_dupl500)

ohne_dupl1000 = pd.read_csv('../results/zeta/ohne_dupl_1000pro_wort.csv', header=None)
ohne_dupl1000 = prepare_df(ohne_dupl1000)

visualise_zeta(ohne_dupl100, ohne_dupl500, ohne_dupl1000, slices=slice(0, 20, None))

# %%
visualise_zeta(ohne_dupl100, ohne_dupl500, ohne_dupl1000, slices=slice(-20, -1, None))

# %%
nur_dupl100 = pd.read_csv('../results/zeta/nur_dupl_100pro_wort.csv', header=None)
nur_dupl100 = prepare_df(nur_dupl100)

nur_dupl500 = pd.read_csv('../results/zeta/nur_dupl_500pro_wort.csv', header=None)
nur_dupl500 = prepare_df(nur_dupl500)

nur_dupl1000 = pd.read_csv('../results/zeta/nur_dupl_1000pro_wort.csv', header=None)
nur_dupl1000 = prepare_df(nur_dupl1000)

visualise_zeta(nur_dupl100, nur_dupl500, nur_dupl1000, slices=slice(0, 20, None))

# %%
visualise_zeta(nur_dupl100, nur_dupl500, nur_dupl1000, slices=slice(-20, -1, None))

# %%
print(lsprech100[lsprech100.wort=='fragen'])
sprech100[sprech100.wort=='fragen']
# Out:
#        wort      zeta
# 117  fragen -0.066436
#      wort      zeta
# 2  fragen -0.066436

# %% [markdown]
# #### Vorkommen einer gesamten Merkmalsliste

# %%
import os
path = '../results/zeta/pro_merkmal/'
filenames = []
merkmal = []
for f in os.listdir(path):
    filenames.append(path+f)
    merkmal.append(f)
combined = pd.concat( [ pd.read_csv(f, header=None) for f in filenames ] )
combined.columns = ['Zeta']
combined['merkmal'] = merkmal
# combined['merkmalkurz'] = ''
combined = combined.reset_index()
combined
# Out:
#     index      Zeta                                merkmal
# 0       0  0.000000      ohneDuplikate_1000pro_merkmal.csv
# 1       0 -0.181137        sprechmarker_100pro_merkmal.csv
# 2       0  0.000000         substantive_500pro_merkmal.csv
# 3       0  0.000000          adjektive_1000pro_merkmal.csv
# 4       0 -0.425235   anführungszeichen_100pro_merkmal.csv
# 5       0 -0.226775    sprechmarkerKurz_100pro_merkmal.csv
# 6       0  0.000144             sentiws_100pro_merkmal.csv
# 7       0  0.000000            pronomen_500pro_merkmal.csv
# 8       0  0.000000        substantive_1000pro_merkmal.csv
# 9       0  0.000000       sprechmarker_1000pro_merkmal.csv
# 10      0 -0.075430   sprechmarkerKurz_1000pro_merkmal.csv
# 11      0  0.000000       ohneDuplikate_100pro_merkmal.csv
# 12      0  0.000000             verben_1000pro_merkmal.csv
# 13      0  0.155383           plutchik_1000pro_merkmal.csv
# 14      0  0.000000        nurDuplikate_500pro_merkmal.csv
# 15      0  0.000000       ohneDuplikate_500pro_merkmal.csv
# 16      0  0.000000           adjektive_500pro_merkmal.csv
# 17      0  0.000000            sentiws_1000pro_merkmal.csv
# 18      0  0.000000            instanz_1000pro_merkmal.csv
# 19      0  0.130629            plutchik_100pro_merkmal.csv
# 20      0 -0.287956  anführungszeichen_1000pro_merkmal.csv
# 21      0  0.000000              verben_500pro_merkmal.csv
# 22      0  0.000000           adjektive_100pro_merkmal.csv
# 23      0  0.000000             instanz_100pro_merkmal.csv
# 24      0  0.000000        nurDuplikate_100pro_merkmal.csv
# 25      0  0.000000            emotion_1000pro_merkmal.csv
# 26      0  0.000000             instanz_500pro_merkmal.csv
# 27      0  0.000000           pronomen_1000pro_merkmal.csv
# 28      0  0.187444             emotion_100pro_merkmal.csv
# 29      0 -0.014767        sprechmarker_500pro_merkmal.csv
# 30      0  0.000000         substantive_100pro_merkmal.csv
# 31      0  0.248789            plutchik_500pro_merkmal.csv
# 32      0  0.000000            pronomen_100pro_merkmal.csv
# 33      0  0.000000             sentiws_500pro_merkmal.csv
# 34      0  0.024552             emotion_500pro_merkmal.csv
# 35      0  0.000000       nurDuplikate_1000pro_merkmal.csv
# 36      0 -0.202631    sprechmarkerKurz_500pro_merkmal.csv
# 37      0  0.000000              verben_100pro_merkmal.csv
# 38      0 -0.416474   anführungszeichen_500pro_merkmal.csv

# %%
def merkmal(df):
    df['Gattungsmerkmal'] = ''
    for i, row in df.iterrows():
#         df[i]['merkalkurz'] =  row['merkmal'].split('_')[0]
        df.loc[i,'Gattungsmerkmal'] = row['merkmal'].split('_')[0].capitalize()
    return df

# %%
merkmal100 = combined[combined['merkmal'].str.contains('100pr')]
merkmal100 = merkmal(merkmal100)
merkmal500 = combined[combined['merkmal'].str.contains('500')]
merkmal500 = merkmal(merkmal500)
merkmal1000 = combined[combined['merkmal'].str.contains('1000')]
merkmal1000 = merkmal(merkmal1000)
# Out:
# /home/teresa/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/teresa/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
fig= plt.figure(figsize=(25,10))
sns.barplot(x='Gattungsmerkmal', y='Zeta', data=merkmal100, color='g')
plt.savefig('../results/zeta/visualisierung/alle_merkmale100.png')

# %%
plutchik = pd.read_csv('../results/zeta/pro_wort/plutchik_100pro_wort.csv', header=None)
plutchik['merkmal']='Plutchik'
anf = pd.read_csv('../results/zeta/pro_wort/anführungszeichen_100pro_wort.csv', header=None)
anf['merkmal']='Anführungszeichen'
sprechmarker = pd.read_csv('../results/zeta/pro_wort/sprechmarkerKurz_100pro_wort.csv', header=None)
sprechmarker['merkmal']='SprechmarkerKurz'
sprechmarkerlang = pd.read_csv('../results/zeta/pro_wort/sprechmarker_100pro_wort.csv', header=None)
sprechmarkerlang['merkmal']='Sprechmarker'
emotion = pd.read_csv('../results/zeta/pro_wort/emotion_100pro_wort.csv', header=None)
emotion['merkmal']='Emotion'
stärkste_merkmale = pd.concat([plutchik, anf, sprechmarker, sprechmarkerlang, emotion])
stärkste_merkmale.columns = ['wort', 'zeta','merkmal']
fig= plt.figure(figsize=(15,10))
sns.boxplot(y='zeta',x='merkmal', data=stärkste_merkmale, color='b')
plt.savefig('../results/zeta/visualisierung/stärkste_merkmale100_boxplot.png')

# %% [markdown]
# #### kombiniere Merkmale

# %%
pos = pd.read_csv('../results/zeta/pro_wort/verben_500pro_wort.csv', header=None)
marker = pd.read_csv('../results/zeta/pro_wort/sprechmarker_500pro_wort.csv', header=None)
# marker2 = pd.read_csv('../results/zeta/pro_wort/emotion_500pro_wort.csv', header=None)
pos.columns = ['wort', 'Zeta']
pos = pos.sort_values(by='Zeta', ascending=False)
pos['Gattungsmerkmal'] = 'Verben'
for i, row in pos.iterrows():
    for m in marker[0]:
        if row['wort'] == m:
            pos.loc[i,'Gattungsmerkmal']='Sprechmarker'
#     for m in marker2[0]:
#         if row[0] == m:
#             pos.loc[i, 'Gattungsmerkmal'] = 'Emotionen'
pos
# Out:
#          wort      Zeta Gattungsmerkmal
# 74     singen  0.336617          Verben
# 432  rauschen  0.296917          Verben
# 12      leben  0.288375          Verben
# 49      ruhen  0.286334          Verben
# 113   klingen  0.282477          Verben
# ..        ...       ...             ...
# 702    währen -0.232523          Verben
# 43      legen -0.233016          Verben
# 33     setzen -0.251629          Verben
# 5      machen -0.321184          Verben
# 0       sagen -0.346035    Sprechmarker
#
# [1298 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(20,50))
sns.barplot(x='Zeta', y=pos.wort[:100], data=pos,hue='Gattungsmerkmal')
plt.title('Verben und Sprechmarker')
# plt.savefig('../results/zeta/visualisierung/verben+sprechmarker.png')
# Out:
# Text(0.5, 1.0, 'Verben und Sprechmarker')

# %% [markdown]
# #### MFW und Zeta

# %%
def mfw(path):
    ''' zählt Wordhäufigkeiten pro Segment '''
    stopword = open("de_stopwords.txt")
    stopwords = stopword.read()
    words = []
    t = open(path, 'r')
    f = t.read()
    stop = ' '.join([item for item in str(f).split() if item not in stopwords])
    c = Counter(stop.split())
    sort_vocab = {k: v for k, v in sorted(c.items(), key=lambda item: item[1],reverse=True)}
    words.append(list(sort_vocab.keys())[:100])
    return sort_vocab, words

# %%
lyrik_sort, lyrik_mfws = mfw('../corpus/corpora/corpora_gesamt/corpus_lyrik.txt')
epik_sort, epik_mfws = mfw('../corpus/corpora/corpora_gesamt/corpus_epik.txt')

# %%
import itertools
marker = pd.read_csv('../results/zeta/pro_wort/sprechmarker_500pro_wort.csv', header=None)
sort100 = dict(itertools.islice(sort.items(), 100))
sort100 = pd.DataFrame.from_dict(sort100, orient='index')
sort100['Wort']=sort100.index
sort100.columns = ['Frequency', 'Wort']
sort100['mfw'] = ' '
sort100['merkmal'] = ' '
for i, row in sort100.iterrows():
    for m in marker[0]:
        if row['Wort'] == m:
            sort100.loc[i,'mfw']='Sprechmarker'
            sort100.loc[i, 'merkmal']=m
sort100
# Out:
#         Frequency    Wort mfw merkmal
# in+die       6003  in+die
# zu+die       2578  zu+die
# herz         2526    herz
# an+die       1798  an+die
# nacht        1579   nacht
# ...           ...     ...  ..     ...
# sinn          356    sinn
# stumm         353   stumm
# weib          353    weib
# selig         352   selig
# ferne         350   ferne
#
# [100 rows x 4 columns]

# %%
fig= plt.figure(figsize=(25,10))
sns.barplot(x='Wort', y='Frequency', data=sort100,hue='mfw')
plt.xticks(np.arange(100),list(sort100['merkmal']), rotation=90)
plt.savefig('../results/zeta/visualisierung/merkmalposition_in_mfw/lyrik_sprechmarker_mfw.png')

# %% [markdown]
# ### Autorensignal?

# %%
def dic2df(dic):
    df = pd.DataFrame.from_dict(dic, orient='index')
    df = df.reset_index()
    df.columns=['wort', 'freq']
    return df

def compute_ranking(path, dic):
    marker = pd.read_csv(path, header=None)
    df = dic2df(dic)
    for i, row in df.iterrows():
        for m in marker[0]:
            if row['wort'] == m:
                print('Rankingstelle: ',i, '; ',row['wort'], ': ', row['freq'])
    return

# %%
text = pd.read_csv('../corpus/corpora/epik/epik.csv')
text.set_index('Unnamed: 0', inplace=True)
text.head(1)
# Out:
#                                                                       text  \
# Unnamed: 0
# epik_lemma_mann_tristan  tristan von thomas mann hier sein > einfried <...
#
#                                               ID Autor    Titel
# Unnamed: 0
# epik_lemma_mann_tristan  epik_lemma_mann_tristan  mann  tristan

# %%
l = 0
d={}
for i, row in text.iterrows():
    l+= len(row.text.split())
    d[i] = len(row.text.split())
print({k: v for k, v in sorted(d.items(), key=lambda item: item[1],reverse=True)})
print(l)
# Out:
# {'epik_lemma_may_wuste': 160445, 'epik_lemma_keller_seldywla1': 89249, 'epik_lemma_heiberg_frau': 61285, 'epik_lemma_brentano_rosenkranz': 56032, 'epik_lemma_achleitner_bergrichters': 48137, 'epik_lemma_wassermann_vierzig': 42857, 'epik_lemma_arnim_isabella': 40402, 'epik_lemma_bonsels_maja': 38535, 'epik_lemma_spyri_heidi1': 38428, 'epik_lemma_gerstacker_reise': 38220, 'epik_lemma_fontane_birnbaum': 34418, 'epik_lemma_schnitzler_tanzerin': 34302, 'epik_lemma_lewald_clementine': 34090, 'epik_lemma_falke_durchschnitt': 33981, 'epik_lemma_goethe_faust1': 30927, 'epik_lemma_hoffmann_topf': 29859, 'epik_lemma_hesse_knulp': 26793, 'epik_lemma_sapper_kriegsbuchlein': 26092, 'epik_lemma_meyer_richterin': 23972, 'epik_lemma_fischer_gustavsverirrungen': 20466, 'epik_lemma_kafka_verwandlung': 19419, 'epik_lemma_mann_tristan': 14525}
# 942434

# %%
may_sort, may_mfw = mfw('../corpus/corpora/epik/epik_lemma/epik_lemma_may_wuste.txt')
may_sort
# Out:
# {'@card@': 455,
#  'in+die': 408,
#  'scheik': 342,
#  'halef': 331,
#  'fragen': 314,
#  'zu+die': 311,
#  'pferd': 236,
#  'hand': 235,
#  'an+die': 232,
#  'stehen': 227,
#  'allah': 226,
#  'halten': 209,
#  'sihdi': 205,
#  'kennen': 202,
#  'liegen': 194,
#  'abu': 179,
#  'bleiben': 179,
#  'finden': 155,
#  'reiten': 147,
#  'antworten': 146,
#  'stamm': 146,
#  'tragen': 140,
#  'hadschi': 139,
#  'treten': 139,
#  'befinden': 138,
#  'gehören': 138,
#  'wasser': 133,
#  'auge': 132,
#  'effendi': 124,
#  'von+die': 121,
#  'tier': 121,
#  'erheben': 120,
#  'euer': 119,
#  'leute': 119,
#  'nennen': 117,
#  'freund': 116,
#  'feind': 116,
#  'weib': 115,
#  'bemerken': 113,
#  'zelt': 111,
#  'glauben': 110,
#  'land': 109,
#  'folgen': 107,
#  'name': 107,
#  'führen': 106,
#  'araber': 104,
#  'töten': 101,
#  'ziehen': 99,
#  'haddedihn': 99,
#  'sofort': 98,
#  'erhalten': 98,
#  'mohammed': 97,
#  'diener': 95,
#  'rufen': 95,
#  'omar': 93,
#  'kamel': 93,
#  'waffe': 93,
#  'mekka': 92,
#  'vater': 91,
#  'emir': 91,
#  'heißen': 89,
#  'brauchen': 87,
#  'legen': 87,
#  'verstehen': 87,
#  'erzählen': 86,
#  'erreichen': 83,
#  'zeigen': 82,
#  'pascha': 82,
#  'denken': 80,
#  'heilig': 79,
#  'giebt': 79,
#  'seite': 77,
#  'sitzen': 76,
#  'fahren': 76,
#  'wenden': 75,
#  'krieger': 75,
#  'fest': 74,
#  'steigen': 74,
#  'scheinen': 73,
#  'verlassen': 73,
#  'fuß': 71,
#  'alt': 71,
#  'wohin': 71,
#  'kopf': 71,
#  'sicher': 71,
#  'geschehen': 71,
#  'christ': 70,
#  'setzen': 69,
#  'schnell': 69,
#  'nieder': 69,
#  'nemsi': 69,
#  'schiff': 68,
#  'stadt': 67,
#  'abrahim': 66,
#  'öffnen': 65,
#  'holen': 64,
#  'dennoch': 63,
#  'schießen': 63,
#  'türke': 63,
#  'gefangene': 63,
#  'suchen': 62,
#  'wohnen': 62,
#  'erkennen': 62,
#  'boden': 61,
#  'erlauben': 61,
#  'mund': 61,
#  'seďf': 60,
#  'emin': 60,
#  'bekommen': 59,
#  'schritt': 59,
#  'sir': 59,
#  'stimme': 58,
#  'blick': 58,
#  'augenblick': 57,
#  'gesicht': 57,
#  'erfahren': 57,
#  'ufer': 57,
#  'lager': 57,
#  'dschesidi': 56,
#  'wüste': 55,
#  'weise': 55,
#  '#': 54,
#  'letzt': 54,
#  'bei+die': 54,
#  'werfen': 54,
#  'jedenfalls': 53,
#  'hammed': 53,
#  'erscheinen': 52,
#  'beginnen': 52,
#  'warten': 52,
#  'nacht': 52,
#  'that': 52,
#  'tod': 51,
#  'genau': 51,
#  'reiter': 51,
#  'glaube': 50,
#  'stelle': 50,
#  'stunde': 50,
#  'schammar': 50,
#  'springen': 49,
#  'mehrere': 49,
#  'schlafen': 49,
#  'führer': 49,
#  'sprache': 49,
#  'hinaus': 49,
#  'empor': 48,
#  'kind': 48,
#  'herd|herde': 48,
#  'bitten': 48,
#  'herz': 48,
#  'senden': 48,
#  'erwarten': 47,
#  'bestehen': 47,
#  'fürchten': 47,
#  'mossul': 47,
#  'schön': 46,
#  'sterben': 46,
#  'tief': 46,
#  'tapfer': 46,
#  'verlieren': 46,
#  'gelingen': 46,
#  'bezahlen': 46,
#  'mamur': 46,
#  'giaur': 45,
#  'grad': 45,
#  'wagen': 45,
#  'sogar': 45,
#  'vollständig': 44,
#  'arm': 44,
#  'nähe': 44,
#  'treffen': 44,
#  'links': 43,
#  'ali': 43,
#  'fallen': 43,
#  'helfen': 43,
#  'frage': 43,
#  'seele': 43,
#  'ateďbeh': 43,
#  'lindsay': 43,
#  'merken': 42,
#  'rechts': 42,
#  'blicken': 42,
#  'engländer': 42,
#  'platz': 42,
#  'befehlen': 42,
#  'malek': 42,
#  'fassen': 41,
#  'höhe': 41,
#  'fluss': 41,
#  'schlagen': 41,
#  'löwe': 41,
#  'ungläubige': 40,
#  'verschwinden': 40,
#  'jung': 40,
#  'vorher': 40,
#  'prophet': 40,
#  'lesen': 40,
#  'laut': 40,
#  'kehren': 40,
#  'kara': 40,
#  'abend': 40,
#  'dschidda': 40,
#  'besitzen': 39,
#  'trinken': 39,
#  'stein': 39,
#  'niemals': 39,
#  'gethan': 39,
#  'gewiss': 39,
#  'meer': 39,
#  'messer': 39,
#  'zurückkehren': 39,
#  'verlangen': 39,
#  'gebieten': 39,
#  'draußen': 39,
#  'hinein': 38,
#  'voll': 38,
#  'lernen': 38,
#  'wadi': 38,
#  'kugel': 38,
#  'wekil': 38,
#  'insel': 38,
#  'zem': 38,
#  'reichen': 37,
#  'versprechen': 37,
#  'schweigen': 37,
#  'stellen': 37,
#  'tot': 37,
#  'sonne': 37,
#  'miene': 37,
#  'thal': 37,
#  'treiben': 37,
#  'kampf': 37,
#  'gefährlich': 37,
#  'danken': 37,
#  'beinahe': 37,
#  'binden': 37,
#  'gefangen': 37,
#  'obeďde': 37,
#  'fühlen': 36,
#  'bein': 36,
#  'hängen': 36,
#  'beten': 36,
#  'willkommen': 36,
#  'gehören|hören': 36,
#  'tigris': 35,
#  'fast': 35,
#  'teufel': 35,
#  'dienen': 35,
#  'buch': 35,
#  'entgegen': 35,
#  'hundert': 35,
#  'stoßen': 35,
#  'schließen': 35,
#  'mörder': 35,
#  'nämlich': 35,
#  'richten': 35,
#  'geld': 35,
#  'bilden': 35,
#  'obgleich': 35,
#  'tochter': 35,
#  'schreiben': 34,
#  'ibn': 34,
#  'reich': 34,
#  'abenteuer': 34,
#  'thut': 34,
#  'fremd': 34,
#  'stark': 34,
#  'türkisch': 34,
#  'gast': 34,
#  'thür': 34,
#  'dschebel': 33,
#  'schott': 33,
#  'scharf': 33,
#  'wohnung': 33,
#  'einzig': 33,
#  'vorwärts': 33,
#  'breit': 33,
#  'greifen': 33,
#  'eilen': 33,
#  'aaleďkum': 33,
#  'hinab': 33,
#  'berühmt': 33,
#  'verbergen': 33,
#  'treffen|triefen': 33,
#  'behalten': 33,
#  'tausend': 33,
#  'schreiten': 33,
#  'entfernen': 33,
#  'boot': 33,
#  'fahrzeug': 33,
#  'isla': 33,
#  'adi': 33,
#  'stets': 32,
#  'bewegung': 32,
#  'gewöhnlich': 32,
#  'zeichen': 32,
#  'antwort': 32,
#  'gedanke': 32,
#  'ruhig': 32,
#  'mauer': 32,
#  'sobald': 31,
#  'nase': 31,
#  'stecken': 31,
#  'himmel': 31,
#  'erblicken': 31,
#  'reißen': 31,
#  'brechen': 31,
#  'arabisch': 31,
#  'betreten': 31,
#  'besuchen': 31,
#  'baschi': 31,
#  'ruine': 31,
#  'ebene': 30,
#  'vermuten': 30,
#  'volk': 30,
#  'flinte': 30,
#  'hart': 30,
#  'blut': 30,
#  'minute': 30,
#  'gläubige': 30,
#  'licht': 30,
#  'drüben': 30,
#  'begegnen': 29,
#  'retten': 29,
#  'schwer': 29,
#  'stunde|stunden': 29,
#  'gewehr': 29,
#  'langsam': 29,
#  'beduine': 29,
#  'woher': 29,
#  'hinüber': 29,
#  'hof': 29,
#  'senitza': 29,
#  'amadijah': 29,
#  'grund': 28,
#  'geist': 28,
#  'thue': 28,
#  'fremde': 28,
#  'verraten': 28,
#  'entkommen': 28,
#  'bruder': 28,
#  'vermögen': 28,
#  'schuss': 28,
#  'hilfe': 28,
#  'herab': 28,
#  'agha': 28,
#  'ägypter': 28,
#  'gegend': 28,
#  'deradsch': 28,
#  'teufelsanbeter': 27,
#  'zwingen': 27,
#  'vergehen': 27,
#  'hervor': 27,
#  'kleid': 27,
#  'herum': 27,
#  'lauten': 27,
#  'wahrheit': 27,
#  'richtung': 27,
#  'ton': 27,
#  'fangen': 27,
#  'grab': 27,
#  'herbei': 27,
#  'grüßen': 27,
#  'notwendig': 27,
#  'mitnehmen': 27,
#  'bord': 27,
#  'dschowari': 27,
#  'emini': 27,
#  'arm|arme': 26,
#  'moslem': 26,
#  'pilger': 26,
#  'glücklich': 26,
#  'unmöglich': 26,
#  'heraus': 26,
#  'berg': 26,
#  'sallam': 26,
#  'rücken': 26,
#  'fliehen': 26,
#  'großherrn': 26,
#  'held': 26,
#  'sandal': 26,
#  'räuber': 26,
#  'buluk': 26,
#  'kapitel': 25,
#  'recht|rechte': 25,
#  'versuchen': 25,
#  'klug': 25,
#  'kuran': 25,
#  'ohr': 25,
#  'gebet': 25,
#  'krank': 25,
#  'spur': 25,
#  'anblick': 25,
#  'luft': 25,
#  'sattel': 25,
#  'schutz': 25,
#  'scheďtan': 25,
#  'mächtig': 25,
#  'ziemlich': 25,
#  'gefahr': 25,
#  'sadek': 25,
#  'kämpfen': 25,
#  'ruhe': 25,
#  'fertig': 25,
#  'soldat': 25,
#  'bewachen': 25,
#  'außerordentlich': 25,
#  'heilige': 25,
#  'hanneh': 25,
#  'lachen': 24,
#  'böse': 24,
#  'aufnehmen': 24,
#  'mädchen': 24,
#  'abul': 24,
#  'eigentlich': 24,
#  'begleiter': 24,
#  'ergreifen': 24,
#  'finger': 24,
#  'gelten': 24,
#  'nötig': 24,
#  'büchse': 24,
#  'vorhin': 24,
#  'halt': 24,
#  'gürtel': 24,
#  'verzeihen': 24,
#  'recht|rechts': 24,
#  'raum': 24,
#  'bloß': 24,
#  'vernehmen': 24,
#  'leise': 24,
#  'begleiten': 24,
#  'ernst': 23,
#  'hund': 23,
#  'turban': 23,
#  'lauf': 23,
#  'heben': 23,
#  'verfolgen': 23,
#  'gelangen': 23,
#  'vorüber': 23,
#  'schaffen': 23,
#  'einzeln': 23,
#  'preis': 23,
#  'pfeife': 23,
#  'truppe': 23,
#  'geheimnis': 23,
#  'erfüllen': 23,
#  'kranke': 23,
#  'bote': 23,
#  'rauben': 23,
#  'verderben': 22,
#  'mut': 22,
#  'untersuchen': 22,
#  'segnen': 22,
#  'wunder': 22,
#  'bieten': 22,
#  'fehlen': 22,
#  'gestalt': 22,
#  'drehen': 22,
#  'deuten': 22,
#  'geschenk': 22,
#  'gieb': 22,
#  'schicken': 22,
#  'handeln': 22,
#  'gestern': 22,
#  'säbel': 22,
#  'thale': 22,
#  'floß': 22,
#  'mutessarif': 22,
#  'feuer': 21,
#  'meinig': 21,
#  'abbas': 21,
#  'ägypten': 21,
#  'sand': 21,
#  'betrachten': 21,
#  'ungefähr': 21,
#  'franke': 21,
#  'mitten': 21,
#  'aufmerksam': 21,
#  'dattel': 21,
#  'laufen': 21,
#  'bewohner': 21,
#  'zahlreich': 21,
#  'dunkel': 21,
#  'erraten': 21,
#  'gewalt': 21,
#  'befestigen': 21,
#  'häuptling': 21,
#  'eintreten': 21,
#  'schenken': 21,
#  'bestimmen': 21,
#  'absicht': 21,
#  'dahabďe': 21,
#  'sambuk': 21,
#  'dscheheďne': 21,
#  'zahn': 21,
#  'flasche': 21,
#  'gouverneur': 21,
#  'fowling': 21,
#  'rappen': 21,
#  'baadri': 21,
#  'ahnen': 20,
#  'bu': 20,
#  'vergessen': 20,
#  'bart': 20,
#  'schmal': 20,
#  'nachher': 20,
#  'wein': 20,
#  'dawud': 20,
#  'mahl': 20,
#  'hals': 20,
#  'felsen': 20,
#  'tasche': 20,
#  'enthalten': 20,
#  'fall': 20,
#  'jagen': 20,
#  'fliegen': 20,
#  'teilen': 20,
#  'gefährt|gefährte': 20,
#  'gefallen': 20,
#  'süden': 20,
#  'strecke': 20,
#  'pflegen': 20,
#  'verbinden': 20,
#  'heran': 20,
#  'beleidigen': 20,
#  'hieb': 20,
#  'schwarz': 20,
#  'befehl': 20,
#  'blume': 20,
#  'hierher': 20,
#  'reďs': 20,
#  'deck': 20,
#  'überfallen': 20,
#  'baum': 19,
#  'brunnen': 19,
#  'ruhen': 19,
#  'ansehen': 19,
#  'gossarah': 19,
#  'kleidung': 19,
#  'gnädig': 19,
#  'kostbar': 19,
#  'fünfzig': 19,
#  'versammeln': 19,
#  'hindurch': 19,
#  'hengst': 19,
#  'drücken': 19,
#  'heimat': 19,
#  'schaden': 19,
#  'hekim': 19,
#  'umstand': 19,
#  'hassan': 19,
#  'kapitän': 19,
#  'singen': 19,
#  'dorf': 19,
#  'verfolger': 19,
#  'nemtsche': 19,
#  'kurdisch': 19,
#  'kurde': 19,
#  'bekehren': 18,
#  'freundlich': 18,
#  'einst': 18,
#  'schwören': 18,
#  'stolz': 18,
#  'thore': 18,
#  'leiden': 18,
#  'ruf': 18,
#  'tote': 18,
#  'erschrecken': 18,
#  'lügen': 18,
#  'gehorchen': 18,
#  'klingen': 18,
#  'leider': 18,
#  'verdienen': 18,
#  'unterbrechen': 18,
#  'krachen': 18,
#  'angesicht': 18,
#  'stürzen': 18,
#  'erschallen': 18,
#  'dicht': 18,
#  'arzt': 18,
#  'piaster': 18,
#  'kosten': 18,
#  'fordern': 18,
#  'wünschen': 18,
#  'thüre': 18,
#  'hinauf': 18,
#  'berg|bergen': 18,
#  'maschallah': 18,
#  'begrüßen': 18,
#  'khan': 18,
#  'david': 18,
#  'ankommen': 17,
#  'kbilli': 17,
#  'eigentümlich': 17,
#  'dünn': 17,
#  'fürchterlich': 17,
#  'zurückbleiben': 17,
#  'reise': 17,
#  'thust': 17,
#  'gering': 17,
#  'wert': 17,
#  'plötzlich': 17,
#  'lippe': 17,
#  'aussehen': 17,
#  'zufrieden': 17,
#  'vorsichtig': 17,
#  'spitze': 17,
#  'freuen': 17,
#  'hütte': 17,
#  'gelegenheit': 17,
#  'zimmer': 17,
#  'besiegen': 17,
#  'padischah': 17,
#  'zählen': 17,
#  'dolch': 17,
#  'reisen': 17,
#  'angreifen': 17,
#  'haut': 17,
#  'bagdad': 17,
#  '#yes': 17,
#  'pir': 17,
#  'beobachten': 16,
#  'thaten': 16,
#  'uëlad': 16,
#  'wild': 16,
#  'paradies': 16,
#  'sorge': 16,
#  'kaffee': 16,
#  'lehren': 16,
#  'kaaba': 16,
#  'oase': 16,
#  'dorthin': 16,
#  'ecke': 16,
#  'still': 16,
#  'kerihm': 16,
#  'brust': 16,
#  'bitte': 16,
#  'vielmehr': 16,
#  'weste|westen': 16,
#  'nahe': 16,
#  'verschieden': 16,
#  'kaufen': 16,
#  'schlimm': 16,
#  'schatten': 16,
#  'punkt': 16,
#  'falsch': 16,
#  'überzeugung': 16,
#  'aussprechen': 16,
#  'krankheit': 16,
#  'verhältnis': 16,
#  'schnelligkeit': 16,
#  'körper': 16,
#  'dauern': 16,
#  'glück': 16,
#  'überall': 16,
#  'teppich': 16,
#  'rauchen': 16,
#  'sogleich': 16,
#  'beziehung': 16,
#  'packen': 16,
#  'haar': 16,
#  'entfliehen': 16,
#  'gewand': 16,
#  'verstecken': 16,
#  'anlegen': 16,
#  'verbieten': 16,
#  'geschichte': 16,
#  'zeihen|ziehen': 16,
#  'heer': 16,
#  'entdecken': 16,
#  'tribut': 16,
#  'arnauten': 16,
#  'treu': 15,
#  'arbeit': 15,
#  'überzeugt': 15,
#  'kris': 15,
#  'fetnassa': 15,
#  'mühe': 15,
#  'stirn': 15,
#  'mutter': 15,
#  'spur|spuren': 15,
#  'knieen': 15,
#  'gegenstand': 15,
#  'berühren': 15,
#  'akbar': 15,
#  'heiß': 15,
#  'langen': 15,
#  'wange': 15,
#  'nebst': 15,
#  'seinige': 15,
#  'augenblicklich': 15,
#  'sicherheit': 15,
#  'entfernt': 15,
#  'decke': 15,
#  'meist': 15,
#  'zelt|zelten': 15,
#  'leuchten': 15,
#  'fremdling': 15,
#  'lenken': 15,
#  'vorhanden': 15,
#  'herrschen': 15,
#  'reihe': 15,
#  'pass': 15,
#  'nassr': 15,
#  'orient': 15,
#  'sitte': 15,
#  'horizont': 15,
#  'wand': 15,
#  'eingang': 15,
#  'strom': 15,
#  'segel': 15,
#  'herrlich': 15,
#  'verschließen': 15,
#  'dieb': 15,
#  'straße': 15,
#  'soeben': 15,
#  'bereiten': 15,
#  'bedeutend': 15,
#  'albani': 15,
#  'botschaft': 15,
#  'lanze': 15,
#  'schaf': 15,
#  'höhle': 15,
#  'vereinigen': 15,
#  'zedar': 15,
#  'ifra': 15,
#  'seddada': 14,
#  'unterhaltung': 14,
#  'abteilung': 14,
#  'schütteln': 14,
#  'begeben': 14,
#  'weshalb': 14,
#  'lächeln': 14,
#  'weisheit': 14,
#  'rasch': 14,
#  'loch': 14,
#  'arab': 14,
#  'prächtig': 14,
#  'papier': 14,
#  'person': 14,
#  'irren': 14,
#  'beschließen': 14,
#  'vertrauen': 14,
#  'osten': 14,
#  'vermag': 14,
#  'überraschung': 14,
#  'konsul': 14,
#  'giölgeda': 14,
#  'gebiet': 14,
#  'pfad': 14,
#  'mindeste': 14,
#  'dick': 14,
#  'voran': 14,
#  'gnade': 14,
#  'schrei': 14,
#  'hinten': 14,
#  'kraft': 14,
#  'weile': 14,
#  'schuld': 14,
#  'rächen': 14,
#  'alte': 14,
#  'fällen': 14,
#  'edel': 14,
#  'freundschaft': 14,
#  'erschießen': 14,
#  'gebrauch': 14,
#  'finster': 14,
#  'höflich': 14,
#  'müde': 14,
#  'hamdulillah': 14,
#  'lebendig': 14,
#  'bedenken': 14,
#  'pistole': 14,
#  'gesund': 14,
#  'steuer': 14,
#  'maflei': 14,
#  'lösen': 14,
#  'herüber': 14,
#  'religion': 14,
#  'pah': 14,
#  'offizier': 14,
#  'posten': 14,
#  'bulls': 14,
#  'huli': 14,
#  'wald': 14,
#  'priester': 14,
#  'hassen': 13,
#  'dscherid': 13,
#  'versuch': 13,
#  'kitab': 13,
#  'anbeten': 13,
#  'erstaunen': 13,
#  'blutrache': 13,
#  'deutsche': 13,
#  'entfernung': 13,
#  'bedecken': 13,
#  'hinzu': 13,
#  'sünde': 13,
#  'richter': 13,
#  'revolver': 13,
#  'förmlich': 13,
#  'überlegen': 13,
#  'besteigen': 13,
#  'stören': 13,
#  'erfolg': 13,
#  'stelle|stellen': 13,
#  'wacker': 13,
#  'abendland': 13,
#  'salz': 13,
#  'ertönen': 13,
#  'schlag': 13,
#  'einfallen': 13,
#  'gewinnen': 13,
#  'eher': 13,
#  'statthalter': 13,
#  'bastonnade': 13,
#  'bekannte': 13,
#  'gleichen': 13,
#  'mustern': 13,
#  'funkeln': 13,
#  'laden': 13,
#  'befreien': 13,
#  'norden': 13,
#  'peitsche': 13,
#  'tropfen': 13,
#  'speise': 13,
#  'geräusch': 13,
#  'garten': 13,
#  'reďsahn': 13,
#  'deutsch': 13,
#  'innere': 13,
#  'zielen': 13,
#  'schrift': 13,
#  'khawassen': 13,
#  'anführer': 13,
#  'brief': 13,
#  'menge': 13,
#  'graben': 13,
#  'grieche': 13,
#  'schwanz': 13,
#  'zuweilen': 12,
#  'stute': 12,
#  'fließen': 12,
#  'rand': 12,
#  'dreißig': 12,
#  'überzeugen': 12,
#  'mittag': 12,
#  'absteigen': 12,
#  'fern': 12,
#  'besitzer': 12,
#  'biegen': 12,
#  'seitwärts': 12,
#  'schurke': 12,
#  'stimmen': 12,
#  'beute': 12,
#  'beni': 12,
#  'geschäft': 12,
#  'verkaufen': 12,
#  'erklären': 12,
#  'buche': 12,
#  'rache': 12,
#  'sorgen': 12,
#  'eindruck': 12,
#  'schlaf': 12,
#  'hälfte': 12,
#  'schwimmen': 12,
#  'öffnung': 12,
#  'lage': 12,
#  'versehen': 12,
#  'verwunden': 12,
#  'moschee': 12,
#  'selamlük': 12,
#  'bewohnen': 12,
#  'woche': 12,
#  'belieben': 12,
#  'flut|fluten': 12,
#  'gebäude': 12,
#  'empfangen': 12,
#  'gastfreundschaft': 12,
#  'drohen': 12,
#  'kanal': 12,
#  'beenden': 12,
#  'bild': 12,
#  'fahrt': 12,
#  'stern': 12,
#  'gebrauchen': 12,
#  'zweck': 12,
#  'schreien': 12,
#  'beisammen': 12,
#  'beweisen': 12,
#  'vornehm': 12,
#  'steil': 12,
#  'englisch': 12,
#  'küssen': 12,
#  'plan': 12,
#  'kunde': 12,
#  'kamek': 12,
#  'ewig': 11,
#  'unternehmen': 11,
#  'figur': 11,
#  'barte': 11,
#  'vorn': 11,
#  'wahrhaftig': 11,
#  'bestrafen': 11,
#  'jungfrau': 11,
#  'unwillkürlich': 11,
#  'einfach': 11,
#  'hedjihn': 11,
#  'hinunter': 11,
#  'kette': 11,
#  'niederschießen': 11,
#  'amasat': 11,
#  'strecken': 11,
#  'gesetz': 11,
#  'zusammentreffen': 11,
#  'beschäftigen': 11,
#  'erwachen': 11,
#  'padischahnün': 11,
#  'berichten': 11,
#  'höchst': 11,
#  'grün': 11,
#  'see': 11,
#  'fahren|führen': 11,
#  'unterwegs': 11,
#  'atem': 11,
#  'lagern': 11,
#  'tabak': 11,
#  'iz': 11,
#  'fünfzehn': 11,
#  'wergi': 11,
#  'nachts': 11,
#  'begriff': 11,
#  'rat': 11,
#  'rennen': 11,
#  'eingange': 11,
#  'horchen': 11,
#  'beschützen': 11,
#  'füllen': 11,
#  'ungeheuer': 11,
#  'schieben': 11,
#  'schuh': 11,
#  'hell': 11,
#  'kalt': 11,
#  'frieden': 11,
#  'winken': 11,
#  'verteidigen': 11,
#  'bewaffnen': 11,
#  'warnen': 11,
#  'täuschen': 11,
#  'kahn': 11,
#  'arbeiten': 11,
#  'umgeben': 11,
#  'unterdessen': 11,
#  'ruder': 11,
#  'kajüte': 11,
#  'eng': 11,
#  'vermeiden': 11,
#  'bemannung': 11,
#  'medina': 11,
#  'derwisch': 11,
#  'säbels': 11,
#  'lösegeld': 11,
#  'dringen': 11,
#  'schmerz': 11,
#  'abermals': 11,
#  'wächter': 11,
#  'dolmetscher': 11,
#  'begleitung': 11,
#  'weideplatz': 11,
#  'rappe': 11,
#  'eslah': 11,
#  'inhalt': 10,
#  'gericht': 10,
#  'sieg': 10,
#  'behandeln': 10,
#  'äußer': 10,
#  'köstlich': 10,
#  'tarfaui': 10,
#  'hölle': 10,
#  'kräftig': 10,
#  'bach': 10,
#  'wachsen': 10,
#  'bewegen': 10,
#  'sechzig': 10,
#  'zunge': 10,
#  'pilger|pilgern': 10,
#  'eingraben': 10,
#  'leer': 10,
#  'flucht': 10,
#  'leiche': 10,
#  'israel': 10,
#  'rein': 10,
#  'hitze': 10,
#  'gespräch': 10,
#  'bir': 10,
#  'bauen': 10,
#  'auszeichnen': 10,
#  'griff': 10,
#  'giebst': 10,
#  'jemals': 10,
#  ...}

# %%
path = '../results/zeta/pro_wort/sprechmarker_500pro_wort.csv'
compute_ranking(path, may_sort)
# Out:
# Rankingstelle:  10 ;  rufen :  7
# Rankingstelle:  98 ;  beten :  2
# Rankingstelle:  133 ;  nennen :  2
# Rankingstelle:  167 ;  schluchzen :  2
# Rankingstelle:  182 ;  vernehmen :  2
# Rankingstelle:  300 ;  verkünden :  1
# Rankingstelle:  348 ;  verlangen :  1
# Rankingstelle:  395 ;  flüstern :  1
# Rankingstelle:  428 ;  beschwören :  1
# Rankingstelle:  484 ;  schreien :  1
# Rankingstelle:  571 ;  erfinden :  1

# %% [markdown]
# Lyrik

# %%
lyrik = pd.read_csv('../corpus/corpora/lyrik/lyrik.csv')
lyrik.set_index('ID', inplace=True)
lyrik.head(1)
# Out:
#            Unnamed: 0          Titel  \
# ID
# l00100002           0  Am Geburtstag
#
#                                                        Autor  Strophen  Verse  \
# ID
# l00100002  Avenarius, Ferdinand [alt. Avernarius, Ferdina...         1     18
#
#                                                   Anthologie  Jahr  \
# ID
# l00100002  Die Perlenschnur. Eine Anthologie moderner Lyr...  1898
#
#                      Hrsg       ID.1   Epoche  ...  bert_Ivis_sonett_2  \
# ID                                             ...
# l00100002  Gemmel, Ludwig  l00100002  Moderne  ...                -3.0
#
#            bert_Ivis_sonett_sup_1  bert_Ivis_sonett_sup_2  bert_Ivis_1  \
# ID
# l00100002                     0.0                     0.0    -5.380342
#
#           bert_Ivis_2  bert_Ivis_sup_1  bert_Ivis_sup_2  dtm_Ivis_sup_1  \
# ID
# l00100002   -0.808883        -0.117857        -3.909007        1.401555
#
#            dtm_Ivis_sup_2                                               text
# ID
# l00100002       -0.390788  neben ich plauderts in+die glitzernd quell aus...
#
# [1 rows x 28 columns]

# %% [markdown]
# längster Text

# %%
l = 0
d={}
for i, row in lyrik.iterrows():
    l+= len(row.text.split())
    d[i] = len(row.text.split())
print({k: v for k, v in sorted(d.items(), key=lambda item: item[1],reverse=True)})
print(l)
# Out:
# {'l00180187': 2297, 'l0020172': 2100, 'l00180129': 2096, 'l0010484': 2029, 'l00160056': 1872, 'l0010238': 1752, 'l00160005': 1723, 'l0020066': 1510, 'l00180220': 1485, 'l0020154': 1470, 'l0060039': 1405, 'l0010407': 1368, 'l00110116': 1313, 'l0020039': 1299, 'l00180160': 1280, 'l0010020': 1207, 'l00180114': 1195, 'l00180161': 1158, 'l00180056': 1129, 'l0020050': 1075, 'l0030477': 1073, 'l00210141': 1048, 'l00160073': 1007, 'l00180046': 997, 'l0020114': 979, 'l00100046': 972, 'l0090246': 964, 'l0010483': 909, 'l00210083': 904, 'l0040498': 882, 'l0020125': 866, 'l0060076': 862, 'l00100147': 826, 'l0020190': 810, 'l00110641': 792, 'l0060079': 776, 'l00180100': 775, 'l00100132': 774, 'l00100133': 773, 'l00210051': 767, 'l00160068': 765, 'l00180120': 759, 'l00210032': 753, 'l0010482': 749, 'l0010444': 746, 'l00210085': 738, 'l0040054': 737, 'l00160078': 728, 'l00210086': 721, 'l00100094': 719, 'l00210040': 711, 'l00210111': 706, 'l00110246': 704, 'l00180227': 697, 'l0030103': 691, 'l00110266': 690, 'l00210115': 690, 'l00160036': 689, 'l00180062': 689, 'l00160054': 686, 'l0020124': 686, 'l0020052': 684, 'l00180156': 676, 'l00210079': 676, 'l00180116': 663, 'l00180047': 657, 'l00160051': 654, 'l0020110': 650, 'l0010339': 645, 'l0040063': 645, 'l0010043': 641, 'l0020055': 639, 'l00210106': 612, 'l0030488': 602, 'l00100098': 599, 'l00180225': 598, 'l00110180': 597, 'l0010275': 596, 'l0090270': 594, 'l0040497': 587, 'l0030473': 586, 'l00210055': 582, 'l0060053': 580, 'l0020123': 579, 'l0060071': 579, 'l00210058': 578, 'l00210151': 576, 'l0030
#
#                      Hrsg       ID.1   Epoche  ...  bert_Ivis_sonett_2  \
# ID                                             ...
# l00180187  Arent, Wilhelm  l00180187  Moderne  ...                -3.0
#
#            bert_Ivis_sonett_sup_1  bert_Ivis_sonett_sup_2  bert_Ivis_1  \
# ID
# l00180187                     0.0                     0.0    -8.860898
#
#           bert_Ivis_2  bert_Ivis_sup_1  bert_Ivis_sup_2  dtm_Ivis_sup_1  \
# ID
# l00180187    0.693855        -3.070181        -9.005007       -0.411825
#
#            dtm_Ivis_sup_2                                               text
# ID
# l00180187        0.646708  zu hersfeld in+die kloster die prior sprechen ...
#
# [1 rows x 28 columns]

# %%
wildenbruch_sort,wildenbruch_mfw = mfw('../corpus/corpora/lyrik/lyrik_lemma/lyrik_lemma_l00180187.txt')
wildenbruch_sort
# Out:
# {'medardus': 20,
#  '\x91': 16,
#  'zu+die': 15,
#  'in+die': 14,
#  'auge': 12,
#  'bruder': 11,
#  'singen': 9,
#  'lippe': 8,
#  'prior': 7,
#  'mönch': 7,
#  'rufen': 7,
#  'gesang': 7,
#  'voll': 7,
#  'herz': 7,
#  'süß': 7,
#  'nacht': 7,
#  'heilig': 6,
#  'von+die': 6,
#  'ohr': 6,
#  'hand': 6,
#  'liegen': 6,
#  'wild': 6,
#  'lied': 6,
#  'tief': 6,
#  'weib': 6,
#  'sünde': 5,
#  'beichtiger': 5,
#  'stunde': 5,
#  'dumpf': 5,
#  'ferne': 5,
#  'stimme': 5,
#  'teufel': 5,
#  'lager': 5,
#  'buße': 5,
#  'fackel': 5,
#  'sterben': 5,
#  'wald': 5,
#  'kloster': 4,
#  'hinein': 4,
#  'schlagen': 4,
#  'zelle': 4,
#  'klagend': 4,
#  'neigen': 4,
#  'sündig': 4,
#  'schallen': 4,
#  'betend': 4,
#  'schweigen': 4,
#  'antlitz': 4,
#  'arm|arme': 4,
#  'heiß': 4,
#  'feuer': 4,
#  'gesicht': 4,
#  'weinen': 4,
#  'flamme': 4,
#  'ewig': 4,
#  'großmutter': 4,
#  'plötzlich': 4,
#  'alt': 3,
#  'fünfzig': 3,
#  'haar': 3,
#  'treten': 3,
#  'schwelle': 3,
#  'schreiten': 3,
#  'schauen': 3,
#  'thaten': 3,
#  'beugen': 3,
#  'leise': 3,
#  'heben': 3,
#  'lauschen': 3,
#  'siehe': 3,
#  'satan': 3,
#  'schwingen': 3,
#  'blicken': 3,
#  'hexe': 3,
#  'wonne': 3,
#  'busen': 3,
#  'lesen': 3,
#  'angst': 3,
#  'thür': 3,
#  'verderben': 3,
#  'stein': 3,
#  'herab': 3,
#  'hängen': 3,
#  'umfangen': 3,
#  'licht': 3,
#  'fassen': 3,
#  'fern': 3,
#  'halten': 3,
#  'dunkel': 3,
#  'brechen': 3,
#  'beginnen': 3,
#  'fuß': 3,
#  "beicht'ger": 2,
#  'finden': 2,
#  'seligkeit': 2,
#  'thor': 2,
#  'knieen': 2,
#  'kreis': 2,
#  'beten': 2,
#  'horchen': 2,
#  'sang': 2,
#  'klingen': 2,
#  'schrecken': 2,
#  'versucher': 2,
#  'kerze': 2,
#  'wand': 2,
#  'gnade': 2,
#  'starrend': 2,
#  'sehnender': 2,
#  'gluth': 2,
#  'stammelnd': 2,
#  'springen': 2,
#  'tragen|trügen': 2,
#  'herüber': 2,
#  'luft': 2,
#  'fremdländisch': 2,
#  'blume': 2,
#  'bestrickend': 2,
#  'duft': 2,
#  'entweichen': 2,
#  'kreuz': 2,
#  'bild': 2,
#  'seele': 2,
#  'einst': 2,
#  'verstummen': 2,
#  'fromm': 2,
#  'stehen': 2,
#  'erheben': 2,
#  'fahren': 2,
#  'hölle': 2,
#  'aug': 2,
#  'recken': 2,
#  'strecken': 2,
#  'nennen': 2,
#  'verbrennen': 2,
#  'glied': 2,
#  'tod': 2,
#  'pein': 2,
#  'todt': 2,
#  'ziehen': 2,
#  'schuld': 2,
#  'heiland': 2,
#  'huld': 2,
#  'sitzen': 2,
#  'verbrechen': 2,
#  'an+die': 2,
#  'steinern': 2,
#  'kalt': 2,
#  'priester': 2,
#  'fließen': 2,
#  'strömend': 2,
#  'land': 2,
#  'schwarz': 2,
#  'thurm': 2,
#  'büßen': 2,
#  'selig': 2,
#  'kehle': 2,
#  'drücken': 2,
#  'trinken': 2,
#  'wenden': 2,
#  'heran': 2,
#  'nackt': 2,
#  'arm': 2,
#  'fühlen': 2,
#  'quellen': 2,
#  'jammer': 2,
#  'bebend': 2,
#  'schluchzen': 2,
#  '\x82du': 2,
#  'greifen': 2,
#  'fliehen': 2,
#  'feld': 2,
#  'jemals': 2,
#  'brust': 2,
#  'lust': 2,
#  'schaudernd': 2,
#  'stoßen': 2,
#  'entsetzen': 2,
#  'himmel': 2,
#  'holzstoß': 2,
#  'richten': 2,
#  'scheidend': 2,
#  'vernehmen': 2,
#  'ergreifen': 2,
#  'verlieren': 2,
#  'rauch': 2,
#  'wohin': 2,
#  '\x82mein': 2,
#  'hersfeld': 1,
#  'schwach': 1,
#  'glauben': 1,
#  'stündlein': 1,
#  'fromme': 1,
#  'vernimm': 1,
#  'geständniß': 1,
#  'dienet': 1,
#  'heuen': 1,
#  'klosterschatten': 1,
#  'verbleicht': 1,
#  'fasten': 1,
#  'kasteien': 1,
#  'vorbereiten': 1,
#  'allmächtige': 1,
#  'wohlgefallen': 1,
#  'innen': 1,
#  'tönen': 1,
#  'ruf': 1,
#  'hervor': 1,
#  'verrann': 1,
#  'staunend': 1,
#  'unsträflich': 1,
#  'verrathen': 1,
#  'vesperglocke': 1,
#  'schall': 1,
#  'kapelle': 1,
#  'herüberklang': 1,
#  'düstrer': 1,
#  'boden': 1,
#  'empor': 1,
#  'erklingen': 1,
#  'gebet': 1,
#  "litanei'n": 1,
#  'weltlich': 1,
#  'herein': 1,
#  'pforte': 1,
#  'gast': 1,
#  'verfallen': 1,
#  'kralle|krallen': 1,
#  'setzen': 1,
#  'brand': 1,
#  'geweiht': 1,
#  'gewölbe': 1,
#  'dröhnend': 1,
#  'klagestimme': 1,
#  'singend': 1,
#  'sündenfrevel': 1,
#  'spott': 1,
#  'bewahr': 1,
#  'allmächtig': 1,
#  'bleich': 1,
#  'hager': 1,
#  'mager': 1,
#  'kärglich': 1,
#  'falten': 1,
#  'wuth': 1,
#  'rastlos': 1,
#  'seltsam': 1,
#  'ton': 1,
#  'sehnend': 1,
#  'lästernder': 1,
#  'hohn': 1,
#  'fleuch': 1,
#  'schauernden': 1,
#  'dringen': 1,
#  'beschleichen': 1,
#  'schauer': 1,
#  'verlorene': 1,
#  'nagend': 1,
#  'trauer': 1,
#  'denken': 1,
#  'besitzen': 1,
#  'jugend': 1,
#  'vergessen': 1,
#  'mählich': 1,
#  'allmählich': 1,
#  'chor': 1,
#  'eifrig': 1,
#  'greis': 1,
#  'eiferndem': 1,
#  'grimm': 1,
#  'verfahren|verführen': 1,
#  'verdammte': 1,
#  'hernieder': 1,
#  'leuchtend': 1,
#  'glanz': 1,
#  'umwob': 1,
#  'starrendes': 1,
#  'säh': 1,
#  'entzücken': 1,
#  'rein': 1,
#  'schändend': 1,
#  'schwellend': 1,
#  'güte': 1,
#  'spielend': 1,
#  'quellend': 1,
#  'blüthe': 1,
#  'liebend': 1,
#  'bieten': 1,
#  'verachtend': 1,
#  'verstoßen': 1,
#  'ewiglich': 1,
#  'entlang': 1,
#  'knie|knien': 1,
#  'dahinging': 1,
#  'erlösend': 1,
#  'vergieb': 1,
#  'einsam': 1,
#  'zimmer': 1,
#  'bei+die': 1,
#  'kerzenschein': 1,
#  'verkünden': 1,
#  'lug': 1,
#  'trug': 1,
#  'sahest': 1,
#  'grauend': 1,
#  'fliese|fliesen': 1,
#  '\x82werdet': 1,
#  'kind': 1,
#  'erfahren': 1,
#  'segnetest': 1,
#  'sünder': 1,
#  'brünstig': 1,
#  'madonne': 1,
#  'maria': 1,
#  'gelten': 1,
#  'erfüllen': 1,
#  'gestalt': 1,
#  'träumend': 1,
#  'mild': 1,
#  'gährende': 1,
#  'gluthen': 1,
#  'andacht': 1,
#  "heil'ge": 1,
#  'brevier': 1,
#  'jung': 1,
#  'blut': 1,
#  'blond': 1,
#  'locke|locken': 1,
#  'gold': 1,
#  'gießen': 1,
#  'hineinschnitt': 1,
#  'tonsur': 1,
#  'mähen': 1,
#  'frühlingsflur': 1,
#  'deutsch': 1,
#  'böse': 1,
#  'entstehen': 1,
#  'buhlschaft': 1,
#  'verführen': 1,
#  'hexe|hexen': 1,
#  'brandpfahl': 1,
#  'schnüren': 1,
#  'geschehen': 1,
#  'lampe': 1,
#  'schein': 1,
#  'klopfend': 1,
#  '\x82komm': 1,
#  'heraus': 1,
#  'verlangen': 1,
#  'heulen': 1,
#  'sturm': 1,
#  'führete': 1,
#  'hinaus': 1,
#  'gleitend': 1,
#  'stufe': 1,
#  'weisen': 1,
#  'loch': 1,
#  '\x82zur': 1,
#  'bereite': 1,
#  'entreiß': 1,
#  "ew'gen": 1,
#  'bauch': 1,
#  'stocken': 1,
#  'hauch': 1,
#  'drüben': 1,
#  'rascheln': 1,
#  'geklirr': 1,
#  'kette': 1,
#  'seufzen': 1,
#  'schwer': 1,
#  'mauer': 1,
#  'finsterst': 1,
#  'ecke': 1,
#  'thier': 1,
#  'versteck': 1,
#  'bücken': 1,
#  'tiefenden': 1,
#  'heften': 1,
#  'schwebend': 1,
#  'wölbung': 1,
#  '\x82wende': 1,
#  'schwester': 1,
#  'fürchten': 1,
#  'sinken': 1,
#  'kriechen': 1,
#  'knie': 1,
#  'umspielen': 1,
#  'lieblich': 1,
#  'angesicht': 1,
#  'erwarmen': 1,
#  'erbarmen': 1,
#  'lautlos': 1,
#  'leiden': 1,
#  'schweigend': 1,
#  'thränen': 1,
#  'flüstern': 1,
#  'weintest': 1,
#  'gütig': 1,
#  'schreck': 1,
#  '\x82gedenke': 1,
#  'gedenken': 1,
#  'entfliehe': 1,
#  'bange': 1,
#  '\x82was': 1,
#  'eltern': 1,
#  'wohnen': 1,
#  "zwei'n": 1,
#  'kennen': 1,
#  'heilsam': 1,
#  'kraut': 1,
#  'tränklein': 1,
#  'kranke': 1,
#  'brauen': 1,
#  'teufelshexe': 1,
#  'lernen': 1,
#  'land|landen': 1,
#  'liebeszauber': 1,
#  'verstehen': 1,
#  'bedeuten': 1,
#  'hartherzig': 1,
#  'leute': 1,
#  'sperren': 1,
#  'finster': 1,
#  'höllisch': 1,
#  'wurm': 1,
#  'drum': 1,
#  'berühren': 1,
#  'flehend': 1,
#  'beschwören': 1,
#  'drängen': 1,
#  '\x82errette': 1,
#  'errette': 1,
#  'bitter': 1,
#  'schrecklich': 1,
#  'noth': 1,
#  'kränken': 1,
#  'betrüben': 1,
#  'gethan': 1,
#  'zauber': 1,
#  'üben': 1,
#  'gleichen': 1,
#  'wärter': 1,
#  'schlafen': 1,
#  'entflieh': 1,
#  'erlöschen': 1,
#  'verräth': 1,
#  'thurmespforte': 1,
#  'schrei': 1,
#  'hahn': 1,
#  'dicht': 1,
#  'stätte': 1,
#  'stelle': 1,
#  'platz': 1,
#  'verbergen': 1,
#  'schatz': 1,
#  'suchen': 1,
#  'zeihen|ziehen': 1,
#  'beglücken': 1,
#  'reiche': 1,
#  'erde|erden': 1,
#  'stern': 1,
#  'wandeln': 1,
#  'stunde|stunden': 1,
#  "zieh'n": 1,
#  "entflieh'n": 1,
#  'odem': 1,
#  'sturmwind': 1,
#  'nacken': 1,
#  'fittig': 1,
#  'umfließen': 1,
#  'herrlich': 1,
#  'pracht': 1,
#  'schwindelnd': 1,
#  'tödtliche': 1,
#  'nieder': 1,
#  'küssen': 1,
#  'rückwärts': 1,
#  'reißen': 1,
#  'küssest': 1,
#  'segnest': 1,
#  'theil': 1,
#  'göttlich': 1,
#  'jagen': 1,
#  'kammer': 1,
#  'schreien': 1,
#  'verzweiflung': 1,
#  'wange': 1,
#  'erblich': 1,
#  'ängstet': 1,
#  'widerstehen': 1,
#  'kunst': 1,
#  'schanden': 1,
#  'tröstend': 1,
#  'gelächter': 1,
#  'lache|lachen': 1,
#  'ungestüm': 1,
#  'lachen': 1,
#  'rollend': 1,
#  '\x82der': 1,
#  'brennen': 1,
#  'flammen': 1,
#  'rotten': 1,
#  'draußen': 1,
#  'scheitern': 1,
#  'schichten': 1,
#  'stand': 1,
#  'düster': 1,
#  'pfahl': 1,
#  'harren': 1,
#  'qual': 1,
#  'taumelnd': 1,
#  'vogel': 1,
#  'verflattert': 1,
#  'meer': 1,
#  'gleiten': 1,
#  'umher': 1,
#  'kruzifix': 1,
#  'erfassen': 1,
#  'suchend': 1,
#  'blick': 1,
#  'verstohlen': 1,
#  'weise': 1,
#  'nicken': 1,
#  'lächeln': 1,
#  'erstehen': 1,
#  'sonne': 1,
#  'verlöschendes': 1,
#  'loderne': 1,
#  'henker': 1,
#  'lechzend': 1,
#  'dürr': 1,
#  'geäst': 1,
#  'fest': 1,
#  'funken': 1,
#  'stieben': 1,
#  'prasselnd': 1,
#  'staub': 1,
#  'erbebten': 1,
#  'sinkend': 1,
#  'laub': 1,
#  'klinge|klingen': 1,
#  'brennend': 1,
#  'frühlingsregen': 1,
#  'durchrauschend': 1,
#  'selige': 1,
#  'spräch': 1,
#  'glück': 1,
#  'letzt': 1,
#  'gruß': 1,
#  'wirbelnd': 1,
#  'umschwoll': 1,
#  'brausend': 1,
#  'zitternd': 1,
#  'glocke': 1,
#  'ertönen': 1,
#  'bedecken': 1,
#  '\x82das': 1,
#  'enden': 1,
#  'entfliehen': 1,
#  'begleiten': 1,
#  'schlummernd': 1,
#  'wachen': 1,
#  'jegliche': 1,
#  'immerdar': 1,
#  '\x82ich': 1,
#  'vernimmst': 1,
#  'herauf': 1,
#  'werfen': 1,
#  '\x82thu': 1,
#  'menschenverderber': 1,
#  'gebunden': 1,
#  'erfinden': 1,
#  'zwingen': 1,
#  '\x82eine': 1,
#  'paradies': 1,
#  'heil': 1,
#  'frevelnd': 1,
#  'öffnen': 1,
#  'thräne': 1,
#  'rinnen': 1,
#  'menschlich': 1,
#  'jauchzend': 1,
#  'flüchtendem': 1,
#  'fenster': 1,
#  'grauende': 1,
#  'menschenauge': 1,
#  "versteh'n": 1,
#  'gericht\x91': 1}

# %%
path = '../results/zeta/pro_wort/sprechmarker_500pro_wort.csv'
compute_ranking(path, wildenbruch_sort)
# Out:
# Rankingstelle:  10 ;  rufen :  7
# Rankingstelle:  98 ;  beten :  2
# Rankingstelle:  133 ;  nennen :  2
# Rankingstelle:  167 ;  schluchzen :  2
# Rankingstelle:  182 ;  vernehmen :  2
# Rankingstelle:  300 ;  verkünden :  1
# Rankingstelle:  348 ;  verlangen :  1
# Rankingstelle:  395 ;  flüstern :  1
# Rankingstelle:  428 ;  beschwören :  1
# Rankingstelle:  484 ;  schreien :  1
# Rankingstelle:  571 ;  erfinden :  1

# %% [markdown]
# häufigster Autor

# %%
c = Counter(lyrik.Autor)
print({k: v for k, v in sorted(c.items(), key=lambda item: item[1],reverse=True)})
# Out:
   in+die bangend sinn die lust und die qual   die zauber die minne verstehn sie zumal   die weidmann erklingen es wie grüßendes horn   die schnitter umsingt es wie wachtel in+die korn   die schiffer an+die land befallen es wie eine weh   er hören die gebrande die rollend see   und wo sich in+die kreis verbluten eine herz   da kühlen er die weise die brennend schmerz   aufatmen es betreffen   als träufeln mild balsamisches hoffen von+die sternengefild   wie adlersgefieder jetzt schwingen sich die schall   jetzt säuseln er nieder wie tropfen in+die fall   so wandeln die bote die jung gericht   so grüßen die tote von+die ort die licht   nun sterben die klang   nun schweigen sie ganz   da jubeln die menge   da bringen sie die kranz   doch stolz sich verneigend   als drücken er die lohn   ins dunkel sein schweigend die spielmann entflohn   bei+die glanz die stern   von wind|winde|winden umrauscht   schon wandern er ferne   wo niemand er lauschen   da geigt er in thränen sich selbst noch eine stück   verloren sehne|sehnen   begrabenes glück    verzaubern liegen   verschollen   dornröschen gleich in+die wald tief   die lied auf staub\'gen rolle   die musenkind   und schlafen   da brechen durch+die dorngestrüppe mit hell ruf eine königssohn   da küssen mit warm lippe die schläferin die ton   und sehen   zu rasch schlag urplötzlich sein ihr herz erwachen   sie heben sich er entgegen   ihr ange weinen und lachen   von+die lager aufspringen   die arm|arme stricken sie um er her   sie halten sich umschlungen und lassen sich nicht mehr   und auf die liebe flügel nun ziehn die beide treugesellt wohl über strom und hügel hinaus in alle welt    hab \' ich einst ehrgeizig wunsch als jüngling unbedacht in+die busen nähren   ich bannen \' er längst   die weltlaufkundigen gehen keine gut mehr über die freiheit   mögen   wer wollen   an+die sessel die macht um einfluss buhlend   stets abhängig los ertragen   oder   laut von+die volk bejauchzt   die volk laune gehorchen   ich gefallen es   nach eigen trieb in ernst muße   fern von+die stimmengebraus die markt   bald in+die schicksalsbuche die zeit die dunkel schrift zu enträtseln     bald an+die reichtum griechisch kunst und schönheit   an homers einfach gewalt zu prüfen   was die neuzeit mächtige schaffen   von andere stern geleiten|leiten     oder tagwerkmüde die zug die wolke nachzuschaun und irgend eine lied zu summen   wie es die einsam träumende hoffnung eingiebt oder erinnrung    ach   noch einmal dies ton   die ich flügel in die schön zauberland die jugend sein   lassen sie schwellen voll und leise   dies weise s ...

# %%
stopword = open("de_stopwords.txt")
stopwords = stopword.read()
stop = ' '.join([item for item in str(lyrik_geibel).split() if item not in stopwords])
c = Counter(stop.split())
geibel_sort_vocab = {k: v for k, v in sorted(c.items(), key=lambda item: item[1],reverse=True)}

# %%
path = '../results/zeta/pro_wort/sprechmarker_500pro_wort.csv'
compute_ranking(path, geibel_sort_vocab)
# Out:
# Rankingstelle:  76 ;  rufen :  8
# Rankingstelle:  317 ;  flüstern :  3
# Rankingstelle:  318 ;  schreien :  3
# Rankingstelle:  426 ;  zeigen :  2
# Rankingstelle:  504 ;  erzählen :  2
# Rankingstelle:  512 ;  keuchen :  2
# Rankingstelle:  544 ;  klagen :  2
# Rankingstelle:  582 ;  plaudern :  2
# Rankingstelle:  657 ;  schließen :  2
# Rankingstelle:  905 ;  nennen :  1
# Rankingstelle:  993 ;  erfinden :  1
