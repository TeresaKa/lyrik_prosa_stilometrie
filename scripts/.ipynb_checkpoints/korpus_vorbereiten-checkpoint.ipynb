# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import seaborn as sns
import matplotlib.pyplot as plt
import regex as re 
import glob
import os
from collections import Counter

# %%
path = "../corpus/epik/epik_lemma/*.txt"
prefix = "../corpus/epik/epik_lemma/"

text_list = []
for file in glob.glob(path):
    filename = file.replace(prefix, '').replace('.txt', '')
    with open(file, 'r') as f:
        data = f.read().replace('\n', '')
    
        
    text_list.append(pd.Series(data, name=filename))
# print(freq_list)

# %%
text = pd.DataFrame(text_list)
# text

# %%
text['ID'] = text.index
text['Autor'] = '0'
text['Titel'] = '0'
for i, row in text.iterrows():
    row['Autor'] = row.ID.split('_')[2]
    row['Titel'] = row.ID.split('_')[3]
text.rename({0: 'text'}, axis=1, inplace=True)
text
# Out:
#                                                                                     text  \
# epik_lemma_mann_tristan                tristan von thomas mann hier sein > einfried <...
# epik_lemma_brentano_rosenkranz         clemens brentano herausgeben und einleiten von...
# epik_lemma_wassermann_vierzig          die mann von vierzig jahr eine klein roman von...
# epik_lemma_lewald_clementine           fanny lewald clementine erste capitel also wei...
# epik_lemma_schnitzler_tanzerin         die griechisch tänzerin und andere novelle von...
# epik_lemma_bonsels_maja                die biene maja und ihr abenteuer von dies buch...
# epik_lemma_may_wuste                   durch wüste und harem reiseerlebnis von carl m...
# epik_lemma_falke_durchschnitt          aus die durchschnitt roman von gustav falke ha...
# epik_lemma_spyri_heidi1                johanna spyri heidi können brauchen   was es l...
# epik_lemma_goethe_faust1               faust   die tragödie erst teil johann wolfgang...
# epik_lemma_fischer_gustavsverirrungen  caroline auguste fischer gustav verirrung eine...
# epik_lemma_arnim_isabella              isabella von ägypten achim von arnim kaiser ka...
# epik_lemma_hoffmann_topf               die golden topfen von e t a  hoffmann   mit @c...
# epik_lemma_fontane_birnbaum            theodor fontane unter+die birnbaum erst kapite...
# epik_lemma_achleitner_bergrichters     bergrichters erdenwallen hochlandsroman von ar...
# epik_lemma_sapper_kriegsbuchlein       kriegsbüchlein für unser kind von agnes sapper...
# epik_lemma_kafka_verwandlung           die verwandlung von franz kafka i   als gregor...
# epik_lemma_heiberg_frau                eine vornehm frau   von hermann heiberg   @car...
# epik_lemma_hesse_knulp                 knulp drei geschichte aus die leben knulps von...
# epik_lemma_gerstacker_reise            herr mahlhuber die reiseabenteuer   erzählung ...
# epik_lemma_keller_seldywla1            gottfried keller die leute von seldwyla erste ...
# epik_lemma_meyer_richterin             die richterin novelle conrad ferdinand meyer e...
#
#                                                                           ID  \
# epik_lemma_mann_tristan                              epik_lemma_mann_tristan
# epik_lemma_brentano_rosenkranz                epik_lemma_brentano_rosenkranz
# epik_lemma_wassermann_vierzig                  epik_lemma_wassermann_vierzig
# epik_lemma_lewald_clementine                    epik_lemma_lewald_clementine
# epik_lemma_schnitzler_tanzerin                epik_lemma_schnitzler_tanzerin
# epik_lemma_bonsels_maja                              epik_lemma_bonsels_maja
# epik_lemma_may_wuste                                    epik_lemma_may_wuste
# epik_lemma_falke_durchschnitt                  epik_lemma_falke_durchschnitt
# epik_lemma_spyri_heidi1                              epik_lemma_spyri_heidi1
# epik_lemma_goethe_faust1                            epik_lemma_goethe_faust1
# epik_lemma_fischer_gustavsverirrungen  epik_lemma_fischer_gustavsverirrungen
# epik_lemma_arnim_isabella                          epik_lemma_arnim_isabella
# epik_lemma_hoffmann_topf                            epik_lemma_hoffmann_topf
# epik_lemma_fontane_birnbaum                      epik_lemma_fontane_birnbaum
# epik_lemma_achleitner_bergrichters        epik_lemma_achleitner_bergrichters
# epik_lemma_sapper_kriegsbuchlein            epik_lemma_sapper_kriegsbuchlein
# epik_lemma_kafka_verwandlung                    epik_lemma_kafka_verwandlung
# epik_lemma_heiberg_frau                              epik_lemma_heiberg_frau
# epik_lemma_hesse_knulp                                epik_lemma_hesse_knulp
# epik_lemma_gerstacker_reise                      epik_lemma_gerstacker_reise
# epik_lemma_keller_seldywla1                      epik_lemma_keller_seldywla1
# epik_lemma_meyer_richterin                        epik_lemma_meyer_richterin
#
#                                             Autor               Titel
# epik_lemma_mann_tristan                      mann             tristan
# epik_lemma_brentano_rosenkranz           brentano          rosenkranz
# epik_lemma_wassermann_vierzig          wassermann             vierzig
# epik_lemma_lewald_clementine               lewald          clementine
# epik_lemma_schnitzler_tanzerin         schnitzler            tanzerin
# epik_lemma_bonsels_maja                   bonsels                maja
# epik_lemma_may_wuste                          may               wuste
# epik_lemma_falke_durchschnitt               falke        durchschnitt
# epik_lemma_spyri_heidi1                     spyri              heidi1
# epik_lemma_goethe_faust1                   goethe              faust1
# epik_lemma_fischer_gustavsverirrungen     fischer  gustavsverirrungen
# epik_lemma_arnim_isabella                   arnim            isabella
# epik_lemma_hoffmann_topf                 hoffmann                topf
# epik_lemma_fontane_birnbaum               fontane            birnbaum
# epik_lemma_achleitner_bergrichters     achleitner        bergrichters
# epik_lemma_sapper_kriegsbuchlein           sapper      kriegsbuchlein
# epik_lemma_kafka_verwandlung                kafka         verwandlung
# epik_lemma_heiberg_frau                   heiberg                frau
# epik_lemma_hesse_knulp                      hesse               knulp
# epik_lemma_gerstacker_reise            gerstacker               reise
# epik_lemma_keller_seldywla1                keller           seldywla1
# epik_lemma_meyer_richterin                  meyer           richterin

# %%
text.to_csv('../corpus/epik/epik.csv')

# %%
lyrik = pd.read_csv('../../hausarbeit_stilometrie/Lyrik/Corpus_Explorer-master/explorer_stable/meta_lyrik.tsv', sep='\t')
lyrik.head()
# Out:
#           ID                                       Titel  \
# 0  l00100002                               Am Geburtstag
# 1  l00100003                                   Krankheit
# 2  l00100004  In dämmerdunklen Wegen [Drei Liebeslieder]
# 3  l00100005         In gelben Ähren [Drei Liebeslieder]
# 4  l00100006          Nach dem Sturm [Drei Liebeslieder]
#
#                                                Autor  Strophen  Verse  \
# 0  Avenarius, Ferdinand [alt. Avernarius, Ferdina...         1     18
# 1  Avenarius, Ferdinand [alt. Avernarius, Ferdina...         3      4
# 2                                     Benzmann, Hans         3      5
# 3                                     Benzmann, Hans         3      7
# 4                                     Benzmann, Hans         3      4
#
#                                           Anthologie  Jahr            Hrsg  \
# 0  Die Perlenschnur. Eine Anthologie moderner Lyr...  1898  Gemmel, Ludwig
# 1  Die Perlenschnur. Eine Anthologie moderner Lyr...  1898  Gemmel, Ludwig
# 2  Die Perlenschnur. Eine Anthologie moderner Lyr...  1898  Gemmel, Ludwig
# 3  Die Perlenschnur. Eine Anthologie moderner Lyr...  1898  Gemmel, Ludwig
# 4  Die Perlenschnur. Eine Anthologie moderner Lyr...  1898  Gemmel, Ludwig
#
#         ID.1   Epoche  ...  bert_Ivis_sonett_1  bert_Ivis_sonett_2  \
# 0  l00100002  Moderne  ...                 3.0                -3.0
# 1  l00100003  Moderne  ...                 3.0                -3.0
# 2  l00100004  Moderne  ...                 3.0                -3.0
# 3  l00100005  Moderne  ...                 3.0                -3.0
# 4  l00100006  Moderne  ...                 3.0                -3.0
#
#    bert_Ivis_sonett_sup_1  bert_Ivis_sonett_sup_2 bert_Ivis_1  bert_Ivis_2  \
# 0                     0.0                     0.0   -5.380342    -0.808883
# 1                     0.0                     0.0   -3.692929     5.331859
# 2                     0.0                     0.0   -1.325232    -1.066014
# 3                     0.0                     0.0   -2.259074    -1.154754
# 4                     0.0                     0.0   -1.166162    -1.794649
#
#    bert_Ivis_sup_1  bert_Ivis_sup_2  dtm_Ivis_sup_1  dtm_Ivis_sup_2
# 0        -0.117857        -3.909007        1.401555       -0.390788
# 1        -1.058132        -3.161242       -1.308754        2.330740
# 2         2.740632        -0.271447        0.670711        2.473900
# 3         2.797562        -1.197993        1.767469        0.094221
# 4         2.745504         1.734362        1.788685       -0.813413
#
# [5 rows x 27 columns]

# %%
path = "../corpus/lyrik/lyrik_lemma/*.txt"
prefix = "../corpus/lyrik/lyrik_lemma/"

text_list = []
for file in glob.glob(path):
    filename = file.replace(prefix, '').replace('.txt', '')
    with open(file, 'r') as f:
        data = f.read().replace('\n', '')    
    text_list.append(pd.Series(data, name=filename))
    
lyrik2 = pd.DataFrame(text_list)
lyrik2['ID'] = lyrik2.index
for i, row in lyrik2.iterrows():
    row['ID'] = row.ID.split('_')[1]
lyrik2
# Out:
#                                                                  0         ID
# lyrik_l0070078   und in die strahl|strahlen spielen die letzt s...   l0070078
# lyrik_l00110589  und durch die busch gehen die gelb mond   und ...  l00110589
# lyrik_l0020153   ich wissen   was mit du vorgehen   was hinter ...   l0020153
# lyrik_l0030107   ji die seele ausziehen sein aus die palast   d...   l0030107
# lyrik_l00160015  sie entspringen die abschreckungstheorie   das...  l00160015
# ...                                                            ...        ...
# lyrik_l0060034   vergeben   ich   du   längst   ich that es   n...   l0060034
# lyrik_l0050067   von bebend wimper tropfen die nacht zähre ich ...   l0050067
# lyrik_l0040541   du treu hand   die ohne beben einst mein hand ...   l0040541
# lyrik_l00210030  herr valentin gehen abends aus zu+die kartenti...  l00210030
# lyrik_l00110148  ich wissen   ihr lieben die dunkel nicht   in ...  l00110148
#
# [4830 rows x 2 columns]

# %%
lyrik = lyrik.merge(lyrik2, on='ID')
# lyrik.drop('Unnamed: 0', axis=1, inplace=True)
lyrik.rename({0: 'text'}, axis=1, inplace=True)
lyrik
# Out:
#              ID                                       Titel  \
# 0     l00100002                               Am Geburtstag
# 1     l00100003                                   Krankheit
# 2     l00100004  In dämmerdunklen Wegen [Drei Liebeslieder]
# 3     l00100005         In gelben Ähren [Drei Liebeslieder]
# 4     l00100006          Nach dem Sturm [Drei Liebeslieder]
# ...         ...                                         ...
# 4825   l0090303                              Abend im Walde
# 4826   l0090304                                 Am Ammersee
# 4827   l0090305                              Klage der Magd
# 4828   l0090306                                   Der Husar
# 4829   l0090307                                   Abendlied
#
#                                                   Autor  Strophen  Verse  \
# 0     Avenarius, Ferdinand [alt. Avernarius, Ferdina...         1     18
# 1     Avenarius, Ferdinand [alt. Avernarius, Ferdina...         3      4
# 2                                        Benzmann, Hans         3      5
# 3                                        Benzmann, Hans         3      7
# 4                                        Benzmann, Hans         3      4
# ...                                                 ...       ...    ...
# 4825                                 Stern, Maurice von         3      8
# 4826                                        Ziel, Ernst         4      8
# 4827                                  Keller, Gottfried         6      8
# 4828                                  Keller, Gottfried         5      4
# 4829                                  Keller, Gottfried         4      4
#
#                                              Anthologie  Jahr  \
# 0     Die Perlenschnur. Eine Anthologie moderner Lyr...  1898
# 1     Die Perlenschnur. Eine Anthologie moderner Lyr...  1898
# 2     Die Perlenschnur. Eine Anthologie moderner Lyr...  1898
# 3     Die Perlenschnur. Eine Anthologie moderner Lyr...  1898
# 4     Die Perlenschnur. Eine Anthologie moderner Lyr...  1898
# ...                                                 ...   ...
# 4825  Neue Lieder der besten neueren Dichter für's V...  1899
# 4826  Neue Lieder der besten neueren Dichter für's V...  1899
# 4827  Neue Lieder der besten neueren Dichter für's V...  1899
# 4828  Neue Lieder der besten neueren Dichter für's V...  1899
# 4829  Neue Lieder der besten neueren Dichter für's V...  1899
#
#                                               Hrsg       ID.1   Epoche  ...  \
# 0                                   Gemmel, Ludwig  l00100002  Moderne  ...
# 1                                   Gemmel, Ludwig  l00100003  Moderne  ...
# 2                                   Gemmel, Ludwig  l00100004  Moderne  ...
# 3                                   Gemmel, Ludwig  l00100005  Moderne  ...
# 4                                   Gemmel, Ludwig  l00100006  Moderne  ...
# ...                                            ...        ...      ...  ...
# 4825  Jacobowski, Ludwig [alt. Jakobowsky, Ludwig]   l0090303  Moderne  ...
# 4826  Jacobowski, Ludwig [alt. Jakobowsky, Ludwig]   l0090304  Moderne  ...
# 4827  Jacobowski, Ludwig [alt. Jakobowsky, Ludwig]   l0090305  Moderne  ...
# 4828  Jacobowski, Ludwig [alt. Jakobowsky, Ludwig]   l0090306  Moderne  ...
# 4829  Jacobowski, Ludwig [alt. Jakobowsky, Ludwig]   l0090307  Moderne  ...
#
#       bert_Ivis_sonett_2  bert_Ivis_sonett_sup_1  bert_Ivis_sonett_sup_2  \
# 0                   -3.0                     0.0                     0.0
# 1                   -3.0                     0.0                     0.0
# 2                   -3.0                     0.0                     0.0
# 3                   -3.0                     0.0                     0.0
# 4                   -3.0                     0.0                     0.0
# ...                  ...                     ...                     ...
# 4825                -3.0                     0.0                     0.0
# 4826                -3.0                     0.0                     0.0
# 4827                -3.0                     0.0                     0.0
# 4828                -3.0                     0.0                     0.0
# 4829                -3.0                     0.0                     0.0
#
#       bert_Ivis_1 bert_Ivis_2  bert_Ivis_sup_1  bert_Ivis_sup_2  \
# 0       -5.380342   -0.808883        -0.117857        -3.909007
# 1       -3.692929    5.331859        -1.058132        -3.161242
# 2       -1.325232   -1.066014         2.740632        -0.271447
# 3       -2.259074   -1.154754         2.797562        -1.197993
# 4       -1.166162   -1.794649         2.745504         1.734362
# ...           ...         ...              ...              ...
# 4825    -0.531412   -2.178765         2.470116         4.415361
# 4826    -2.525950    0.724239        -0.860047        -0.687187
# 4827    -1.770992    1.825194        -0.435139        -1.574231
# 4828    -0.918860    4.837693        -2.241466        -2.007997
# 4829    -0.407763    2.097504        -1.218012        -0.271588
#
#       dtm_Ivis_sup_1  dtm_Ivis_sup_2  \
# 0           1.401555       -0.390788
# 1          -1.308754        2.330740
# 2           0.670711        2.473900
# 3           1.767469        0.094221
# 4           1.788685       -0.813413
# ...              ...             ...
# 4825        0.751563       -0.570169
# 4826        1.657395       -0.657326
# 4827        0.093640        1.002120
# 4828       -1.665183        1.045698
# 4829        0.601502       -0.313131
#
#                                                    text
# 0     neben ich plauderts in+die glitzernd quell aus...
# 1     wenn droben du sein   die alle leben du durchb...
# 2     wir lieben wir in dämmerdunklen weg   es schwi...
# 3     wir gehen in gelb ähre   nachmittagsstille   v...
# 4     die sturmwind kommen und fegen rein die himmel...
# ...                                                 ...
# 4825  warm in die weich wolkendaunen die abendmüde s...
# 4826  es stehen eine weide an+die ammersee   die tau...
# 4827  nun sein die lenz kommen   nun blühen alle wie...
# 4828  ich glänzen die auge wie die himmel so klar   ...
# 4829  auge   mein lieb fensterlein   geben ich schon...
#
# [4830 rows x 28 columns]

# %%
lyrik.to_csv('../corpus/lyrik/lyrik.csv')

# %%
l = 0
for i, row in lyrik.iterrows():
    l+= len(row.text.split())
print(l)
# Out:
# 692405

# %%
l = 0
for i, row in text.iterrows():
    l+= len(row.text.split())
print(l)
# Out:
# 942434

# %%
print(np.unique(lyrik.Autor))
len(np.unique(lyrik.Autor))
# Out:
# ['. Joseph Frhr. v. Eichendorff.' 'A. E. Fröhlich.' 'A. Galster.' ...
#  'riedrich Bodenstedt.' 'unknown' 'Öhquist, Johannes']
# 1051

# %%
Counter(lyrik.Autor)
# Out:
# Counter({'Avenarius, Ferdinand [alt. Avernarius, Ferdinand; Avernius, Ferinand]': 2,
#          'Benzmann, Hans': 16,
#          'Jürgen Friedrich Ahrens.': 4,
#          'Bethge, Hans': 12,
#          'Bethge,  Hans': 1,
#          'Bierbaum, Otto Julius': 52,
#          'Bodman, Emanuel von [Bodman, Emanuel Freiherr von; alt. Bodmann, Emanuel von]': 3,
#          'Bruns, Max': 10,
#          'Busse, Carl [alt. Busse, Karl]': 17,
#          'Conradi, Hermann': 29,
#          'Croissant-Rust, Anna': 4,
#          'Dehmel, Richard': 54,
#          'Eduard Alberti.': 2,
#          'Donath, Adolph [alt. Donath, Adolf]': 3,
#          'Evers, Franz': 33,
#          'Leopold Alberti.': 5,
#          'Falke, Gustav': 42,
#          'Flaischlen, Cäsar [alt. Flaischlen, Caesar]': 20,
#          'Hart, Julius': 20,
#          'Hartleben, Otto Erich [alt. Hartleben, O. Erich; Hartleben, Erich]': 30,
#          'Henckell, Karl': 58,
#          'Holz, Arno': 44,
#          'Holzamer, Wilhelm': 12,
#          'Jacobowski, Ludwig [alt. Jakobowsky, Ludwig]': 15,
#          'Friedrich Albrecht.': 2,
#          'Janitschek, Maria': 13,
#          'Kamlah, Kurt': 3,
#          'Liliencron, Detlev von [alt. Liliencron, Detlev Frhr. von; Liliencron, Detlev Freiherr von]': 55,
#          'L. Altenbernd.': 6,
#          'Lindner, Anton': 5,
#          'Lingen, Thekla': 7,
#          'Mackay, John Henry': 12,
#          'Maria, Karl': 7,
#          'Morgenstern, Christian': 28,
#          'Nietzsche, Friedrich': 14,
#          'Preuschen, Hermione von [Preuschen-Telmann, Hermione von; alt. Preuschen, Hermine von]': 4,
#          'Remer, Paul': 13,
#          'Salus, Hugo': 11,
#          'Scharf, Ludwig': 16,
#          'Schaukal, Richard': 39,
#          'Gerhard von Amyntor.': 1,
#          'Schaumberg, Georg': 5,
#          'Scheffer, Thassilo von': 12,
#          'Ludwig Auerbach.': 4,
#          'Schlaf, Johannes': 15,
#          'Scholz, Wilhelm von': 18,
#          'Schur, Ernst': 23,
#          'Stern, Fritz': 3,
#          'Wilhelm, Paul': 10,
#          'Wille, Bruno': 15,
#          'Ferdinand Avenarius.': 2,
#          'Wilhelm Backhaus.': 5,
#          'Eufemia Gräfin Ballestrem.': 2,
#          'Karoline Freifran von Bartenstein.': 2,
#          'Gustav Emil Barthel.': 4,
#          'Karl Bartsch.': 5,
#          'Friedrich Beck.': 4,
#          'Konrad Beyer.': 4,
#          'Franz Binhack.': 12,
#          'Moritz Blanckarts.': 4,
#          'Viktor Blüthgen.': 1,
#          'Friedrich Bodenstedt.': 17,
#          'Wilhelm Buchholz.': 5,
#          'Rudolf Bunge.': 2,
#          'Thekla Busch.': 2,
#          'Karl Conrad.': 1,
#          'Edmund Dorer.': 1,
#          'Heinrich Dorgeel.': 1,
#          'G. Dnill.': 1,
#          'Adelheid EberhardtBürck.': 2,
#          'Adelheid Eberhardt-Bürck.': 3,
#          'Karl Egon Ritter von Ebert.': 2,
#          'Erust Eckstein.': 5,
#          'Lndwig Eichrodt.': 2,
#          'Karl Elze.': 4,
#          'Rudolf Fastenrath.': 2,
#          'Josef Feler.': 3,
#          'Therese Focking.': 1,
#          'Ludwig Folgar.': 1,
#          'Philipp Freytag.': 2,
#          'Friedrich Geßler.': 5,
#          'Melchior Grohe.': 2,
#          'Jul. vom Hag.': 6,
#          'Inl. vom hag.': 4,
#          'Harbert Harberts.': 2,
#          'Adalbert Harnisch.': 4,
#          'Sophie Hasenclever.': 2,
#          'Mar Hanshofer.': 2,
#          'Gedeon von der Heide.': 1,
#          'Ludwig Hinterding.': 3,
#          'Th. Hoferichter.': 5,
#          'Inlins Hübner.': 5,
#          'Friedrich Kampmann.': 9,
#          'Adolf Katsch.': 11,
#          'Emma Kattner.': 2,
#          'Alexander Kanfmann.': 5,
#          'Friedrich Kirchner.': 4,
#          'Hermann Kletke.': 13,
#          'C. Krause.': 1,
#          'Rudolf Kulemann.': 9,
#          'Edmund Alexander Läutner.': 6,
#          'Freiherr von Ledersteger.': 2,
#          'Heinrich Littrow.': 7,
#          'Hieronymus Lorm.': 2,
#          'Lodoiska Meyer.': 1,
#          'Dr. Mises.': 4,
#          'Paul Möbins.': 4,
#          'Mar Moltke.': 9,
#          'Albert Möser.': 4,
#          'Wilhelm Müller.': 11,
#          'Emil Neubürger.': 2,
#          'Karl Woldemar Nenmann.': 1,
#          'Baron Ferdinand von Nolde.': 7,
#          'Anton Ohorn.': 3,
#          'Lnise Otto.': 3,
#          'Adolf Pichler.': 19,
#          'Kourad von Prittwitz-Gaffron.': 1,
#          'Heinrich Pröhle.': 5,
#          'Ferdinand Freiherr von Rast.': 2,
#          'Heribert Rau.': 5,
#          'Ernst Rauscher.': 5,
#          'Karl Reuleaux.': 1,
#          'Karl Reuleaur.': 1,
#          'Liddy Richter.': 6,
#          'Emilie Ringseis.': 1,
#          'Hermann Rollett.': 1,
#          'P. K. Rosegger.': 2,
#          'Rotenburger Einsiedler.': 4,
#          'E. Sartorins.': 1,
#          'E. Jartorins.': 2,
#          'Frida Schanz.': 1,
#          'Pauline Schanz.': 3,
#          'Uli Schanz.': 5,
#          'Hans Schmidt.': 6,
#          'Wilhelm Schöpff.': 2,
#          'C. Schultes.': 3,
#          'Constans Schulze': 7,
#          'Justus Schumann.': 3,
#          'H. Schwerdt.': 1,
#          'Friedr. Xaver Seidl.': 2,
#          'August Silberstein.': 3,
#          'Adolf Stern.': 5,
#          'Adolf Stöber.': 9,
#          'Franz Tiefenbacher.': 2,
#          'ichard Treitschke.': 1,
#          'Ernst Veit.': 4,
#          'Hermann Waldow.': 6,
#          'Gustav Weck.': 3,
#          'Louis Wolff.': 2,
#          'Karl Woermann.': 2,
#          'Ludwig Würkert.': 3,
#          'Heinrich Zeise.': 8,
#          'Karl Zettel.': 5,
#          'Morit Zille.': 2,
#          'Engelbert Albrecht.': 2,
#          'August Auch.': 2,
#          'Amand Baumgarten.': 1,
#          'Wilhelm Beste.': 8,
#          'Anton Boesch.': 5,
#          'Cajetan Cerri.': 9,
#          'W. Constant.': 15,
#          'Felix Dahn.': 18,
#          'Nikolaus Delius.': 2,
#          'Hermann Dickmann.': 8,
#          'F. J. Düraner.': 2,
#          'Angust Hermann Franke.': 3,
#          'Ludwig August Frankl.': 3,
#          'Emanuel Geibel.': 65,
#          'Robert Gericke.': 1,
#          'Rudolf von Gottschall.': 4,
#          'Rudolf Grimm.': 3,
#          'Julius Grosse.': 7,
#          'Robert Hamerling.': 11,
#          'Wilhelm Hasenclever.': 4,
#          'Friedrich Haßlwander.': 3,
#          'Lina Hetzer.': 1,
#          'Paul Heyse.': 5,
#          'Franziska von Hoffnaaß.': 1,
#          'Hermann Eduard Jahn.': 3,
#          'Wilhelm Jordan.': 1,
#          'Anna Karbe.': 2,
#          'Theodor Kirchhoff.': 2,
#          'Jermann Krassert.': 2,
#          'Meta Langer.': 2,
#          'Richard Leander.': 2,
#          'F. A. Leo.': 4,
#          'Hermann Lingg.': 25,
#          'Oswald Marbach.': 1,
#          'Friedrich Konrad Müller': 1,
#          'Emil Rittershaus.': 19,
#          'Friedrich Schenck.': 1,
#          'Ernst Scherenberg.': 7,
#          'Fr. Wilhelm Schuster.': 1,
#          'Hermann Semmig.': 2,
#          'Vogel von Glarus.': 4,
#          'Ernst Ziel.': 7,
#          'Adler, Friedrich': 13,
#          'Arent, Wilhelm [alt. Arendt, Wilhelm]': 35,
#          'Avenarius, Ferdinand [alt. Avernarius, Ferdinand; Avernius, Ferdinand]': 6,
#          'Barsch, Paul': 5,
#          'Bartels, Adolf': 2,
#          'Baum, Peter': 5,
#          'Beutler, Margarethe': 1,
#          'Bienenstein, Karl': 6,
#          'Bleibtreu, Carl [Bleibtreu, Karl]': 6,
#          'Bodman, Emanuel von [alt. Bodman, Emanuel Freiherr von; Bodmann, Emanuel von]': 8,
#          'Boelitz, Martin [alt. Bölitz, Martin]': 5,
#          'Bondy, Josef Adolf': 4,
#          'Bulcke, Karl': 7,
#          'Busse, Carl [Busse, Karl]': 13,
#          'Conrad, Michael Georg': 6,
#          'Dauthendey, Max [Dauthendey, Maximilian; alt. Dauthendey, Maxim]': 24,
#          'David, Jakob Julius [alt. David, J. J.]': 8,
#          'Diesener, Helene': 2,
#          'Eichhorn, Maria [Pseud. Dolorosa]': 3,
#          'Donath, Adolf': 1,
#          'Engels, Alexander': 2,
#          'Ernst, Otto [vollst. Otto Ernst Schmidt]': 4,
#          'Etzwein, Hermann': 2,
#          'Faktor, Emil': 3,
#          'Falckenberg, Otto': 3,
#          'Finckh, Ludwig': 6,
#          'Fontane, Theodor Fontane': 1,
#          'Fontane, Theodor': 12,
#          'Friedrichs, Hermann': 3,
#          'Frommel, Otto': 3,
#          'Fuchs, Georg': 3,
#          'Fulda, Ludwig': 4,
#          'Gabriel, Hans': 2,
#          'Gaudy, Alice Freiin von': 3,
#          'Geiger, Albert': 4,
#          'Geucke, Kurt': 2,
#          'Ginzkey, Franz Karl': 2,
#          'Grazie, Marie Eugenie delle [Grazie, Maria Eugenie delle; alt. Grazie, M. E. delle; Grazie, M. Eug. delle]': 5,
#          'Greif, Martin': 15,
#          'Greiner, Leo': 6,
#          'Grisebach, Eduard': 10,
#          'Grotowsky, Paul': 2,
#          'Grotthuß, Emil Freiherr von [Grotthuß, Jeannot Emil Freiherr von; alt. Grotthuss, J. E. Freih. von]': 2,
#          'Hango, Hermann': 13,
#          'Hauptmann, Gerhart': 3,
#          'Hauptmann, Karl': 4,
#          'Held, Franz': 9,
#          'Herzog, Rudolf': 4,
#          'Hesse, Hermann': 12,
#          'Hille, Peter': 8,
#          'Himmelbauer, Franz': 4,
#          'Hirschfeld, Georg': 2,
#          'Hoffmann, Camill': 5,
#          'Hofmannsthal, Hugo von [Pseud. Loris]': 10,
#          'Holst, Adolf': 2,
#          'Huch, Ricarda': 32,
#          'Jung, Frida': 2,
#          'Kiesgen, Laurenz': 2,
#          'Klie, Anna': 9,
#          'Knodt, Karl Ernst': 7,
#          'Koch, Maidy': 1,
#          'Kröger, Timm': 3,
#          'Kurz, Isolde': 10,
#          'Kurz, Islode': 1,
#          'Lachmann, Hedwig': 14,
#          'Lasker-Schüler, Else': 7,
#          'Lauff, Josef': 2,
#          'Leppin, Paul': 3,
#          'Liebisch, Rudolf': 2,
#          'Lienhard, Fritz': 7,
#          'Mackay, Henry John': 3,
#          'Marie-Madeleine': 2,
#          'Martens, Rolf Wolfgang': 1,
#          'Meyer, Conrad Ferdinand [Meyer, Konrad Ferdinand; alt. Meier, Conrad Ferdinand]': 12,
#          'Miegel, Agnes': 7,
#          'Mombert, Alfred': 49,
#          'Müller, Hans': 2,
#          'Müller, Klara': 11,
#          'Münchhausen, Börries Freiherr von [alt. Münchhausen, Börries von]': 8,
#          'Nöthig, Theobald': 3,
#          'Ompteda, Georg von [Ompteda, Georg Freiherr von; alt. Ompteda, Georg Frhr. von (G. Egestorff)]': 2,
#          'Paquet, Alfons': 4,
#          'Philipp, Hugo': 1,
#          'Philippi, Fritz': 5,
#          'Piper, Reinhard': 1,
#          'Popp, Wilhelm': 3,
#          'Presber, Rudolf': 2,
#          'Preuschen, Hermione von [alt. Preuschen-Telmann, Hermione von; Preuschen, Hermine von]': 4,
#          'Puttkamer, Alberta von [alt. Puttkamer, Alberta Freiin von; Puttkammer, Alberta von]': 11,
#          'Reder, Heinrich von': 4,
#          'Reicke, Georg': 2,
#          'Renk, Anton': 2,
#          'Renner, Gustav': 7,
#          'Resa, T.': 1,
#          'Reß, Robert': 3,
#          'Rilke, Rainer Maria [alt. Rilke, Rainer-Maria]': 36,
#          'Ritter, Anna': 17,
#          'Roffhack, Albert': 2,
#          'Saar, Ferdinand von': 5,
#          'Schafheitlin, Adolf': 4,
#          'Schanz, Frida': 16,
#          'Scheerbart, Paul': 2,
#          'Scheid, Richard': 2,
#          'Scheuermann, Julie Virginie': 1,
#          'Schickele, René': 2,
#          'Schmitt, Christian': 2,
#          'Schnitzler, Arthur [Schnitzler, Artur]': 2,
#          'Schoenaich-Carolath, Prinz Emil von [alt. Schoenaich-Carolath, Emil zu; Schönaich-Carolath, Prinz Emil von]': 5,
#          'Schüler, Gustav': 13,
#          'Spitteler, Karl': 5,
#          'Stern, Maurice Reinhold von [alt. Stern, Maurice von; Stern, Maurice-Reinhold von]': 5,
#          'Stöber, Fritz': 10,
#          'Stolzenberg, Georg': 10,
#          'Stona, Marie': 5,
#          'Strauß und Torney, Lulu von': 7,
#          'Sudermann, Hermann': 4,
#          'Susman, Margarete [alt. Susman, Margareta]': 1,
#          'Tielo, A. K. T. [Pseud. Mickoleit, Kurt]': 2,
#          'Vanselow, Karl': 3,
#          'Vierordt, Heinrich': 7,
#          'Voigt-Diederichs, Helene': 3,
#          'Vollmoeller, Karl Gustav': 6,
#          'Wallpach, Artur von': 7,
#          'Weber-Lutkrow, Hans': 2,
#          'Weigand, Wilhelm': 17,
#          'Weiser, Karl': 2,
#          'Weiß, Emil Rudolf': 5,
#          'Wertheimer, Paul': 5,
#          'Wiener, Oskar': 3,
#          'Wildberg, Bodo': 4,
#          'Wildenbruch, Ernst von': 11,
#          'Wilhelm, Karl': 2,
#          'Zimmermann, Elsa': 1,
#          'Zimmerman, Elsa': 1,
#          'Zoozmann, Richard': 3,
#          'Zweig, Stefan [Zweig, Stephan]': 6,
#          'George, Stefan [George, Stephan]': 2,
#          'Bonsels, Waldemar': 11,
#          'Brandenburg, Hans': 8,
#          'Isemann, Bernd': 12,
#          'Vesper, Will': 9,
#          'Hartleben, Otto Erich [alt. Hartleben, O. Erich]': 2,
#          'Loens, Hermann': 1,
#          'Vogel, Georg': 1,
#          'Seidel, Heinrich': 2,
#          'Kirchbach, Wolfgang': 12,
#          'Fuchs, Reinhold': 2,
#          'Triepel, Gertrud': 1,
#          'Hartleben, Otto Erich[alt. Hartleben, O. Erich]': 1,
#          'Hartleben, Otto Erich [Hartleben, O. Erich]': 1,
#          'Baumbach, Rudolf': 4,
#          'Christen, Ada [eigtl. Christine Rosalia Friederik, später Christine Rosalia von Neupauer, Christine Rosalia von Breden]': 1,
#          'Gumppenberg, Carl Freiherr von': 1,
#          'Jordan, Wilhelm': 5,
#          'Bruhnsen, Otto': 1,
#          'Puttkamer, Alberta von [Puttkammer, Alberta von; alt. Puttkamer, Alberta Freiin von]': 2,
#          'Leuthold, Heinrich': 6,
#          'Liliencron, Detlev von [alt. Liliencron, Detlev Freiherr von, Liliencron, Detlev Frhr. von]': 3,
#          'Voigt, Paul': 1,
#          'Kitir, Josef': 15,
#          'Hartleben, Erich Otto [alt. Hartleben, O. Erich]': 1,
#          'Hopfen, Hans Ritter von [Hopfen, Hans]': 3,
#          'Herbert, M. [eigtl. Keiter, Therese]': 1,
#          'Waldmüller, Robert [eigtl. Duboc, Charles Edouard]': 1,
#          'Flaischlen, Cäsar [Flaischlen, Caesar]': 2,
#          'Ernst, Adolf Wilhelm': 1,
#          'Hamerling, Robert': 1,
#          'Öhquist, Johannes': 1,
#          'Oswald, J.G.': 1,
#          'Gittermann, Wilhelm': 1,
#          'Grosse, Johannes [eigtl. B. Johannes Grosse]': 1,
#          'Fitger, Arthur': 4,
#          'Backhaus, Wilhelm E.': 1,
#          'Jensen, Wilhelm': 1,
#          'Pfungst, Arthur': 1,
#          'Hartleben, Otto Erich [alt. Hartleben, o. Erich]': 1,
#          'X.X.': 1,
#          'Knussert, Rudolf': 1,
#          'Nietzsche, Friedrich; Koegel, Fritz': 1,
#          'Liliencron, Detlev von [alt. Liliencron, Detlev Freiherr von; Liliencron, Detlev Frhr. von]': 20,
#          'Dauthendey, Max [alt. Dauthendey, Maxim; Dauthendey, Maximilian]': 8,
#          'Calé, Walter': 8,
#          'George, Stefan': 22,
#          'Hofmannsthal, Hugo von [alt. Pseudonym Loris]': 11,
#          'Gebsattel, Marie von [alt. Gebsattel, Marie Freiin von] [alt. Gebsattel, Marie Freiin von]': 4,
#          'Hielscher-Panten, Elsa': 8,
#          'Gareth, M. H. [Pseud. Huch, Margarete]': 15,
#          'Hoechstetter, Sophie': 2,
#          'Grosse, Martha': 4,
#          'Langauf, Margareta': 3,
#          'Susmann, Margarete [alt. Susmann, Margareta; Susman, Margarete]': 13,
#          'Prellwitz, Gertrud': 5,
#          'Pfaff-Joerissen, Elli': 16,
#          'Dransfeld, Hedwig': 7,
#          'Leo, Felicitas': 6,
#          'Franke, Ilse': 6,
#          'Kaiser, Isabella': 2,
#          'Harder, Agnes': 4,
#          'Jung, Frieda': 2,
#          'Frapan, Ilse': 2,
#          'Herbert, M. [Pseud. von Keiter, Therese]': 20,
#          'Puttkammer, Alberta von': 1,
#          'Skorra, Thekla': 3,
#          'Naumann, Dora': 2,
#          'Blüthgen, Clara': 2,
#          'Mayreder, Rosa': 3,
#          'Preuschen, Hermione von [alt. Preuschen-Telmann, Hermine von]': 3,
#          'Rösler, Paula': 6,
#          'Schwabe, Toni': 9,
#          'Schirmacher, Kaethe': 2,
#          'Schanz, Pauline': 5,
#          'Holm, Mia': 1,
#          'Christen, Ada': 2,
#          'Handel-Mazzetti, E. v.': 1,
#          'Gebsattel, Marie von [alt. Gebsattel, Marie Freiin von]': 3,
#          'Schleker, Klara': 2,
#          'Bülow, Frieda von': 2,
#          'Ephraim, M. J. [alt. Ephraim, Marianne J.]': 3,
#          'Zahn, Martha': 2,
#          'Heinemann-Granthoff, Erna': 1,
#          'Funke, Wilhelmine': 4,
#          'Wernicke, Marie': 4,
#          'Eck, Miriam': 7,
#          'Bredig, Katharina': 4,
#          'Hirsch, Elisabeth': 1,
#          'Schirmacher, Käthe': 2,
#          'Mervarid': 1,
#          'Schmidt-Luz, E.': 1,
#          'Handel-Mazzetti, Enrica von [Handel-Mazetti, E. von]': 2,
#          'Heinemann-Grautoff, Erna': 2,
#          'Semmig, Jeanne Berta': 2,
#          'Kaiser, Isabelle': 5,
#          'Bülow, Margarete von [Bülow, Margareta von]': 2,
#          'Krömer, Charlotte': 1,
#          'Grazie, Marie Eugenie delle [Grazie, M. E. delle; alt. Grazie, M. Eug. delle; Grazie, Maria Eugenie delle]': 1,
#          'Ziel, Ernst': 5,
#          'Dörmann, Felix': 18,
#          'Stern, Maurice Reinhold von [Stern, Maurice von; alt. Stern, Maurice-Reinhold von]': 4,
#          'Preuschen, Hermione von [Preuschen-Telmann, Hermine von; alt. Preuschen-Telmann, Hermione von; alt. Preuschen, Hermine von]': 1,
#          'Preuschen-Telmann, Hermine von': 1,
#          'Dauthendey, Max [al. Dauthendey, Maxim;  Dauthendey, Maximilian]': 5,
#          'March, Ottokar Stauff von der': 3,
#          'Petri, Julius': 1,
#          'Hoffmann, Max': 2,
#          'Fischer, H.': 1,
#          'Korn, Carl': 1,
#          'Beutler, Margarete': 2,
#          'Bölitz, Martin': 3,
#          'Bruns, Margarete': 3,
#          'Busse-Palma, Georg': 3,
#          'Collin-Schönfeld, Ernst': 3,
#          'Donath, Adolph': 1,
#          'Forbes-Mosse, Irene': 6,
#          'Hardt, Ernst': 2,
#          'Hardt, Julius': 3,
#          'Herrmann, Emil Alfred': 3,
#          'Huch,Ricarda': 1,
#          'Müller-Rastatt, Karl': 1,
#          'Sauer, Hedda': 3,
#          'Schmitz, Oscar A. H.': 3,
#          'Schoenaich-Carolath, Prinz Emil von [Schönaich-Carolath, Prinz Emil von; alt. Schoenaich-Carolath, Emil zu]': 9,
#          'Schröder, Rudolf Alexander': 1,
#          'Stern, Maurice Reinhold von [alt. Stern, Maurice von; Stern, Maurice-Reinhold]': 3,
#          'Susmann, Margarete [Susman, Margarete; Susmann, Margareta]': 6,
#          'Tielo, A. K. T. [Pseud. von Mickoleit, Kurt]': 1,
#          'Wedekind, Frank': 5,
#          'Zweig, Stefan [Stephan]': 3,
#          'Linke, Oscar': 15,
#          'Lemmermayer, Fritz': 5,
#          'Bohne, Johannes': 7,
#          'Hückinghaus, Karl August': 10,
#          'Jerschke, Oskar': 9,
#          'Hart, Heinrich': 12,
#          'Hansen, Oskar': 7,
#          'Hartleben, Otto Erich [Hartleben, Erich; alt. Hartleben, O. Erich]': 7,
#          'Hugenberg, Alfred': 4,
#          'Gradnauer, Georg': 1,
#          'Kralik, Richard': 9,
#          'Winter, Joseph': 7,
#          'Jahn, Hermann Eduard': 7,
#          'Bleibtreu, Carl [alt. Bleibtreu, Karl]': 8,
#          'E. Albrecht.': 1,
#          'Ludwig Bauer.': 4,
#          'Karl Beck.': 3,
#          'Maximilian Beilhack.': 1,
#          'Michel Berend.': 5,
#          'Adolf Böttger.': 8,
#          'W. Clemen.': 7,
#          'Georg Friedrich Daumer.': 5,
#          'Bernhard Endrulat.': 7,
#          'Johann Georg Fischer.': 20,
#          'Paul Fischer.': 2,
#          'Theodor Fontane.': 1,
#          'Marie Förster.': 5,
#          'Ferdinand Freiligrath.': 11,
#          'A. Galster.': 3,
#          'Amara George.': 5,
#          'Rudolf Gottschall.': 11,
#          'Ferdinand Gregorovius.': 1,
#          'Wilhelm Grimme.': 4,
#          'J. Virgil Grohmann.': 1,
#          'Julius Große.': 15,
#          'Anastasius Grün.': 22,
#          'Moriz Hartmann.': 1,
#          'Friedrich Hebbel.': 9,
#          'Karl Heigel.': 2,
#          'Clara Held.': 2,
#          'J. Herzfelder.': 2,
#          'Nicolaus Hocker.': 1,
#          'Hoffmann von Fallersleben.': 13,
#          'J. M. Hutterus.': 6,
#          'Ludwig Ißleib.': 3,
#          'Alexander Kaufmann.': 12,
#          'Gottfried Keller.': 3,
#          'Emanuel Klopsch.': 1,
#          'Hermann Köpert.': 2,
#          'Emil Kuh.': 4,
#          'Richard Kunisch.': 1,
#          'Heinrich Landesmann.': 1,
#          'Cäsar von Lengerke.': 1,
#          'Feodor Löwe.': 13,
#          'Hermann Marggraff.': 10,
#          'German Mäurer.': 2,
#          'S. Meyer.': 1,
#          'Melchior Meyr.': 7,
#          'Wolfgang Müller von Königswinter.': 1,
#          'Karl Mund.': 2,
#          'Eugen Obermayer.': 2,
#          'Hermann Oelschläger.': 3,
#          'Kurt Oswalt.': 1,
#          'Friedrich Otte.': 1,
#          'Gustav Pfarrius.': 6,
#          'Ludwig Pfau.': 10,
#          'Friedrich Pichler.': 1,
#          'Robert Prutz.': 28,
#          'Gustav Reinhart.': 1,
#          'Robert Reinick.': 13,
#          'Gustav Reisewitz.': 2,
#          'Julius Rodenberg.': 19,
#          'Hermann Rollet.': 1,
#          'Ernst Victor Schellenberg.': 1,
#          'Erwin Schlieben.': 1,
#          'Karl Schmitt.': 1,
#          'Gottlob Schneider.': 5,
#          'Karl Schönborn.': 1,
#          'Adolf Schults.': 6,
#          'Ernst Arthur Seemann.': 2,
#          'Friedrich Staufing.': 1,
#          'Theodor Storm.': 12,
#          'Adolf Strodtmann.': 8,
#          'Julius Sturm.': 20,
#          'Albert Träger.': 6,
#          'Heinrich von Treitschke.': 1,
#          'Nina von Waldburg.': 5,
#          'Max Waldstein.': 1,
#          'Oskar von Warkotsch.': 1,
#          'Feodor Wehl.': 2,
#          'Karl Weishaupt.': 1,
#          'Antonie Zander.': 4,
#          'unknown': 18,
#          'August Kopisch': 4,
#          'Friedrich Schulz': 1,
#          'Ludwig I.': 4,
#          'Ludwig Uhland': 5,
#          'Detlev Freiherr von Liliencron': 4,
#          'Otto Ludwig': 1,
#          'August Friedrich Langbein': 3,
#          'Friedrich Wilhelm Gotter': 1,
#          'Franz Graf Pocci': 1,
#          'Christian Graf zu Stolberg': 1,
#          'Justinus Kerner': 1,
#          'Christian Morgenstern': 4,
#          'Hugo von Hofmannsthal': 1,
#          'Moritz Graf von Strachwitz': 2,
#          'Kaspar Friedrich Lossius': 1,
#          'Alfred Meißner': 3,
#          'Friedrich Rückert': 7,
#          'Hugo Freiherr von Blomberg': 1,
#          'Johann August Apel': 2,
#          'Carl Philipp Conz': 2,
#          'Joseph Freiherr von Eichendorff': 4,
#          'August Wilhelm v. Schlegel': 1,
#          'Ernst Moritz Arndt': 2,
#          'Adelbert von Chamisso': 2,
#          'Hermann von Gilm': 1,
#          'Anastasius Grün': 2,
#          'Heinrich von Reder': 2,
#          'Friedrich Baron de la Motte Fouqué': 2,
#          'Friedrich von Matthissen': 1,
#          'Karl Friedrich Wetzel': 1,
#          'Achim von Arnim': 3,
#          'Heinrich Christian Boie': 1,
#          'Johann Heinrich Jung': 2,
#          'Maximilian Freiherr von Oer': 1,
#          'Adolf Böttger': 1,
#          'Felix Dahn': 2,
#          'Friedrich Hebbel': 4,
#          'Georg Philipp Schmidt': 1,
#          'Wolfgang Müller von Königswinter': 1,
#          'Eduard Mörike': 3,
#          'Otto Heinrich Graf von Loeben': 1,
#          'Günther von Göckingk': 1,
#          'Johann Gottfried Seume': 1,
#          'Gustav Freytag': 1,
#          'Heinrich von Kleist': 1,
#          'August Stöber': 2,
#          'Adolf Ludwig Stöber': 1,
#          'Adolf Friedrich Graf von Schack': 1,
#          'Helmina von Chezy': 1,
#          'Gustav Schwab': 1,
#          'August Schnezler': 2,
#          'Ernst Raupach': 1,
#          'Alexander Graf von Württemberg': 1,
#          'Friedrich Leopold Graf zu Stollberg': 2,
#          'Annette von Droste-Hülshoff': 1,
#          'Ferdinand von Saar': 1,
#          'Nikolaus Lenau': 2,
#          'Novalis': 1,
#          'Friedrich von Schlegel': 1,
#          'Wilhelm A. Schreiber': 1,
#          'Theodor Fontane': 2,
#          'Ludwig Tieck': 1,
#          'Magnus Gottfried Lichtwer': 1,
#          'Hermann Lingg': 3,
#          'Ignaz Franz Castelli': 1,
#          'Emanuel Geibel': 2,
#          'Caroline von Günderode': 1,
#          'Nicolaus Becker': 1,
#          'Joseph Friedrich Engelschall': 1,
#          'Victor von Strauß und Torney': 1,
#          'Friedrich Gottlieb Klopstock': 1,
#          'Karl Gerok': 1,
#          'Artur Fitger': 1,
#          'Ferdinand Freiligrath': 1,
#          'Hermann Löns': 1,
#          'Gottfried Kinkel.': 8,
#          'Alfred Meißner.': 9,
#          'Wilhelm Dunker.': 2,
#          'Franz Dingelstedt.': 7,
#          'Angust Schnezler.': 1,
#          'Robert Waldmüller.': 2,
#          'Franz v. Gaudy [Franz Freiherr Gaudy].': 2,
#          'Joseph Christian v. Zedlitz [J. C. Freiherr von Zedlitz].': 1,
#          'Friedrich Rückert.': 27,
#          'Heinrich Uhse.': 2,
#          'Carl Siebel.': 1,
#          'Robert Waldmuller': 1,
#          'Ludwig Uhland.': 19,
#          'Moritz Hartmann.': 7,
#          'Clotilde von Schwarzkoppen.': 2,
#          'Dilia Helena.': 2,
#          'Julius Hammer.': 16,
#          'C. J. Ph. Spitta.': 7,
#          'Max von Schenkendorf.': 1,
#          'Ernst [Pseud. f. Matthias Jacob Schleiden].': 1,
#          'Schiller.': 6,
#          'Justinus Kerner.': 10,
#          'K. E. Ebert.': 6,
#          'Annette v. Droste-Hülshoff [Anette v. Droste-Hülshof]': 1,
#          'Georg Herwegh.': 3,
#          'Joseph v. Eichendorff [J. Freiherr v. Eichendorff].': 1,
#          'Ernst Schulze.': 3,
#          'Carl Dräxler-Manfred.': 3,
#          'August Schnezler.': 1,
#          'J. B. von Albertini.': 1,
#          'Otto Roquette.': 9,
#          'E. M. Arndt.': 4,
#          'Nicolaus Lenau.': 11,
#          'Luise Hensel.': 2,
#          'Henrich Uhse': 1,
#          'Franz v. Kobell.': 1,
#          'Platen.': 6,
#          'Annette v. Droste-Hülshoff (Anette v. Droste-Hülshof).': 2,
#          'Goethe.': 17,
#          'Klaus Groth (Uebertragen v. A. v. Winterfeld).': 1,
#          'Dranmor.': 1,
#          'J. Ch. Frhr. v. Zedlitz': 1,
#          'Reinhold Mund.': 1,
#          'Friedrich Hölderlin.': 4,
#          'Ernst Schulze': 2,
#          'Platen': 1,
#          'Schiller': 2,
#          'Cäsar v. Lengerke.': 1,
#          'Goelhe.': 1,
#          'Joseph Frhr. v. Eichendorff.': 13,
#          'Ernst.': 3,
#          'Robert Reinick': 2,
#          'Eduard Ferrand.': 2,
#          'Schmidt von Lübeck.': 1,
#          'Nicolaus Lenau': 1,
#          'Hoffmann von Fallersleben': 3,
#          'Carl Mayer.': 2,
#          'Joseph Frhr. v. Eichendorff': 2,
#          'Ritter von Leitner.': 2,
#          'Lebrecht Dreves.': 1,
#          'Wolfgang Muller.': 1,
#          'Gustav Pfizer': 1,
#          'Friedrich v. Sallet.': 1,
#          'Adolph Stöber.': 1,
#          'Luise v. Ploennies.': 2,
#          'Julius Mosen.': 4,
#          'Moritz Hartmann': 1,
#          'C. F. Scherenberg.': 1,
#          'Lndwig Pfau': 1,
#          'Moritz Graf Strachwitz.': 3,
#          'Julius Rodenberg': 1,
#          'Mathilde Quednow.': 2,
#          'Paul Wigand.': 1,
#          'Friedrich Halm.': 8,
#          'Heinrich Heine.': 21,
#          'Albert Traeger.': 14,
#          'Friedrich Bodenstedt': 1,
#          'R. E. Wegener.': 1,
#          'J. G. Fischer.': 2,
#          'Wilhelm Hertz.': 9,
#          'Wolfgang Müller.': 9,
#          'Franz Kugler.': 4,
#          'Leopold Schefer.': 3,
#          'Luise v. Ploennies': 1,
#          'Heinrich Silesius.': 3,
#          'Heinrich Silesius': 1,
#          'Cart Herloßsohn.': 1,
#          'Adalbert v. Chamisso.': 4,
#          'Moritz Harimann.': 1,
#          'Carl Herloßsohn.': 2,
#          'Betty Paoli.': 3,
#          'Armin Werther.': 1,
#          'Eduard Tempeltey.': 7,
#          'Julius Mosen': 1,
#          'Friedrich Ruperti.': 3,
#          'Christian Hoeppl.': 1,
#          'Heinrich Heine': 1,
#          'Otto Prechtler.': 2,
#          'Ludwig Tieck.': 2,
#          'Theodor Körner.': 5,
#          'Adolph Böttger.': 2,
#          'J. Ch. Frhr. v. Zedlitz.': 2,
#          'Oscar Frhr. v. Redwitz.': 13,
#          'N.N.[Altrheinisches Liedlein].': 1,
#          'Clemens Brentano.': 2,
#          'N.N. [aus: Des Knaben Wunderhorn]': 16,
#          'Wilhelm Grimme': 1,
#          'N.N. [aus: Des Knaben Wunderhorn].': 1,
#          'Wilhelm Hauff.': 2,
#          'Eduard Mörike.': 6,
#          'Wunderhorn.': 1,
#          'Adolph Schults.': 4,
#          'Frhr. J. Ch. v. Zedlitz.': 1,
#          'Ferdinand Stolle.': 5,
#          'Georg Scheurlin.': 7,
#          'Eduard von Bauernfeld.': 1,
#          'N.N. [Volkslied]': 2,
#          'Victor Strauß.': 1,
#          'Rudolph Reiter.': 1,
#          'Franz Frhr. Gaudy.': 1,
#          'Abert Traeger.': 1,
#          'Adalbert von Chamisso.': 5,
#          'Anastasiuns Grun.': 1,
#          'Paut Heyse.': 1,
#          'Elisabeth Kulmann.': 1,
#          'A. E. Fröhlich.': 1,
#          'Georg Herwegh': 1,
#          'J. G. Seidl.': 3,
#          'Julius v. Rodenberg.': 1,
#          'Adolph Strodtmann.': 1,
#          'Karl Simrock.': 2,
#          'Rudolph Gottschall.': 1,
#          'Annette v. Droste-Hülshoff [Anette v. Droste-Hülshof].': 3,
#          'Theodor Körner': 1,
#          'Max v. Schenkendorf.': 1,
#          'Karl v Holtei.': 1,
#          'Gustav Schwab.': 4,
#          'Goethe': 1,
#          'Luise Brachmann.': 1,
#          'Ernst Langrehr.': 1,
#          'Fr. de la Motte Fouqué.': 2,
#          'Friedrich von Sallet': 1,
#          'Ernst Pfeilschmidt.': 3,
#          'S. A. Mahlmann.': 1,
#          'F. A. Krummacher.': 1,
#          'Ludwig Schnabel.': 1,
#          'K. R. Tanner.': 1,
#          '. Joseph Frhr. v. Eichendorff.': 1,
#          'S. Ch Pape.': 1,
#          'Ernst Pfeilschmidt': 1,
#          'Alexis Adolphi.': 4,
#          'Hermann Allmers.': 3,
#          'Theodor Apel.': 4,
#          'Julius Bamme.': 4,
#          'Otto Banck.': 8,
#          'Eduard Bauernfeld.': 9,
#          'Adolf Bekk.': 3,
#          'August Becker.': 5,
#          'Julius Becker.': 4,
#          'Julius Bercht.': 6,
#          'Moritz Berndt.': 1,
#          'Gustav Berthold.': 3,
#          'riedrich Bodenstedt.': 9,
#          'Adolf Bube.': 6,
#          'Julie Burow.': 2,
#          'Marie Clausnitzer-Hennes.': 3,
#          'Peter Cornelius.': 4,
#          'Theodor Cretzenach.': 2,
#          'Kelix Dahn.': 3,
#          'ranz Dingelstedt.': 3,
#          'Carl Dräxler⸗Manfred.': 7,
#          'Martin Drucker.': 4,
#          'Wilhelm Duncker.': 1,
#          'Egon Ebert.': 5,
#          'Ludwig Eckardt.': 1,
#          'Emil Edel.': 4,
#          'Elfried von Taura.': 3,
#          'Carl Gärtner.': 4,
#          'Adolf Glaser.': 1,
#          'Wolfgang v. Goethe.': 1,
#          'Moritz Grandjean.': 1,
#          'F. W. Gubitz.': 2,
#          'Südhauch und Nordsturm.': 4,
#          'Kriedrich Hebbel.': 5,
#          'J. M. Hessemer.': 2,
#          'Rudolf Hirsch.': 3,
#          'Edmund Höfer.': 3,
#          'Hermann Hölty.': 1,
#          'Christian Höppl.': 4,
#          'Hoffmann v. Fallersleben.': 2,
#          'Carl v. Holtei.': 1,
#          'Hans Hopfen.': 6,
#          'oritz Horn.': 2,
#          'Eduard Kauffer.': 9,
#          'Gottfried eller.': 6,
#          'Theobald Kerner.': 4,
#          'Ernst Koch.': 3,
#          'Gustav Kühne.': 7,
#          'Carl Gottfried Ritter v. Leitner.': 3,
#          'Hermann embcke.': 1,
#          'Heinrich ier.': 1,
#          'Gustav von Mepern.': 1,
#          'Emil Ueubürger.': 2,
#          'Anton Uiendorf.': 3,
#          'Hugo Oelbermann.': 4,
#          'Theodor Oelckers.': 4,
#          'Adolf Peters.': 4,
#          'Luise v. Plönnies.': 4,
#          'Josef Pollhammer.': 7,
#          'Oskar von Redwitz.': 6,
#          'Rothenburger Einsiedler.': 4,
#          'Friedrich v. Schack.': 6,
#          'Christian Schad.': 2,
#          'Wilhelm Schäfer.': 2,
#          'Julius Schanz.': 3,
#          'Ceopold Schefer.': 7,
#          'Georg Scherer.': 10,
#          'Arnold Schlönbach.': 6,
#          'Julius Schröer.': 2,
#          'Carl Schultes.': 3,
#          'Carl Scriba.': 2,
#          'Ludwig Seeger.': 8,
#          'Carl Biebel.': 6,
#          'Berthold Sigismund.': 4,
#          'M. Solitaire.': 1,
#          'Friedrich Spielhagen.': 2,
#          'Heinrich Steinheuer.': 5,
#          'Carl Stelter.': 2,
#          'Ludwig Storch.': 3,
#          'Tannengrün und Edelweiß.': 6,
#          'Titus Ulrich.': 7,
#          'Gisbert Freiherr von Vincke.': 1,
#          'Johann Uepomuk Vogl.': 3,
#          'obert Waldmüllex.': 5,
#          'Rhingulph Eduard Wegener.': 3,
#          'Keodor Wehl.': 2,
#          'Joseph Weilen.': 1,
#          'Erwin Wester.': 3,
#          'Wilfried von der Ueun.': 3,
#          'P. J. willatzen.': 2,
#          'Leonhart Wohlmuth.': 3,
#          'August Wolf.': 4,
#          'Wilibald Wulff.': 6,
#          'Georg Schmidt.': 1,
#          'Friedrich Adolf Krummacher.': 1,
#          'Ernst Moritz Arndt.': 3,
#          'Novalis [Pseud. f. Georg Philipp Friedrich von Hardenberg].': 1,
#          'Karl Lappe.': 1,
#          'Adalbert von Chamisso [auch: Adelbert von Chamisso].': 4,
#          'Max von Schenkendorf [auch: Maximilian von Schenkendorf].': 2,
#          'Karl Mayer.': 2,
#          'Joseph Freiherr von Eichendorff.': 8,
#          'Johann David Friedrich Schottin.': 1,
#          'Christian Freiherr von Zedlitz [auch: Joseph Christian von Zedlitz].': 2,
#          'Carl Theodor Körner.': 1,
#          'Heinrich Ludwig Theodor Giesebrecht.': 1,
#          'August Graf von Platen [auch: August Graf von Platen-Hallermünde].': 5,
#          'Annette von Droste-Hülshoff.': 1,
#          'August Heinrich Hoffmann von Fallersleben.': 4,
#          'Albert Knapp.': 1,
#          'Leberecht Uhlich.': 1,
#          'August Kopisch.': 1,
#          'Franz Freiherr von Gaudy.': 1,
#          'Karl Gottfried Ritter von Leitner.': 1,
#          'Philipp Heinrich Welcker.': 2,
#          'Karl Johann Philipp Spitta.': 2,
#          'Nicolaus Lenau [auch: Nikolaus Lenau, Pseud. f. Nikolaus Franz Niembsch Edler von Strehlenau].': 6,
#          'Johann Nepomuk Vogl.': 1,
#          'Johann Gabriel Seidl.': 1,
#          'Anastasius Grün [Pseud. f. Anton Alexander Graf von Auersperg].': 2,
#          'Wilhelm Wackernagel.': 2,
#          'Ludwig Ferdinand Stolle.': 1,
#          'Johann Wilhelm Schäfer.': 1,
#          'Friedrich Wilhelm Rogge.': 1,
#          'Karl Ziegler.': 2,
#          'Friedrich von Sallet.': 1,
#          'Eduard Ferrand [Pseud. f. Eduard Schulz].': 3,
#          'Carl Gerok.': 4,
#          'Adolf Friedrich von Schack.': 4,
#          'Lebrecht Drewes [auch: Leberecht Dreves].': 1,
#          'August Heinrich Theodor Schwartzkopff.': 1,
#          'George Hesekiel.': 1,
#          'Julius von der Traun [Pseud. f. Julius Schindler].': 1,
#          'Martin [Pseud. f. Martin Hugo Lange].': 2,
#          'Max Moltke.': 1,
#          'Wilhelm Osterwald.': 2,
#          'Hugo Freiherr von Blomberg.': 2,
#          'Ernst Fischer.': 1,
#          'Siegfried Kapper.': 1,
#          'Moritz Graf von Strachwitz.': 1,
#          'Max Waldau [Pseud. f. Richard Georg Spiller von Hauenschild].': 1,
#          'Josef Sami Tauber [auch: Joseph Samuel Tauber, Josef Samuel Tauber].': 1,
#          'Robert Waldmüller [Pseud. f. Charles Edouard Duboc].': 2,
#          'Peter Johann Willatzen.': 8,
#          'Conrad Ferdinand Meyer.': 3,
#          'Joseph Victor Scheffel.': 3,
#          'Richard Pohl.': 1,
#          'Karl Friedrich Bartsch.': 1,
#          'Adolf Wilbrandt.': 1,
#          'Heinrich Freimann [Pseud. f. Heinrich Bauerreiß].': 1,
#          'Theodor Winkler.': 1,
#          'Ludwig Salomon.': 1,
#          'Max Kalbeck.': 1,
#          'Liliencron, Detlev von [Liliencron, Detlev Freiherr von; alt. Liliencron, Detlev Frhr. von]': 23,
#          'Ompteda, Georg von [Ompteda, Georg Frhr. von (Pseud. G. Egestorff); alt. Ompteda, Freiherr von]': 1,
#          'Heilborn, E.': 1,
#          'Panizza, Oskar': 1,
#          'Jacobowski, Ludwig [Jakobowsky, Ludwig]': 3,
#          'Grazie, Marie Eugenie delle [alt. Grazie, M. E. delle; Grazie, M. Eug. delle; Grazie, Maria Eugenie delle]': 2,
#          'Rosmer, Ernst': 1,
#          'Mann, L. H.': 1,
#          'Wolzogen, Ernst Freiherr von': 1,
#          'Ernst, Otto': 2,
#          'Lothar, Rudolf': 1,
#          'Brand, Julius': 1,
#          'Alberti, Conrad': 3,
#          'Tovote, Heinz': 1,
#          'Seidel, Robert': 1,
#          'Bernstein, Max': 5,
#          'Wohlmuth, Alois': 10,
#          'Towska, Kory': 3,
#          'Dehmel, Richard [Orig. von Li-tai-po]': 1,
#          'Dehmel, Richard [Orig. von Villon]': 1,
#          'Dehmel, Richard [Orig. von Verlain, Paul]': 1,
#          'Dörmann, Felix [Orig. von Baudelaire, Charles]': 1,
#          'Hartleben, Otto Erich [alt. Hartleben, O. Erich; Hartleben, Erich] [Orig. von Giraud, Albert]': 4,
#          'Lachmann, Hedwig [Orig. von Swinburne, Ch. A.]': 1,
#          'Borngräber, Otto': 5,
#          'Braun, Felix': 9,
#          'Fontana, Oscar Maurus': 6,
#          'Friedrich, Paul': 13,
#          'Goldschmidt, Kurt Walter': 9,
#          'Günther, Hans von': 1,
#          'Kramer, Adolf': 7,
#          'Lieber, Alfred von': 6,
#          'Lissauer, Ernst': 7,
#          'Robertus, Gerda von': 6,
#          'Silbergleit, Artur': 6,
#          'Willecke, Kurt Hans': 7,
#          'Saar, Ferdinand': 10,
#          'David, Jakob Julius [David, J. J.]': 8,
#          'Herold, Franz': 6,
#          'Levetzow, Karl Michael Freiherr von [Levetzow, Carl Freiherr von]': 7,
#          'Hagenauer, Arnold': 9,
#          'Klob, Karl Maria [Klob, Carl M.]': 7,
#          'Anzengruber, Ludwig': 1,
#          'Arent, Wilhelm': 2,
#          'Blüthgen, Victor': 1,
#          'Bodman, Emanuel von [alt. Bodmann, Emanuel von; Bodman, Emanuel Freiherr von]': 2,
#          'Claar, Emil': 1,
#          'Cornelius, Peter': 2,
#          'Dahn, Felix': 2,
#          'David, Jakob Julius [David, J.J.]': 2,
#          'Doehler, Gottfried': 2,
#          'Fehrs, J.G.': 1,
#          'Fischer, J.G. [alt. Fischer, Johann Georg]': 12,
#          'Fritsche, Paul': 1,
#          'Gerok, Karl': 3,
#          'Gilm, Hermann von': 2,
#          'Große, Julius': 1,
#          'Groth, Klaus': 2,
#          'Grotthuß, Jeannot Emil Freiherr von [alt. Grotthuss, J. E. Freih. von]': 1,
#          'Hertz, Wilhelm': 2,
#          'Heyse, Paul': 2,
#          'Holm, Kurt': 2,
#          'Hörmann, Angelika von': 1,
#          'Jacobowski, Ludwig': 5,
#          'Kaufmann, Alexander': 1,
#          'Keller, Gottfried': 4,
#          ...})

# %%
l = 0
for i, row in text.iterrows():
    l+= len(row.text.split())
    if len(row.text.split()) > 50000:
        print("text", i, "länge: ",len(row.text.split()))
print(l)
# Out:
# text epik_lemma_brentano_rosenkranz länge:  56032
# text epik_lemma_may_wuste länge:  160445
# text epik_lemma_heiberg_frau länge:  61285
# text epik_lemma_keller_seldywla1 länge:  89249
# 942434

# %%
l = 0
d={}
for i, row in prosa.iterrows():
    l+= len(row.text.split())
    d[i] = len(row.text.split())
print(sorted(d.items()))
print(l)
# Out:
# [('achleitner_bergrichters', 45648), ('arnim_isabella', 39736), ('bonsels_maja', 36707), ('brentano_rosenkranz', 54911), ('falke_durchschnitt', 32609), ('fischer_gustavsverirrungen', 20756), ('fontane_birnbaum', 32758), ('gerstacker_reise', 36760), ('goethe_faust1', 30629), ('heiberg_frau', 58835), ('hesse_knulp', 25777), ('hoffmann_topf', 29836), ('kafka_verwandlung', 19248), ('keller_seldywla1', 88457), ('lewald_clementine', 34092), ('mann_tristan', 14154), ('may_wuste', 147862), ('meyer_richterin', 22357), ('sapper_kriegsbuchlein', 25001), ('schnitzler_tanzerin', 33685), ('spyri_heidi1', 37326), ('wassermann_vierzig', 42213)]
# 909357

# %%
lyrik = pd.read_csv('meta_lyrik.tsv',sep='\t')
lyrik = lyrik.sort_values(by='Autor')
# lyrik.drop_duplicates(subset=['Autor','Titel'], inplace=True)
duplicateRowsDF = lyrik[lyrik.duplicated(['Autor', 'Titel'], keep=False)]
IDS = list(duplicateRowsDF.ID)

# %%
import os.path
from os import path
import random

path = '../corpus/segmente/segmenteepik_1000/'
filelist = []
for file in os.listdir(path):
        if file.endswith('.txt'):
            filelist.append(file)
            
sampled_list = random.sample(filelist, 250)
for i in sampled_list:
    if os.path.exists('../corpus/segmente/segmenteepik_1000/' + i):
        os.remove('../corpus/segmente/segmenteepik_1000/' + i)
