# %%
import pandas as pd
import numpy as np
#from nltk.corpus import stopwords
import seaborn as sns
import matplotlib.pyplot as plt
import regex as re 
import glob
from collections import Counter

from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
# %matplotlib inline

# %%
pd.read_csv('../corpus/corpora/epik/epik.csv')
# Out:
#                                Unnamed: 0  \
# 0                 epik_lemma_mann_tristan
# 1          epik_lemma_brentano_rosenkranz
# 2           epik_lemma_wassermann_vierzig
# 3            epik_lemma_lewald_clementine
# 4          epik_lemma_schnitzler_tanzerin
# 5                 epik_lemma_bonsels_maja
# 6                    epik_lemma_may_wuste
# 7           epik_lemma_falke_durchschnitt
# 8                 epik_lemma_spyri_heidi1
# 9                epik_lemma_goethe_faust1
# 10  epik_lemma_fischer_gustavsverirrungen
# 11              epik_lemma_arnim_isabella
# 12               epik_lemma_hoffmann_topf
# 13            epik_lemma_fontane_birnbaum
# 14     epik_lemma_achleitner_bergrichters
# 15       epik_lemma_sapper_kriegsbuchlein
# 16           epik_lemma_kafka_verwandlung
# 17                epik_lemma_heiberg_frau
# 18                 epik_lemma_hesse_knulp
# 19            epik_lemma_gerstacker_reise
# 20            epik_lemma_keller_seldywla1
# 21             epik_lemma_meyer_richterin
#
#                                                  text  \
# 0   tristan von thomas mann hier sein > einfried <...
# 1   clemens brentano herausgeben und einleiten von...
# 2   die mann von vierzig jahr eine klein roman von...
# 3   fanny lewald clementine erste capitel also wei...
# 4   die griechisch tänzerin und andere novelle von...
# 5   die biene maja und ihr abenteuer von dies buch...
# 6   durch wüste und harem reiseerlebnis von carl m...
# 7   aus die durchschnitt roman von gustav falke ha...
# 8   johanna spyri heidi können brauchen   was es l...
# 9   faust   die tragödie erst teil johann wolfgang...
# 10  caroline auguste fischer gustav verirrung eine...
# 11  isabella von ägypten achim von arnim kaiser ka...
# 12  die golden topfen von e t a  hoffmann   mit @c...
# 13  theodor fontane unter+die birnbaum erst kapite...
# 14  bergrichters erdenwallen hochlandsroman von ar...
# 15  kriegsbüchlein für unser kind von agnes sapper...
# 16  die verwandlung von franz kafka i   als gregor...
# 17  eine vornehm frau   von hermann heiberg   @car...
# 18  knulp drei geschichte aus die leben knulps von...
# 19  herr mahlhuber die reiseabenteuer   erzählung ...
# 20  gottfried keller die leute von seldwyla erste ...
# 21  die richterin novelle conrad ferdinand meyer e...
#
#                                        ID       Autor               Titel
# 0                 epik_lemma_mann_tristan        mann             tristan
# 1          epik_lemma_brentano_rosenkranz    brentano          rosenkranz
# 2           epik_lemma_wassermann_vierzig  wassermann             vierzig
# 3            epik_lemma_lewald_clementine      lewald          clementine
# 4          epik_lemma_schnitzler_tanzerin  schnitzler            tanzerin
# 5                 epik_lemma_bonsels_maja     bonsels                maja
# 6                    epik_lemma_may_wuste         may               wuste
# 7           epik_lemma_falke_durchschnitt       falke        durchschnitt
# 8                 epik_lemma_spyri_heidi1       spyri              heidi1
# 9                epik_lemma_goethe_faust1      goethe              faust1
# 10  epik_lemma_fischer_gustavsverirrungen     fischer  gustavsverirrungen
# 11              epik_lemma_arnim_isabella       arnim            isabella
# 12               epik_lemma_hoffmann_topf    hoffmann                topf
# 13            epik_lemma_fontane_birnbaum     fontane            birnbaum
# 14     epik_lemma_achleitner_bergrichters  achleitner        bergrichters
# 15       epik_lemma_sapper_kriegsbuchlein      sapper      kriegsbuchlein
# 16           epik_lemma_kafka_verwandlung       kafka         verwandlung
# 17                epik_lemma_heiberg_frau     heiberg                frau
# 18                 epik_lemma_hesse_knulp       hesse               knulp
# 19            epik_lemma_gerstacker_reise  gerstacker               reise
# 20            epik_lemma_keller_seldywla1      keller           seldywla1
# 21             epik_lemma_meyer_richterin       meyer           richterin

# %%
z = pd.read_csv('../results/delta/fontane/zscores_fontane.csv')
# ind = []
# for i, row in z.iterrows():
#     ind.append(str('lyrik_' + row['Unnamed: 0'].split('_')[2] + '_' + row['Unnamed: 0'].split('_')[3]))
z.index = list(z['Unnamed: 0'])
z.drop('Unnamed: 0', axis=1, inplace=True)
# z.to_csv('../results/delta/zscores_lyrik.csv')
z
# Out:
#                                                       in+die      herz  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.572996 -0.374771
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.572996 -0.374771
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.572996 -0.374771
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  0.313154  4.724450
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.572996 -0.374771
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.253795  0.005841
# autoren_lyrik_lemma_Fontane_Prolog                 -0.572996 -0.374771
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    0.756228 -0.374771
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.524142 -0.374771
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.572996 -0.374771
#
#                                                       zu+die    an+die  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.357604 -0.297227
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.357604 -0.297227
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.357604 -0.297227
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.357604 -0.297227
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.357604 -0.297227
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.176422 -0.297227
# autoren_lyrik_lemma_Fontane_Prolog                 -0.357604 -0.297227
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    1.788769 -0.297227
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.357604  0.504016
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.357604 -0.297227
#
#                                                          alt    stehen  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.334234 -0.207624
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.334234 -0.207624
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.334234 -0.207624
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.334234 -0.207624
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.334234  1.124953
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion               -0.053774  0.225941
# autoren_lyrik_lemma_Fontane_Prolog                 -0.334234 -0.207624
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    1.920233 -0.207624
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.334234 -0.207624
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  2.525090 -0.207624
#
#                                                       liegen     still  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.261117 -0.247157
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.261117 -0.247157
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.261117 -0.247157
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  1.536266 -0.247157
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.261117 -0.247157
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion                0.074280 -0.247157
# autoren_lyrik_lemma_Fontane_Prolog                 -0.261117 -0.247157
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.261117 -0.247157
# autoren_lyrik_lemma_fontane_Hastingsfeld            0.851548 -0.247157
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.261117 -0.247157
#
#                                                        glück      kind  ...  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.193487 -0.202139  ...
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.193487 -0.202139  ...
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.193487 -0.202139  ...
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  1.220819 -0.202139  ...
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.193487 -0.202139  ...
# ...                                                      ...       ...  ...
# autoren_lyrik_lemma_fontane_Religion               -0.193487  0.111566  ...
# autoren_lyrik_lemma_Fontane_Prolog                 -0.193487 -0.202139  ...
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.193487 -0.202139  ...
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.193487 -0.202139  ...
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  1.151828 -0.202139  ...
#
#                                                     schwalbe    winken  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.088334 -0.096148
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.088334 -0.096148
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.088334 -0.096148
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.088334 -0.096148
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.088334 -0.096148
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion               -0.088334 -0.096148
# autoren_lyrik_lemma_Fontane_Prolog                 -0.088334 -0.096148
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.088334 -0.096148
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.088334 -0.096148
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  9.504551 -0.096148
#
#                                                         soso     hecke  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.046929 -0.053896
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.046929 -0.053896
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.046929 -0.053896
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.046929 -0.053896
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.046929 -0.053896
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion               -0.046929 -0.053896
# autoren_lyrik_lemma_Fontane_Prolog                 -0.046929 -0.053896
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.046929 -0.053896
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.046929 -0.053896
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.046929 -0.053896
#
#                                                          nest     frack  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben          25.624011 -0.084956
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der...  -0.051738 -0.084956
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre...  -0.051738 -0.084956
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi...  -0.051738 -0.084956
# autoren_lyrik_lemma_fontane_König Karl der Zwei...  -0.051738 -0.084956
# ...                                                       ...       ...
# autoren_lyrik_lemma_fontane_Religion                -0.051738 -0.084956
# autoren_lyrik_lemma_Fontane_Prolog                  -0.051738 -0.084956
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz    -0.051738 -0.084956
# autoren_lyrik_lemma_fontane_Hastingsfeld            -0.051738 -0.084956
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc...  -0.051738 -0.084956
#
#                                                         rute  gelächter  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.046121   -0.04165
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.046121   -0.04165
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.046121   -0.04165
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.046121   -0.04165
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.046121   -0.04165
# ...                                                      ...        ...
# autoren_lyrik_lemma_fontane_Religion               -0.046121   -0.04165
# autoren_lyrik_lemma_Fontane_Prolog                 -0.046121   -0.04165
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.046121   -0.04165
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.046121   -0.04165
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.046121   -0.04165
#
#                                                     zuzeiten  hamilton
# autoren_lyrik_lemma_Fontane_Die zwei Raben         -0.065082 -0.041647
# autoren_lyrik_lemma_Fontane_2. Seydlitz und der... -0.065082 -0.041647
# autoren_lyrik_lemma_fontane_4. Es kann die Ehre... -0.065082 -0.041647
# autoren_lyrik_lemma_fontane_5. [O, wie weit, wi... -0.065082 -0.041647
# autoren_lyrik_lemma_fontane_König Karl der Zwei... -0.065082 -0.041647
# ...                                                      ...       ...
# autoren_lyrik_lemma_fontane_Religion               -0.065082 -0.041647
# autoren_lyrik_lemma_Fontane_Prolog                 -0.065082 -0.041647
# autoren_lyrik_lemma_Fontane_4. Re Umbertos Kranz   -0.065082 -0.041647
# autoren_lyrik_lemma_fontane_Hastingsfeld           -0.065082 -0.041647
# autoren_lyrik_lemma_fontane_Kaiser Wilhelms Rüc... -0.065082 -0.041647
#
# [720 rows x 1000 columns]

# %%
epik = pd.read_csv('../results/delta/zscores_epik.csv', index_col=[0])
alle = pd.concat([epik, z])
alle = alle.fillna(0)
alle.to_csv('../results/delta/zscores_alle.csv')

# %%
alle
# Out:
#                                         in+die    zu+die    stehen    an+die  \
# epik_mann_tristan                    -0.557208  1.091691  0.577737 -0.515833
# epik_brentano_rosenkranz             -0.250617  2.317812  0.573611 -0.685949
# epik_wassermann_vierzig              -0.027355 -0.041922 -0.020413  0.763556
# epik_lewald_clementine               -1.307970 -0.925938 -1.308277 -1.084952
# epik_schnitzler_tanzerin              1.155074 -0.537935  1.914737  0.691357
# ...                                        ...       ...       ...       ...
# lyrik_Bleibtreu_Davids Psalmen       -0.632688  0.233930 -0.396244  0.348304
# lyrik_Bleibtreu_Weisheit des Orients  0.231131  0.006032 -0.396244  1.344953
# lyrik_Bleibtreu_Unrast               -0.559681 -0.061542 -0.396244  0.588792
# lyrik_Bleibtreu_Dichtermission       -0.079556  0.185720  0.640252 -0.503861
# lyrik_Bleibtreu_Schutzengel           0.531454  0.316258  0.512054  0.433520
#
#                                           hand      auge     rufen      kind  \
# epik_mann_tristan                     0.535493  0.977742 -1.095508 -0.251980
# epik_brentano_rosenkranz             -1.167999 -0.906518 -0.904048 -0.310407
# epik_wassermann_vierzig              -0.143698  0.876125 -0.879306  0.305547
# epik_lewald_clementine               -0.839173  0.095978 -0.987162  0.654671
# epik_schnitzler_tanzerin              1.601397  1.147040  0.151379 -0.219878
# ...                                        ...       ...       ...       ...
# lyrik_Bleibtreu_Davids Psalmen       -0.362403 -0.499133 -0.275957 -0.319283
# lyrik_Bleibtreu_Weisheit des Orients -0.362403  0.165204 -0.275957  0.970876
# lyrik_Bleibtreu_Unrast                1.034763  0.089804 -0.275957  0.443204
# lyrik_Bleibtreu_Dichtermission       -0.020454 -0.499133 -0.275957  0.053946
# lyrik_Bleibtreu_Schutzengel          -0.362403  0.006113  0.885766 -0.319283
#
#                                        bleiben    liegen  ...     hülle  \
# epik_mann_tristan                    -1.026645  1.014981  ...  0.000000
# epik_brentano_rosenkranz             -0.978765 -1.512787  ...  0.000000
# epik_wassermann_vierzig              -0.541223  0.467290  ...  0.000000
# epik_lewald_clementine                1.489872  0.463627  ...  0.000000
# epik_schnitzler_tanzerin              1.166456  1.449605  ...  0.000000
# ...                                        ...       ...  ...       ...
# lyrik_Bleibtreu_Davids Psalmen       -0.327609 -0.346434  ... -0.088113
# lyrik_Bleibtreu_Weisheit des Orients  0.187793 -0.346434  ... -0.088113
# lyrik_Bleibtreu_Unrast               -0.327609  0.309151  ... -0.088113
# lyrik_Bleibtreu_Dichtermission       -0.327609 -0.346434  ... -0.088113
# lyrik_Bleibtreu_Schutzengel          -0.327609 -0.346434  ... -0.088113
#
#                                         stumpf      wußt    leiten  schlürfen  \
# epik_mann_tristan                     0.000000  0.000000  0.000000   0.000000
# epik_brentano_rosenkranz              0.000000  0.000000  0.000000   0.000000
# epik_wassermann_vierzig               0.000000  0.000000  0.000000   0.000000
# epik_lewald_clementine                0.000000  0.000000  0.000000   0.000000
# epik_schnitzler_tanzerin              0.000000  0.000000  0.000000   0.000000
# ...                                        ...       ...       ...        ...
# lyrik_Bleibtreu_Davids Psalmen       -0.134148 -0.107247 -0.102071  -0.102296
# lyrik_Bleibtreu_Weisheit des Orients -0.134148 -0.107247  1.618938   1.627112
# lyrik_Bleibtreu_Unrast               -0.134148 -0.107247 -0.102071  -0.102296
# lyrik_Bleibtreu_Dichtermission       -0.134148 -0.107247 -0.102071  -0.102296
# lyrik_Bleibtreu_Schutzengel          -0.134148 -0.107247  2.515675  -0.102296
#
#                                           korn  hienieden  tiefblau  mus|muse  \
# epik_mann_tristan                     0.000000   0.000000   0.00000  0.000000
# epik_brentano_rosenkranz              0.000000   0.000000   0.00000  0.000000
# epik_wassermann_vierzig               0.000000   0.000000   0.00000  0.000000
# epik_lewald_clementine                0.000000   0.000000   0.00000  0.000000
# epik_schnitzler_tanzerin              0.000000   0.000000   0.00000  0.000000
# ...                                        ...        ...       ...       ...
# lyrik_Bleibtreu_Davids Psalmen       -0.094646  -0.114282  -0.09988 -0.109112
# lyrik_Bleibtreu_Weisheit des Orients -0.094646  -0.114282  -0.09988 -0.109112
# lyrik_Bleibtreu_Unrast               -0.094646  -0.114282  -0.09988 -0.109112
# lyrik_Bleibtreu_Dichtermission       -0.094646  -0.114282  -0.09988 -0.109112
# lyrik_Bleibtreu_Schutzengel          -0.094646  -0.114282  -0.09988  2.707759
#
#                                       verzehren
# epik_mann_tristan                      0.000000
# epik_brentano_rosenkranz               0.000000
# epik_wassermann_vierzig                0.000000
# epik_lewald_clementine                 0.000000
# epik_schnitzler_tanzerin               0.000000
# ...                                         ...
# lyrik_Bleibtreu_Davids Psalmen        -0.104253
# lyrik_Bleibtreu_Weisheit des Orients  -0.104253
# lyrik_Bleibtreu_Unrast                -0.104253
# lyrik_Bleibtreu_Dichtermission        -0.104253
# lyrik_Bleibtreu_Schutzengel           -0.104253
#
# [247 rows x 1592 columns]

# %% [markdown]
# ### compare delta values for texts by same and different authors

# %%
data = pd.read_hdf('../results/delta/autoren_corpus/delta_autoren_corpus.h5')
data.head(1)
# Out:
#                                             manhattan  cosine labelgenre  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben        0.0     1.0       same
#
#                                            labelauthor genres   author
# autoren_lyrik_lemma_Fontane_Die zwei Raben        same  lyrik  fontane

# %%
def same_dif(delta):
    ax = sns.distplot(delta['cosine'][delta['label']=='different'], hist=False, label='different', color=(0.2, 0.3, 0.1))
    ax1 = sns.distplot(delta['cosine'][delta['label']=='same'], hist=False, label='same', color='g')
    ax.set(ylabel='Count')

    # Get the two lines from the axes to generate shading
    l1 = ax.lines[0]
    l2 = ax1.lines[0]

    # Get the xy data from the lines so that we can shade
    x1, y1 = l1.get_xydata().T
    x2, y2 = l2.get_xydata().T

    xmin = max(x1.min(), x2.min())
    xmax = min(x1.max(), x2.max())
    x = np.linspace(xmin, xmax, 100)
    y1 = np.interp(x, x1, y1)
    y2 = np.interp(x, x2, y2)
    y = np.minimum(y1, y2)
    ax.fill_between(x, y, color="grey", alpha = 0.3, hatch = '|')
    
    # uncomment to add cutoff border
#     cut = cutoff[cutoff['corpus']==corpus]['delta']
#     plt.axvline(float(cut), 0, 1) 
#     plt.savefig(mfw + '_' + corpus + '_' + 'same_different_cutoff')

    
#     plt.savefig(mfw + '_' + corpus + '_' + 'same_different_deltas')
    plt.legend()
    plt.show()

# %%
delta = pd.read_hdf('../results/delta/fontane/delta_fontane2.h5')

# %%
delta = delta[delta.cosine!=1.00]
# mfw = file.replace(prefix, "").split('_')[0]
# corpus = file.replace(prefix, "").replace('.h5','').split('_')[2]
same_dif(delta)
#     if mfw == '1000':
#         same_dif(delta)

delta
# Out:
#                                                     manhattan  cosine label  \
# autoren_lyrik_lemma_fontane_Nette Bücher               187.75   -0.01  same
# autoren_lyrik_lemma_fontane_Weltzeitungs-Inserat       195.81   -0.02  same
# autoren_lyrik_lemma_fontane_An die Autoritätskl...     197.58   -0.01  same
# autoren_lyrik_lemma_fontane_Sanft ruhe seine Asche     198.98   -0.01  same
# autoren_lyrik_lemma_fontane_Suum Cuique                199.17   -0.01  same
# ...                                                       ...     ...   ...
# autoren_lyrik_lemma_Fontane_Die zwei Raben             295.83    0.01  same
# autoren_lyrik_lemma_Fontane_10. Man wird nicht ...     301.26   -0.01  same
# autoren_lyrik_lemma_Fontane_Der erste Schnee           304.33   -0.01  same
# autoren_lyrik_lemma_Fontane_7. Tritt ein für de...     304.46   -0.01  same
# autoren_lyrik_lemma_fontane_Plädoyer gegen die ...        NaN     NaN  same
#
#                                                    genres   author
# autoren_lyrik_lemma_fontane_Nette Bücher            lyrik  fontane
# autoren_lyrik_lemma_fontane_Weltzeitungs-Inserat    lyrik  fontane
# autoren_lyrik_lemma_fontane_An die Autoritätskl...  lyrik  fontane
# autoren_lyrik_lemma_fontane_Sanft ruhe seine Asche  lyrik  fontane
# autoren_lyrik_lemma_fontane_Suum Cuique             lyrik  fontane
# ...                                                   ...      ...
# autoren_lyrik_lemma_Fontane_Die zwei Raben          lyrik  Fontane
# autoren_lyrik_lemma_Fontane_10. Man wird nicht ...  lyrik  Fontane
# autoren_lyrik_lemma_Fontane_Der erste Schnee        lyrik  Fontane
# autoren_lyrik_lemma_Fontane_7. Tritt ein für de...  lyrik  Fontane
# autoren_lyrik_lemma_fontane_Plädoyer gegen die ...  lyrik  fontane
#
# [517651 rows x 5 columns]

# %%
path = "project_stylometry_statistics/results/Chinese/delta/*.h5"
prefix = "project_stylometry_statistics/results/Chinese/delta/"
for file in glob.glob(path):
    delta = pd.read_hdf(file)
    delta = delta[delta.cosine!=1.00]
    mfw = file.replace(prefix, "").split('_')[0]
    corpus = file.replace(prefix, "").replace('.h5','').split('_')[2]
    same_dif(delta)
#     if mfw == '1000':
#         same_dif(delta)

# %%
path = 'results/1000/*.h5'
prefix = 'results/1000'
for file in glob.glob(path):
    language = pd.read_hdf(file)
    language = language[language.cosine!=1.00]
    corp = file.replace('.h5', '').split('_')[2]
    sns.set_palette(sns.cubehelix_palette(7, start=1.85, rot=0, dark=0.3, light=.7, reverse=True))
    ax = sns.distplot(language['cosine'], hist=False, label=corp)
    plt.legend()
plt.savefig('delta_normaldist_1000mfw')

# %% [markdown]
# ### Delta variance per corpus

# %%
v = delta.copy()
# v['corpus'] = 'Chinese'
v = v.drop('manhattan', axis=1)
v = v.drop('euclidean', axis=1)
v = v.drop('label', axis=1)
# v = v.drop('author', axis=1)
v = v.reset_index()
v = v.drop('index', axis=1)
v
# Out:
#        cosine genres
# 0        0.00  lyrik
# 1        0.04  lyrik
# 2        0.06  lyrik
# 3        0.09  lyrik
# 4        0.02  lyrik
# ...       ...    ...
# 60757    0.04   epik
# 60758    0.08   epik
# 60759   -0.03   epik
# 60760   -0.02   epik
# 60761   -0.01   epik
#
# [60762 rows x 2 columns]

# %%
# variance = pd.DataFrame()
variance = pd.concat([variance, v])
variance = variance[variance['cosine']!=0.00]
variance
# Out:
#        cosine genres
# 1        0.04  lyrik
# 2        0.06  lyrik
# 3        0.09  lyrik
# 4        0.02  lyrik
# 5        0.02  lyrik
# ...       ...    ...
# 60757    0.04   epik
# 60758    0.08   epik
# 60759   -0.03   epik
# 60760   -0.02   epik
# 60761   -0.01   epik
#
# [55658 rows x 2 columns]

# %%
import pandas as pd 
vdelta = pd.read_csv("delta_varianz_allekorpora")
vdelta = vdelta[vdelta.cosine!=1.00]
vdelta.sort_values(by=['corpus'], inplace=True)
vdelta
# Out:
#                                               Unnamed: 0  cosine    corpus
# 1                         BiShuMin,LanSeTianTang,seg.txt    0.51   Chinese
# 3755                              YanGelin,LvXie,seg.txt    0.09   Chinese
# 3754                        YanGelin,LuFanYanShi,seg.txt    0.10   Chinese
# 3753                          JiaPingwa,QinQiang,seg.txt    0.32   Chinese
# 3752                         ChenZhongshi,ChuXia,seg.txt    0.40   Chinese
# ...                                                  ...     ...       ...
# 37703                  Cladel,Leon_OMPDRAILLES_Novel.txt   -0.03  pipierFR
# 37704               Zola,Emile_LeventredeParis_Novel.txt   -0.07  pipierFR
# 37705  Charriere,IsabelleDe_CalisteOuLettresDeLausann...    0.12  pipierFR
# 37641         Dumas,Alexandre_OlympesDesCleves_Novel.txt   -0.01  pipierFR
# 45225                    Benjamin,Rene_Gaspard_Novel.txt    0.06  pipierFR
#
# [89550 rows x 3 columns]

# %%
cutoff = pd.read_csv("entire_best_cutoff.csv")
cutoff.sort_values(by=['corpus'], inplace=True)
cutoff
# Out:
#    Unnamed: 0  Unnamed: 0.1        fp        fn  percentage   delta   corpus  \
# 5          15            56  0.005766  0.003964        0.57  0.3382  Chinese
# 2           6            48  0.002883  0.003964        0.49  0.2243  English
# 1          10            64  0.004324  0.009730        0.65  0.3385   French
# 4          26            56  0.002883  0.003964        0.57  0.3040   German
# 6           4            64  0.002416  0.002953        0.65  0.3955  piperDE
# 0          18            67  0.003311  0.005459        0.68  0.3996  piperEN
# 3          18            68  0.004592  0.005828        0.69  0.4367  piperFR
#
#     mfw
# 5  1000
# 2  2000
# 1   500
# 4  1000
# 6   500
# 0  1000
# 3   500

# %%
plt.figure(figsize=(8,6))
ax = sns.boxplot(x='genres', y='cosine', data=delta, color=(0.4, 0.8, 0.1), fliersize=0.5)
# ax = sns.scatterplot(x='corpus', y='delta', data=cutoff, color='black', s=80, zorder=10)
plt.ylabel('cosine')
# plt.savefig("deltastreuung_plus_deltacutoff")
# Out:
# Text(0, 0.5, 'cosine')

# %% [markdown]
# ### Delta normal distribution

# %%
cutoff
# Out:
#    Unnamed: 0  Unnamed: 0.1        fp        fn  percentage   delta   corpus  \
# 0          18            67  0.003311  0.005459        0.68  0.3996  piperEN
# 1          10            64  0.004324  0.009730        0.65  0.3385   French
# 2           6            48  0.002883  0.003964        0.49  0.2243  English
# 3          18            68  0.004592  0.005828        0.69  0.4367  piperFR
# 4          26            56  0.002883  0.003964        0.57  0.3040   German
# 5          15            56  0.005766  0.003964        0.57  0.3382  Chinese
# 6           4            64  0.002416  0.002953        0.65  0.3955  piperDE
#
#     mfw
# 0  1000
# 1   500
# 2  2000
# 3   500
# 4  1000
# 5  1000
# 6   500

# %%
cos = delta.copy()
cos = cos[cos.cosine!=1.00]

# %%
plus_same = np.mean(cos[cos['label']=='same']['cosine']) + np.std(cos[cos['label']=='same']['cosine'])
minus_same = np.mean(cos[cos['label']=='same']['cosine']) - np.std(cos[cos['label']=='same']['cosine'])

plus_diff = np.mean(cos[cos['label']=='different']['cosine']) + np.std(cos[cos['label']=='different']['cosine'])
minus_diff = np.mean(cos[cos['label']=='different']['cosine']) - np.std(cos[cos['label']=='different']['cosine'])

print(plus_same, minus_same, plus_diff, minus_diff)
# Out:
# 0.04451305977774847 -0.05296809497101655 0.03423736548476722 -0.03413231497971672

# %%
path = "project_stylometry_statistics/results/piperEN/delta/1000_delta_piperEN.h5"
prefix = "project_stylometry_statistics/results/piperEN/delta/"
corpus = 'piperEN'
def distplot(dist):
    ax = sns.distplot(dist['cosine'], hist=False, color='green')
    plt.savefig(mfw + '_' + corpus + '_delta_normaldist')
    plt.show()
    
import re
from scipy import stats


numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

        
        
for file in sorted(glob.glob(path), key=numericalSort):
    dist = pd.read_hdf(file)
    mfw = file.replace(prefix,'').split('_')[0]
    dist = dist[dist['cosine']!=1.00]

    #distplot(dist)
    #sns.set_palette("summer")
    sns.set_palette(sns.cubehelix_palette(14, start=1.85, rot=0, dark=0.3, light=.7, reverse=True))
#     ax = sns.distplot(dist['cosine'], hist=False, label=mfw)    #visualise all mfw steps

    #visualise same and different curve for one mfw step with quartile
    ax = sns.distplot(dist[dist['label']=='different']['cosine'], hist=False, label='different', color='g')
    kde = stats.gaussian_kde(dist[dist['label']=='different']['cosine'])
    shade = np.linspace(minus_diff, plus_diff, 300)
    plt.fill_between(shade, kde(shade), alpha=0.5, color='green')
    
    ax = sns.distplot(dist[dist['label']=='same']['cosine'], hist=False, label='same')
    kde = stats.gaussian_kde(dist[dist['label']=='same']['cosine'])
    shade = np.linspace(minus_same, plus_same, 300)
    plt.fill_between(shade, kde(shade), alpha=0.5, color='blue')
    
    
    plt.legend()
plt.savefig(corpus + '_delta_normaldist_quartile_MFW1000')

# %%
cutoff = pd.read_csv("project_stylometry_statistics/entire_best_cutoff.csv")

# %%
#vdelta = pd.DataFrame()
deltas = pd.read_hdf("project_stylometry_statistics/results/piperDE/delta/500_delta_piperDE.h5")
deltas.drop('manhattan', axis=1, inplace=True)
deltas.drop('euclidean', axis=1, inplace=True)
deltas.drop('label', axis=1, inplace=True)
deltas.drop('author', axis=1, inplace=True)
deltas['corpus']='piperDE'
vdelta=pd.concat([vdelta, deltas])
vdelta
# Out:
#                                                     cosine   corpus
# BiShuMin,HuaGuanBingDu,seg.txt                        1.00  Chinese
# BiShuMin,LanSeTianTang,seg.txt                        0.51  Chinese
# YvQiuyv,ShuangLengChangHe,seg.txt                     0.27  Chinese
# LongYingtai,ZheGeDongDangDeShiJie,seg.txt             0.20  Chinese
# YvQiuyv,XingZheWuJiang,seg.txt                        0.24  Chinese
# ...                                                    ...      ...
# Ehrmann,Marianne_Amalie.EinewahreGeschichteinBr...   -0.35  piperDE
# Fischer,CarolineAuguste_Margarethe_Novel.txt         -0.34  piperDE
# Reventlow,Franziska_VonPaulzuPedro_Novel.txt         -0.23  piperDE
# Fischer,CarolineAuguste_DieHonigmonathe_Novel.txt    -0.37  piperDE
# Ehrmann,Marianne_NinasBriefeanihrenGeliebten_No...   -0.32  piperDE
#
# [90301 rows x 2 columns]

# %%
vdelta.to_csv("delta_varianz_allekorpora")

# %%
vdelta = pd.read_csv("delta_varianz_allekorpora")
vdelta = vdelta[vdelta.cosine!=1.00]
vdelta
# Out:
#                                               Unnamed: 0  cosine   corpus
# 1                         BiShuMin,LanSeTianTang,seg.txt    0.51  Chinese
# 2                      YvQiuyv,ShuangLengChangHe,seg.txt    0.27  Chinese
# 3              LongYingtai,ZheGeDongDangDeShiJie,seg.txt    0.20  Chinese
# 4                         YvQiuyv,XingZheWuJiang,seg.txt    0.24  Chinese
# 5                             YvQiuyv,WenHuaKuLv,seg.txt    0.13  Chinese
# ...                                                  ...     ...      ...
# 90296  Ehrmann,Marianne_Amalie.EinewahreGeschichteinB...   -0.35  piperDE
# 90297       Fischer,CarolineAuguste_Margarethe_Novel.txt   -0.34  piperDE
# 90298       Reventlow,Franziska_VonPaulzuPedro_Novel.txt   -0.23  piperDE
# 90299  Fischer,CarolineAuguste_DieHonigmonathe_Novel.txt   -0.37  piperDE
# 90300  Ehrmann,Marianne_NinasBriefeanihrenGeliebten_N...   -0.32  piperDE
#
# [89550 rows x 3 columns]

# %%
german = vdelta[vdelta['corpus']=='German']
chinese = vdelta[vdelta['corpus']=='Chinese']
french = vdelta[vdelta['corpus']=='French']
english = vdelta[vdelta['corpus']=='English']
piperDE = vdelta[vdelta['corpus']=='piperDE']
piperFR = vdelta[vdelta['corpus']=='pipierFR']
piperFR.corpus='piperFR'
piperEN = vdelta[vdelta['corpus']=='piperEN']
liste = [german, chinese, french, english, piperDE, piperEN, piperFR]
# Out:
# /home/teresa/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
for language in liste:
    corp = np.unique(language['corpus'])[0]
    sns.set_palette(sns.cubehelix_palette(7, start=1.85, rot=0, dark=0.3, light=.7, reverse=True))
    ax = sns.distplot(language['cosine'], hist=False, label=corp)
    plt.legend()
plt.savefig('_delta_normaldist_best_cutoffs')

# %%
import pandas as pd

# %%
data = pd.read_hdf('../results/delta/fontane/delta_fontane.h5')
data.head()
# Out:
#                                                     manhattan  cosine  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben               0.00    1.00
# autoren_lyrik_lemma_fontane_Nette Bücher               162.28   -0.01
# autoren_lyrik_lemma_fontane_Weltzeitungs-Inserat       169.96   -0.01
# autoren_lyrik_lemma_Fontane_Brunnenpromenade           171.27    0.02
# autoren_lyrik_lemma_fontane_An die Autoritätskl...     172.19   -0.01
#
#                                                    labelgenre labelauthor  \
# autoren_lyrik_lemma_Fontane_Die zwei Raben               same        same
# autoren_lyrik_lemma_fontane_Nette Bücher                 same        same
# autoren_lyrik_lemma_fontane_Weltzeitungs-Inserat         same        same
# autoren_lyrik_lemma_Fontane_Brunnenpromenade             same        same
# autoren_lyrik_lemma_fontane_An die Autoritätskl...       same        same
#
#                                                    genres   author
# autoren_lyrik_lemma_Fontane_Die zwei Raben          lyrik  fontane
# autoren_lyrik_lemma_fontane_Nette Bücher            lyrik  fontane
# autoren_lyrik_lemma_fontane_Weltzeitungs-Inserat    lyrik  fontane
# autoren_lyrik_lemma_Fontane_Brunnenpromenade        lyrik  fontane
# autoren_lyrik_lemma_fontane_An die Autoritätskl...  lyrik  fontane

# %%
data = data.sort_values(by='cosine', ascending=False)
data = data[data.cosine!=1.00]
data.head(1)
# Out:
#                                           manhattan  cosine labelgenre  \
# autoren_lyrik_lemma_Fontane_Johanna Gray       5.42    0.99       same
#
#                                          labelauthor genres   author
# autoren_lyrik_lemma_Fontane_Johanna Gray        same  lyrik  fontane

# %%
cut = data[data.cosine>=0.35]
cut
# Out:
#                                                     manhattan  cosine  \
# autoren_lyrik_lemma_Fontane_Johanna Gray                 5.42    0.99
# autoren_lyrik_lemma_Fontane_Melrose-Abbey                8.33    0.99
# autoren_lyrik_lemma_fontane_Johanna Gray                 5.42    0.99
# autoren_lyrik_lemma_fontane_l00110178                   11.84    0.99
# autoren_lyrik_lemma_fontane_Die Gans von Putlitz        11.84    0.99
# ...                                                       ...     ...
# autoren_lyrik_lemma_fontane_28. [Mille de Fleur...     143.69    0.35
# autoren_lyrik_lemma_fontane_Einzug (20. Septemb...     183.77    0.35
# autoren_lyrik_lemma_fontane_4. Der sterbende Do...     170.82    0.35
# autoren_lyrik_lemma_fontane_12. [Jüngst sah ich...     158.05    0.35
# autoren_lyrik_lemma_fontane_Einem Pseudonym             93.39    0.35
#
#                                                    labelgenre labelauthor  \
# autoren_lyrik_lemma_Fontane_Johanna Gray                 same        same
# autoren_lyrik_lemma_Fontane_Melrose-Abbey                same        same
# autoren_lyrik_lemma_fontane_Johanna Gray                 same        same
# autoren_lyrik_lemma_fontane_l00110178                    same        same
# autoren_lyrik_lemma_fontane_Die Gans von Putlitz         same        same
# ...                                                       ...         ...
# autoren_lyrik_lemma_fontane_28. [Mille de Fleur...       same        same
# autoren_lyrik_lemma_fontane_Einzug (20. Septemb...       same        same
# autoren_lyrik_lemma_fontane_4. Der sterbende Do...       same        same
# autoren_lyrik_lemma_fontane_12. [Jüngst sah ich...       same        same
# autoren_lyrik_lemma_fontane_Einem Pseudonym              same        same
#
#                                                    genres   author
# autoren_lyrik_lemma_Fontane_Johanna Gray            lyrik  fontane
# autoren_lyrik_lemma_Fontane_Melrose-Abbey           lyrik  fontane
# autoren_lyrik_lemma_fontane_Johanna Gray            lyrik  fontane
# autoren_lyrik_lemma_fontane_l00110178               lyrik  fontane
# autoren_lyrik_lemma_fontane_Die Gans von Putlitz    lyrik  fontane
# ...                                                   ...      ...
# autoren_lyrik_lemma_fontane_28. [Mille de Fleur...  lyrik  fontane
# autoren_lyrik_lemma_fontane_Einzug (20. Septemb...  lyrik  fontane
# autoren_lyrik_lemma_fontane_4. Der sterbende Do...  lyrik  fontane
# autoren_lyrik_lemma_fontane_12. [Jüngst sah ich...  lyrik  fontane
# autoren_lyrik_lemma_fontane_Einem Pseudonym         lyrik  fontane
#
# [460 rows x 6 columns]

# %%
dic = {'Korpus': 'Fontane','Gesamt':len(data),'same genre': len(cut[cut.labelgenre=='same']), 'different genre': len(cut[cut.labelgenre=='different']), 'same author': len(cut[cut.labelauthor=='same']), 'different author': len(cut[cut.labelauthor=='different'])}
res = pd.DataFrame.from_dict(dic, orient='index')
res = res.T
res
# Out:
#     Korpus  Gesamt same genre different genre same author different author
# 0  Fontane  545312        460               0         460                0

# %%
# cutoff = res
cutoff = pd.concat([cutoff, res])
cutoff
# Out:
#                       Korpus   Gesamt same genre different genre same author  \
# 0              Autorenkorpus  5805428       2724              30        1916
# 0     Autorenkorpus_Segmente  1657652        394             248           0
# 0           Vergleichskorpus  9843834       2200              50         758
# 0  Vergleichskorpus_Segmente  3391114        778            1966           0
# 0                    Fontane   545312        460               0         460
#
#   different author Fontane
# 0              838     NaN
# 0                0     NaN
# 0             1492     NaN
# 0                0     NaN
# 0                0     NaN

# %%
cutoff.to_csv('../results/delta/cutoff_all.csv')

# %%
c = cutoff[['Korpus', 'different author']]
c.columns = ['Korpus', 'result']
c['same_dif'] = ['different author', 'different author','different author','different author','different author']

c2 = cutoff[['Korpus', 'different genre']]
c2.columns = ['Korpus', 'result']
c2['same_dif'] = ['different genre', 'different genre','different genre','different genre','different genre']

f = cutoff[['Korpus', 'same author']]
f.columns = ['Korpus', 'result']
f['same_dif'] = ['same_author','same_author','same_author','same_author','same_author']

f2 = cutoff[['Korpus', 'same genre']]
f2.columns = ['Korpus', 'result']
f2['same_dif'] = ['same genre','same genre','same genre','same genre','same genre']


cutoffs = pd.concat([c, c2, f, f2])
cutoffs
# Out:
# /home/teresa/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/teresa/.local/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/teresa/.local/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/teresa/.local/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                       Korpus result          same_dif
# 0              Autorenkorpus    838  different author
# 0     Autorenkorpus_Segmente      0  different author
# 0           Vergleichskorpus   1492  different author
# 0  Vergleichskorpus_Segmente      0  different author
# 0                    Fontane      0  different author
# 0              Autorenkorpus     30   different genre
# 0     Autorenkorpus_Segmente    248   different genre
# 0           Vergleichskorpus     50   different genre
# 0  Vergleichskorpus_Segmente   1966   different genre
# 0                    Fontane      0   different genre
# 0              Autorenkorpus   1916       same_author
# 0     Autorenkorpus_Segmente      0       same_author
# 0           Vergleichskorpus    758       same_author
# 0  Vergleichskorpus_Segmente      0       same_author
# 0                    Fontane    460       same_author
# 0              Autorenkorpus   2724        same genre
# 0     Autorenkorpus_Segmente    394        same genre
# 0           Vergleichskorpus   2200        same genre
# 0  Vergleichskorpus_Segmente    778        same genre
# 0                    Fontane    460        same genre

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.barplot(x='Korpus', y='result', hue='same_dif', data=cutoffs)
plt.savefig('../results/delta/cutoffs_all')

# %%
data2 = data[:100]
i=0
for x, row in data2.iterrows():
    data2.loc[x,'Autor']= str(row.author) + str(i)
    i+=1 
data2
# Out:
# /home/teresa/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/teresa/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                                         manhattan  cosine labelgenre  \
# lyrik_lemma_wilhelm dunker._l0030005         9.69    0.99       same
# lyrik_lemma_fontane_Johanna Gray             5.42    0.99       same
# lyrik_lemma_wilhelm duncker._l0040109        9.69    0.99       same
# lyrik_lemma_fontane_l0090073                 3.39    0.99       same
# lyrik_lemma_fontane_Der alte Derffling       3.39    0.99       same
# ...                                           ...     ...        ...
# lyrik_lemma_fontane_Jan Bart               139.26    0.79       same
# lyrik_lemma_hermann allmers._l0050230      118.67    0.78       same
# lyrik_lemma_hermann allmers._l0040005      118.67    0.78       same
# lyrik_lemma_holz_l00140061                  89.66    0.77       same
# lyrik_lemma_holz_l0060038                   89.66    0.77       same
#
#                                        labelauthor genres            author  \
# lyrik_lemma_wilhelm dunker._l0030005     different  lyrik   wilhelm dunker.
# lyrik_lemma_fontane_Johanna Gray              same  lyrik           fontane
# lyrik_lemma_wilhelm duncker._l0040109    different  lyrik  wilhelm duncker.
# lyrik_lemma_fontane_l0090073                  same  lyrik           fontane
# lyrik_lemma_fontane_Der alte Derffling        same  lyrik           fontane
# ...                                            ...    ...               ...
# lyrik_lemma_fontane_Jan Bart                  same  lyrik           fontane
# lyrik_lemma_hermann allmers._l0050230         same  lyrik  hermann allmers.
# lyrik_lemma_hermann allmers._l0040005         same  lyrik  hermann allmers.
# lyrik_lemma_holz_l00140061                    same  lyrik              holz
# lyrik_lemma_holz_l0060038                     same  lyrik              holz
#
#                                                      Autor
# lyrik_lemma_wilhelm dunker._l0030005      wilhelm dunker.0
# lyrik_lemma_fontane_Johanna Gray                  fontane1
# lyrik_lemma_wilhelm duncker._l0040109    wilhelm duncker.2
# lyrik_lemma_fontane_l0090073                      fontane3
# lyrik_lemma_fontane_Der alte Derffling            fontane4
# ...                                                    ...
# lyrik_lemma_fontane_Jan Bart                     fontane95
# lyrik_lemma_hermann allmers._l0050230   hermann allmers.96
# lyrik_lemma_hermann allmers._l0040005   hermann allmers.97
# lyrik_lemma_holz_l00140061                          holz98
# lyrik_lemma_holz_l0060038                           holz99
#
# [100 rows x 7 columns]

# %%
data2 = data[:100]
i=0
for x, row in data2.iterrows():
    if 'epik' in row.genres:
        data2.loc[x,'Genre']= 'epik'
    else:
        data2.loc[x,'Genre']= 'lyrik'

    i+=1 
data2
# Out:
# /home/teresa/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/teresa/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#              manhattan  cosine labelgenre labelauthor genres Genre
# epik2851000       7.07    0.99       same           ?  epik2  epik
# epik2900500      12.52    0.99       same           ?  epik2  epik
# epik2748500       7.07    0.99       same           ?  epik2  epik
# epik2798000      12.52    0.99       same           ?  epik2  epik
# epik1626000      47.32    0.96       same           ?  epik1  epik
# ...                ...     ...        ...         ...    ...   ...
# epik744500       96.45    0.86  different           ?  epik7  epik
# epik1144000      91.10    0.85       same           ?  epik1  epik
# epik1518000      91.10    0.85       same           ?  epik1  epik
# epik3035500     114.06    0.85       same           ?  epik3  epik
# epik3092000     114.06    0.85       same           ?  epik3  epik
#
# [100 rows x 6 columns]

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data2.Autor, y='cosine', data=data2[:100], hue='genres')
# plt.title(title)
plt.savefig('../Latex/Bilder_Theorie/vergleich_100cos_gattung.png')
plt.xticks(rotation=90)
plt.show()

# %%
emotion = ['liebreich','angst', 'ängstlich', 'trauer', 'traurig', 'zornig', 'zorn', 'verachtungsvoll', 'verachtung',
           'schuld', 'schuldig', 'liebe',  'geliebt', 'liebevoll', 'stolz', 'scham', 'schämen', 'überrasschung',
           'überrascht', 'sorge', 'sorgenvoll', 'ekel', 'ekeln', 'angeekelt', 'neid', 'neidisch', 'neidvoll',
           'glücklich', 'glück', 'freude', 'freudig', 'freuen', 'erleichterung', 'erleichtert', 'vergnügt', 'vergnügen',
           'zufrieden', 'zufriedenheit', 'verzweiflung', 'verzweifelt', 'verlegenheit', 'verlegen', 'aufregung',
           'aufgeregt', 'aufregen', 'spannung', 'gespannt', 'erregung', 'erregt', 'hoffen', 'hoffnung', 'befriedigt',
           'langweilig', 'langeweile', 'mitgefühl', 'mitfühlen', 'enttäuscht', 'enttäuschung', 'frust', 'frustriert',
           'eifersucht', 'eifersüchtig', 'wut', 'wütend', 'reue', 'schock', 'schockiert', 'zuneigung', 'verärgert',
           'verärgerung', 'erwartungsvoll', 'erwartung', 'vorfreude', 'scheu', 'gelassen', 'gelassenheit', 'mut',
           'mutig', 'neugierde', 'neugierig', 'depression', 'depressiv', 'niedergeschlagenheit', 'niedergeschlagen',
           'lustvoll', 'lust', 'rausch', 'einfühlend', 'einfühlsam', 'euphorisch', 'euphorie', 'dankbarkeit', 'dankbar',
           'hass', 'entsetzt', 'entsetzen', 'demütigung', 'demütig', 'demut', 'interesse', 'interessiert', 'einsamkeit',
           'einsam', 'empörung', 'empört', 'vertrauen', 'qualvoll', 'qual', 'gleichgültigkeit', 'gleichgültig',
           'fröhlichkeit', 'fröhlich', 'schadenfroh', 'schadenfreude', 'schmerz', 'melancholie', 'melancholisch',
           'panik', 'panisch', 'fühlen', 'herz', 'seele', 'schwermut', 'unglück', 'wanderlust',  'bitterkeit','freuen', 
           'weinen',  'erschrecken',  'empfinden', 'vergnügen', 'bekümmern', 'befürchten', 'jauchzen', 'verzweifeln', 
           'qual', 'grausne', 'Lust',  'kichern', 'zufrieden',  'leid', 'zorn',  'heiter', 'lache',  'weinen', 'sehnsucht',
           'hoffnung',  'mutig', 'trost', 'ohnmacht', 'ohnmächtig']

sprechmarker_lang = ['abhören','ablehnen','abraten','abschlagen','abschweifen','absprechen','abstreiten',
                     'andeuten','anerkennen', 'anfechten','angeben','ankünden','anraten',
                     'antworten','anvertrauen','anweisen','artikulieren','aufmuntern',
                     'aufzeigen','ausdrücken','Ausflüchte machen','ausforschen','ausfragen','aushorchen',
                     'ausplaudern','ausquetschen','aussagen', 'äußern', 'sich aussprechen','ausweichen',
                     'bedanken', 'befehlen','befragen','befürchten','begründen','beharren auf','behaupten',
                     'beichten','bejahen', 'bekennen', 'beklagen', 'bekräftigen', 'bekunden', 'beleuchten', 'bemängeln',
                     'bemerken', 'berichten', 'berichtigen', 'beruhigen', 'besagen', 'Bescheid geben', 'beschönigen',
                     'beschreiben','beschwören','bestätigen','bestehen auf','bestimmen','bestreiten','beten','beteuern',
                     'betonen','betteln','beweisen','bezeichnen','bezeugen','bitten','brabbeln','bramarbasieren',
                     'breittreten','brüllen','brummen','daherreden','darlegen','dartun','definieren',
                     'dementieren','demonstrieren', 'den Mund vollnehmen','deuteln','dick auftragen','dazwischenfahren',
                     'drohen', 'ein Ohr abkauen','einräumen','einreden','einschärfen','einwenden','einwilligen','empfehlen',
                     'entgegenhalten','entgegnen','enthüllen','entkräften','entschuldigen','erdichten','erfinden',
                     'ergänzen','erinnern','erklären','erkundigen', 'ermahnen','ermuntern','ermutigen','erörtern','erschließen',
                     'erwähnen', 'erwidern','erzählen','evident machen','fabulieren','faseln','feststellen',
                     'flehen','flunkern','flüstern','folgern','fordern','fragen', 'geheim halten',
                     'gestehen','herausposaunen','herausreden', 'herausschreien','herumkritteln','hervorheben','hinweisen',
                     'hinzufügen','höhnen','in Abrede stellen','in Frage stellen','ins Gesicht sagen',
                     'jammern','keuchen','klagen','klöhnen','konstatieren','krächzen','kritisieren','kundgeben',
                     'kundtun','labern','lallen','leugnen','lispeln','loben','mahnen','meinen','mitteilen',
                     'munkeln','murmeln','nachfragen','nachweisen','näseln','negieren','nennen',
                     'nuscheln','offenbaren','palavern','petzen','plaudern','plauschen','prahlen','quasseln','quatschen',
                     'raten','raunen','Rede und Antwort stehen','reden wie ein Buch','reden wie ein Wasserfall',
                     'reinen Wein einschenken','röcheln','rufen','sagen','schildern','schleimen','schließen',
                     'schluchzen','schnacken','schnarren','schnattern','schreien','schwadronieren','schwatzen',
                     'schwätzen','schwören','seiern','skizzieren','sprechen','stammeln','stottern','tadeln',
                     'trösten','tuscheln','überinterpretieren','überreden',
                     'überzeugen','umreißen','umschreiben','unken','Unsinn verzapfen','unterhalten','unterstreichen',
                     'unterstützen','veranschaulichen','verdrehen','verfälschen','verhören','verklickern',
                     'verkünden','verlangen','verlautbaren','verleugnen','vernehmen','verneinen','verraten','verschleiern',
                     'versichern','versprechen','vertiefen','verwerfen','verzerren','vorbringen','vorenthalten','vorgeben','warnen',
                     'weit ausholen','widerlegen','widerrufen','widersprechen','wiederholen','wissen wollen','zeigen',
                     'zitieren','zu bedenken geben','zugeben','zugestehen','zureden','zurücknehmen',
                     'zurufen','zustimmen', 'hören', 'singen', 'danken', 'grüßen', 'befehlen', 'lügen', 'gestehen', 'seufzen',
                     'stöhnen', 'staunen', 'zuhören', 'jubeln', 'schimpfen', 'wettern', 'krächzen']

# %%
zscores = pd.read_csv('../results/delta/vergleich/zscores_vergleich.csv', index_col=[0])
epik = zscores[zscores.index.str.contains('epik')]
print(len(epik))
epik.loc['Epik'] = epik.sum(axis=0)/7

lyrik = zscores[zscores.index.str.contains('lyrik')]
print(len(lyrik))
lyrik.loc['Lyrik'] = lyrik.sum(axis=0)/3131

result = pd.concat([lyrik.loc['Lyrik'], epik.loc['Epik']], axis=1)
result = result.T
# Out:
# 7
# 3131
# /home/teresa/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
result
# Out:
#          in+die      herz    zu+die    an+die     still     nacht   von+die  \
# Lyrik  0.000774  0.000737  0.000153  0.000323  0.000604  0.000524  0.000439
# Epik  -0.346068 -0.329798 -0.068277 -0.144426 -0.270347 -0.234212 -0.196359
#
#            hand    stehen      tief  ...   täglich  erbarmen       öde  \
# Lyrik  0.000121 -0.000100  0.000365  ... -0.000134  0.000130  0.000050
# Epik  -0.054028  0.044566 -0.163230  ...  0.059849 -0.057947 -0.022252
#
#           hegen     faust     ew'ge   streuen     lilie  schneiden  \
# Lyrik -0.000018 -0.002881  0.000153  0.000082 -0.000128   0.000081
# Epik   0.007891  1.288462 -0.068639 -0.036468  0.057411  -0.036134
#
#        klinge|klingen
# Lyrik        0.000144
# Epik        -0.064221
#
# [2 rows x 1000 columns]

# %%
df = pd.DataFrame(columns=['Wort', 'Z-Score', 'Genre'])
wort = ''
zscore = []
genre = []
for i, row in result.iterrows():
    for m in emotion:
        if m in result.columns:
            wort+=' ' + m
            zscore.append(result.at[i, m])
            genre.append(i)
worte = wort.split(' ')
df['Wort'] = worte[1:]
df['Z-Score'] = zscore
df['Genre'] = genre
df = df.sort_values(by='Z-Score')
df
# Out:
#          Wort   Z-Score Genre
# 70       herz -0.329798  Epik
# 71      seele -0.201544  Epik
# 61       lust -0.177112  Epik
# 52      glück -0.145029  Epik
# 48      stolz -0.132470  Epik
# ..        ...       ...   ...
# 72     freuen  0.038473  Epik
# 55     freuen  0.038473  Epik
# 65  vertrauen  0.067628  Epik
# 42      angst  0.078899  Epik
# 51  glücklich  0.199083  Epik
#
# [84 rows x 3 columns]

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Z-Score', y='Wort', hue='Genre',data=df)

plt.savefig('../Latex/Bilder_Theorie/vergleich_emotion_zscores.png')
