# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
emotion100 = pd.read_csv('../results/zeta/emotion_100pro_wort.csv', header=None)
emotion100.columns = ['wort', 'zeta']
emotion100 = emotion100.sort_values(by='zeta', ascending=False)

emotion500 = pd.read_csv('../results/zeta/emotion_500pro_wort.csv', header=None)
emotion500.columns = ['wort', 'zeta']
emotion500 = emotion500.sort_values(by='zeta', ascending=False)

emotion1000 = pd.read_csv('../results/zeta/emotion_1000pro_wort.csv', header=None)
emotion1000.columns = ['wort', 'zeta']
emotion1000 = emotion1000.sort_values(by='zeta', ascending=False)

fig, axs = plt.subplots(1,3, figsize=(30,40))
sns.barplot(x='zeta', y=emotion100.wort[:10], data=emotion100, color='b', ax=axs[0])
axs[0].set_title('100 Wörter pro Segment')
sns.barplot(x='zeta', y=emotion500.wort[:10], data=emotion500, color='b', ax=axs[1])
axs[1].set_title('500 Wörter pro Segment')
sns.barplot(x='zeta', y=emotion1000.wort[:10], data=emotion1000, color='b', ax=axs[2])
axs[2].set_title('1000 Wörter pro Segment')
# Out:
# Text(0.5, 1.0, '1000 Wörter pro Segment')

# %%
nomen = pd.read_csv('../results/zeta/nomen_100pro_wort.csv', header=None)
nomen.columns = ['wort', 'zeta']
nomen = nomen.sort_values(by='zeta', ascending=False)

# %%
anf100 = pd.read_csv('../results/zeta/anf_100pro_merkmal.csv', header=None)
anf100.columns = ['zeta']
anf100 = anf100.sort_values(by='zeta', ascending=False)

anf500 = pd.read_csv('../results/zeta/anf_500pro_merkmal.csv', header=None)
anf500.columns = ['zeta']
anf500 = anf500.sort_values(by='zeta', ascending=False)

anf1000 = pd.read_csv('../results/zeta/anf_1000pro_merkmal.csv', header=None)
anf1000.columns = ['zeta']
anf1000 = anf1000.sort_values(by='zeta', ascending=False)

fig, axs = plt.subplots(1,3, figsize=(10,3))
sns.barplot(y='zeta', data=anf100, color='b', ax=axs[0])
axs[0].set_title('100 Wörter pro Segment')
sns.barplot(y='zeta', data=anf500, color='b', ax=axs[1])
axs[1].set_title('500 Wörter pro Segment')
sns.barplot(y='zeta', data=anf1000, color='b', ax=axs[2])
axs[2].set_title('1000 Wörter pro Segment')
# Out:
# Text(0.5, 1.0, '1000 Wörter pro Segment')

# %%
nur_dupl = pd.read_csv('../results/zeta/nur_dupl_100.csv', header=None)
nur_dupl.columns = ['wort', 'zeta']
nur_dupl = nur_dupl.sort_values(by='zeta', ascending=False)

# %%
ohne_dupl = pd.read_csv('../results/zeta/ohne_dupl_100.csv', header=None)
ohne_dupl.columns = ['wort', 'zeta']
ohne_dupl = ohne_dupl.sort_values(by='zeta', ascending=False)

# %%
sns.barplot(x='zeta', y='wort', data=nomen, color='b')

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5))

sns.barplot(x='zeta', y=ohne_dupl.wort[:20], data=ohne_dupl, color='b', ax=axs[0])
sns.barplot(x='zeta', y=ohne_dupl.wort[-20:], data=ohne_dupl, color='b', ax=axs[1])

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5))
sns.barplot(x='zeta', y=nur_dupl.wort[:20], data=nur_dupl, color='b', ax=axs[0])
sns.barplot(x='zeta', y=nur_dupl.wort[-20:], data=nur_dupl, color='b', ax=axs[1])

# %%
instanz100 = pd.read_csv('../results/zeta/instanz_epik_100.csv', header=None)
instanz100.columns = ['wort', 'zeta']
instanz100 = instanz100.sort_values(by='zeta', ascending=False)

instanz500 = pd.read_csv('../results/zeta/instanz_epik_500.csv', header=None)
instanz500.columns = ['wort', 'zeta']
instanz500 = instanz500.sort_values(by='zeta', ascending=False)

instanz1000 = pd.read_csv('../results/zeta/instanz_epik_1000.csv', header=None)
instanz1000.columns = ['wort', 'zeta']
instanz1000 = instanz1000.sort_values(by='zeta', ascending=False)

fig, axs = plt.subplots(1,3, figsize=(10,3))
sns.barplot(x='zeta', y=instanz100.wort, data=instanz100, color='b', ax=axs[0])
axs[0].set_title('100 Wörter pro Segment')
sns.barplot(x='zeta', y=instanz500.wort, data=instanz500, color='b', ax=axs[1])
axs[1].set_title('500 Wörter pro Segment')
sns.barplot(x='zeta', y=instanz1000.wort, data=instanz1000, color='b', ax=axs[2])
axs[2].set_title('1000 Wörter pro Segment')
# Out:
# Text(0.5, 1.0, '1000 Wörter pro Segment')

# %%
sprech100 = pd.read_csv('../results/zeta/sprechmarker_100.csv', header=None)
sprech100.columns = ['wort', 'zeta']
sprech100 = sprech100.sort_values(by='zeta', ascending=False)

sprech500 = pd.read_csv('../results/zeta/sprechmarker_500.csv', header=None)
sprech500.columns = ['wort', 'zeta']
sprech500 = sprech500.sort_values(by='zeta', ascending=False)

sprech1000 = pd.read_csv('../results/zeta/sprechmarker_1000.csv', header=None)
sprech1000.columns = ['wort', 'zeta']
sprech1000 = sprech1000.sort_values(by='zeta', ascending=False)

fig, axs = plt.subplots(1,3, figsize=(20,3))
sns.barplot(x='zeta', y=sprech100.wort, data=sprech100, color='b', ax=axs[0])
axs[0].set_title('100 Wörter pro Segment')
sns.barplot(x='zeta', y=sprech500.wort, data=sprech500, color='b', ax=axs[1])
axs[1].set_title('500 Wörter pro Segment')
sns.barplot(x='zeta', y=sprech1000.wort, data=sprech1000, color='b', ax=axs[2])
axs[2].set_title('1000 Wörter pro Segment')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-f7eab6f740db> in <module>
# ----> 1 sprech100 = pd.read_csv('../results/zeta/sprechmarker_100.csv', header=None)
#       2 sprech100.columns = ['wort', 'zeta']
#       3 sprech100 = sprech100.sort_values(by='zeta', ascending=False)
#       4
#       5 sprech500 = pd.read_csv('../results/zeta/sprechmarker_500.csv', header=None)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../results/zeta/sprechmarker_100.csv does not exist: '../results/zeta/sprechmarker_100.csv'

# %%
lsprech100 = pd.read_csv('../results/zeta/sprechmarker_lang_100pro_wort.csv', header=None)
lsprech100.columns = ['wort', 'zeta']
lsprech100 = lsprech100.sort_values(by='zeta', ascending=False)

lsprech500 = pd.read_csv('../results/zeta/sprechmarker_lang_500pro_wort.csv', header=None)
lsprech500.columns = ['wort', 'zeta']
lsprech500 = lsprech500.sort_values(by='zeta', ascending=False)

lsprech1000 = pd.read_csv('../results/zeta/sprechmarker_lang_1000pro_wort.csv', header=None)
lsprech1000.columns = ['wort', 'zeta']
lsprech1000 = lsprech1000.sort_values(by='zeta', ascending=False)

fig, axs = plt.subplots(1,3, figsize=(20,7))
sns.barplot(x='zeta', y=lsprech100.wort[-20:], data=lsprech100, color='b', ax=axs[0])
axs[0].set_title('100 Wörter pro Segment')
sns.barplot(x='zeta', y=lsprech500.wort[-20:], data=lsprech500, color='b', ax=axs[1])
axs[1].set_title('500 Wörter pro Segment')
sns.barplot(x='zeta', y=lsprech1000.wort[-20:], data=lsprech1000, color='b', ax=axs[2])
axs[2].set_title('1000 Wörter pro Segment')
# Out:
# Text(0.5, 1.0, '1000 Wörter pro Segment')

# %%
print(lsprech100[lsprech100.wort=='fragen'])
sprech100[sprech100.wort=='fragen']
# Out:
#        wort      zeta
# 127  fragen -0.066436
#      wort      zeta
# 2  fragen -0.066436

# %%
sprech100 = pd.read_csv('../results/zeta/sprechmarker_100pro_wort.csv', header=None)
sprech100.columns = ['wort', 'zeta']
sprech100 = sprech100.sort_values(by='zeta', ascending=False)

sprech500 = pd.read_csv('../results/zeta/sprechmarker_500pro_wort.csv', header=None)
sprech500.columns = ['wort', 'zeta']
sprech500 = sprech500.sort_values(by='zeta', ascending=False)

sprech1000 = pd.read_csv('../results/zeta/sprechmarker_1000pro_wort.csv', header=None)
sprech1000.columns = ['wort', 'zeta']
sprech1000 = sprech1000.sort_values(by='zeta', ascending=False)

fig, axs = plt.subplots(1,3, figsize=(20,7))
sns.barplot(x=sprech100.zeta, y=sprech100.wort, data=sprech100, color='b', ax=axs[0])
axs[0].set_title('100 Wörter pro Segment')
sns.barplot(x=sprech500.zeta, y=sprech500.wort, data=sprech500, color='b', ax=axs[1])
axs[1].set_title('500 Wörter pro Segment')
sns.barplot(x=sprech1000.zeta, y=sprech1000.wort, data=sprech1000, color='b', ax=axs[2])
axs[2].set_title('1000 Wörter pro Segment')
# Out:
# Text(0.5, 1.0, '1000 Wörter pro Segment')

# %%
test100 = pd.read_csv('../results/zeta/test_100pro_wort.csv', header=None)
test100.columns = ['wort', 'zeta']
test100 = test100.sort_values(by='zeta', ascending=False)

test500 = pd.read_csv('../results/zeta/test_500pro_wort.csv', header=None)
test500.columns = ['wort', 'zeta']
test500 = test500.sort_values(by='zeta', ascending=False)

test1000 = pd.read_csv('../results/zeta/test_1000pro_wort.csv', header=None)
test1000.columns = ['wort', 'zeta']
test1000 = test1000.sort_values(by='zeta', ascending=False)

fig, axs = plt.subplots(1,3, figsize=(20,7))
sns.barplot(x='zeta', y=test100.wort, data=test100, color='b', ax=axs[0])
axs[0].set_title('100 Wörter pro Segment')
sns.barplot(x='zeta', y=test500.wort, data=test500, color='b', ax=axs[1])
axs[1].set_title('500 Wörter pro Segment')
sns.barplot(x='zeta', y=test1000.wort, data=test1000, color='b', ax=axs[2])
axs[2].set_title('1000 Wörter pro Segment')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-cf13b63ca41b> in <module>
# ----> 1 test100 = pd.read_csv('../results/zeta/test_100pro_wort.csv', header=None)
#       2 test100.columns = ['wort', 'zeta']
#       3 test100 = test100.sort_values(by='zeta', ascending=False)
#       4
#       5 test500 = pd.read_csv('../results/zeta/test_500pro_wort.csv', header=None)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../results/zeta/test_100pro_wort.csv does not exist: '../results/zeta/test_100pro_wort.csv'

# %%
nur_merkmale = pd.read_csv('../results/zeta/pro_merkmal/alle_pro_merkmal.csv', header=None)
nur_merkmale.columns = ['zeta', 'merkmal']
nur_merkmale
# Out:
#        zeta       merkmal
# 0 -0.414740           anf
# 1  0.023844       emotion
# 2  0.229046         nomen
# 3  0.000000      nur_dupl
# 4  0.000000     ohne_dupl
# 5 -0.003613  sprechmarker
# 6  0.000000       instanz

# %%
fig= plt.figure(figsize=(20,10))
sns.barplot(x='merkmal', y='zeta', data=nur_merkmale, color='b')
